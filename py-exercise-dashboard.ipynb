# %% [markdown]
# # Programming Project - Unit 3,3
# *by Igor A. Brandão and Leandro Antonio Feliciano da Silva*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Full content of the statistical part seen in the course;
# - Graphs generation;
# - Geolocation analysis and hypotheses should be explained in detail;
# - Web scraping.

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Bokeh charts;
# - Numpy library;
# - Tqdm progress bar
# - Requests;
# - urlopen;
# - HTTPError;
# - BeautifulSoup
# - Regular expression

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium heatmap
import folium
from folium.plugins import HeatMap

# Import tqdm progressing bar plugin
from tqdm import tqdm

# Import bokeh libraries
from bokeh.plotting import figure
from bokeh.charts import Bar, Histogram, Donut, BoxPlot, Line, output_notebook, show
from bokeh.layouts import row, gridplot, column
from bokeh.models import HoverTool
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.models import HoverTool
from bokeh.charts.attributes import AttrSpec, ColorAttr, MarkerAttr, CatAttr

# Import request libraries
from urllib.request import Request, urlopen
from urllib.error import HTTPError

# Import web scraping libraries
from bs4 import BeautifulSoup
import re # regular expression

# Import API libraries
import requests
import json
from pandas.io.json import json_normalize

# %% [markdown]
# <hr>

# %% [markdown]
# # API section
#
# ## API data retrieving
#
# #### In the cell bellow, we perform a connection with Health Graph API - Runkeeper.

# %%
# Access token
ACCESS_TOKEN = '25bc30d6dd6f4b99bbeb48e8619103b4'

# Base URI
api_URI = "http://api.runkeeper.com/fitnessActivities"

# Number of results
pageSize = 300

# Final URI
url = '%s?pageSize=%s&access_token=%s' % \
    (api_URI, pageSize, ACCESS_TOKEN,)

# print(url)

# Receive the results from API
api_content = requests.get(url).json()

print(json.dumps(api_content, indent=1))
# Out:
# {
#  "size": 245,
#  "items": [
#   {
#    "utc_offset": -3,
#    "duration": 1037,
#    "start_time": "Fri, 23 Jun 2017 12:40:11",
#    "total_calories": 148,
#    "tracking_mode": "outdoor",
#    "total_distance": 5345.75479639154,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005956310"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1140,
#    "start_time": "Fri, 23 Jun 2017 07:50:54",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6081.16390011933,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005843765"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1285,
#    "start_time": "Thu, 22 Jun 2017 12:41:16",
#    "total_calories": 184,
#    "tracking_mode": "outdoor",
#    "total_distance": 6589.61628038915,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005535586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1235,
#    "start_time": "Thu, 22 Jun 2017 07:37:35",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6162.94434876089,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005303953"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1158,
#    "start_time": "Tue, 20 Jun 2017 12:35:21",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 5382.67114549159,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004255363"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1193,
#    "start_time": "Tue, 20 Jun 2017 07:30:08",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6086.98681262211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004088987"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1021,
#    "start_time": "Mon, 19 Jun 2017 12:36:20",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5389.11505599285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1003621881"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 

#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/835895188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2271,
#    "start_time": "Sun, 19 Jun 2016 15:54:04",
#    "total_calories": 420,
#    "tracking_mode": "outdoor",
#    "total_distance": 5850.37512732216,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/810514835"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8106,
#    "start_time": "Sat, 18 Jun 2016 07:13:03",
#    "total_calories": 781,
#    "tracking_mode": "outdoor",
#    "total_distance": 7463.43806205611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687187"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2563,
#    "start_time": "Sat, 18 Jun 2016 06:08:27",
#    "total_calories": 373,
#    "tracking_mode": "outdoor",
#    "total_distance": 4123.84686293397,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687157"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2087,
#    "start_time": "Wed, 15 Jun 2016 06:02:52",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 6129.74843199285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/807853214"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 789,
#    "start_time": "Mon, 13 Jun 2016 17:06:40",
#    "total_calories": 59,
#    "tracking_mode": "outdoor",
#    "total_distance": 615.714617224684,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806924800"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 606,
#    "start_time": "Mon, 13 Jun 2016 15:03:52",
#    "total_calories": 299,
#    "tracking_mode": "outdoor",
#    "total_distance": 549.757560743894,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806901919"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1594,
#    "start_time": "Mon, 13 Jun 2016 05:50:21",
#    "total_calories": 450,
#    "tracking_mode": "outdoor",
#    "total_distance": 5756.30000050235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806547477"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1634,
#    "start_time": "Fri, 10 Jun 2016 05:58:37",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5797.34713357958,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/804841603"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2209,
#    "start_time": "Mon, 23 May 2016 06:08:33",
#    "total_calories": 429,
#    "tracking_mode": "outdoor",
#    "total_distance": 5884.05329187354,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/793442865"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1661,
#    "start_time": "Mon, 16 May 2016 05:54:44",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5814.90671752075,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/788769831"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1862,
#    "start_time": "Sat, 14 May 2016 06:09:23",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5835.27134531731,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/787533188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Thu, 5 May 2016 05:43:14",
#    "total_calories": 453,
#    "tracking_mode": "outdoor",
#    "total_distance": 5786.59705963899,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/781785039"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1812,
#    "start_time": "Tue, 3 May 2016 05:49:35",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5887.67166192717,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/780351088"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1837,
#    "start_time": "Wed, 20 Apr 2016 05:51:15",
#    "total_calories": 456,
#    "tracking_mode": "outdoor",
#    "total_distance": 5734.59075257851,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/772361130"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 450,
#    "start_time": "Mon, 18 Apr 2016 06:19:21",
#    "total_calories": 63,
#    "tracking_mode": "outdoor",
#    "total_distance": 1047.1593087184,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943625"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1586,
#    "start_time": "Mon, 18 Apr 2016 05:50:48",
#    "total_calories": 565,
#    "tracking_mode": "outdoor",
#    "total_distance": 5782.77043463861,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943610"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1631,
#    "start_time": "Mon, 11 Apr 2016 05:23:04",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 5895.7589925569,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/766282546"
#   },
#   {
#    "utc_offset": -3,
#    "duration":

#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/695107893"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1390,
#    "start_time": "Tue, 27 Oct 2015 05:57:52",
#    "total_calories": 357,
#    "tracking_mode": "outdoor",
#    "total_distance": 4675.89620892755,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/682306939"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1358,
#    "start_time": "Fri, 25 Sep 2015 06:03:30",
#    "total_calories": 365,
#    "tracking_mode": "outdoor",
#    "total_distance": 4683.06656215611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/662964078"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1382,
#    "start_time": "Tue, 22 Sep 2015 06:05:45",
#    "total_calories": 361,
#    "tracking_mode": "outdoor",
#    "total_distance": 4655.54963372923,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/660961272"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1458.45,
#    "start_time": "Mon, 25 May 2015 05:40:07",
#    "total_calories": 362,
#    "tracking_mode": "outdoor",
#    "total_distance": 4703.8352331533,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/577596948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1417.324,
#    "start_time": "Thu, 30 Apr 2015 05:56:58",
#    "total_calories": 360,
#    "tracking_mode": "outdoor",
#    "total_distance": 4672.89007690554,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/559747998"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1397.167,
#    "start_time": "Wed, 22 Apr 2015 05:53:43",
#    "total_calories": 520,
#    "tracking_mode": "outdoor",
#    "total_distance": 4690.98068548032,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/554014359"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1500,
#    "start_time": "Mon, 20 Apr 2015 05:40:00",
#    "total_calories": 343,
#    "tracking_mode": "outdoor",
#    "total_distance": 4498.63606169824,
#    "entry_mode": "Web",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/553679343"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1436.981,
#    "start_time": "Sat, 15 Mar 2014 22:15:59",
#    "total_calories": 130,
#    "tracking_mode": "outdoor",
#    "total_distance": 1984.280937576,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268589"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 839.407,
#    "start_time": "Sat, 15 Mar 2014 18:25:50",
#    "total_calories": 65,
#    "tracking_mode": "outdoor",
#    "total_distance": 986.246059611153,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268582"
#   }
#  ]
# }

# %% [markdown]
# ## JSON to Data Frame conversion
#
# In order to have a better data manipulation, in the next cell we perform a conversion of importe in json format from API to pandas data frame

# %%
# Perform a conversion from JSON to Data Frame
api_df = json_normalize(api_content['items'])

# Converts the duration from seconds to minutes
api_df['duration'] = api_df['duration']/60
api_df['duration'] = api_df['duration'].round(2);

api_df
# Out:
#      duration entry_mode has_path     source                 start_time  \
# 0       17.28        API     True  RunKeeper  Fri, 23 Jun 2017 12:40:11
# 1       19.00        API     True  RunKeeper  Fri, 23 Jun 2017 07:50:54
# 2       21.42        API     True  RunKeeper  Thu, 22 Jun 2017 12:41:16
# 3       20.58        API     True  RunKeeper  Thu, 22 Jun 2017 07:37:35
# 4       19.30        API     True  RunKeeper  Tue, 20 Jun 2017 12:35:21
# 5       19.88        API     True  RunKeeper  Tue, 20 Jun 2017 07:30:08
# 6       17.02        API     True  RunKeeper  Mon, 19 Jun 2017 12:36:20
# 7       23.08        API     True  RunKeeper  Mon, 19 Jun 2017 07:43:02
# 8       50.43        API     True  RunKeeper  Sat, 17 Jun 2017 14:47:50
# 9       18.17        API     True  RunKeeper  Wed, 14 Jun 2017 13:26:09
# 10      18.82        API     True  RunKeeper  Wed, 14 Jun 2017 07:53:31
# 11      23.17        API     True  RunKeeper  Tue, 13 Jun 2017 12:48:45
# 12      19.30        API     True  RunKeeper  Tue, 13 Jun 2017 07:42:39
# 13      16.75        API     True  RunKeeper  Mon, 12 Jun 2017 12:12:13
# 14      18.48        API     True  RunKeeper  Mon, 12 Jun 2017 07:29:08
# 15      15.23        API     True  RunKeeper   Fri, 9 Jun 2017 13:47:21
# 16      18.82        API     True  RunKeeper   Fri, 9 Jun 2017 07:58:28
# 17      17.03        API     True  RunKeeper   Thu, 8 Jun 2017 13:01:53
# 18      19.70        API     True  RunKeeper   Thu, 8 Jun 2017 07:51:49
# 19      17.13        API     True  RunKeeper   Wed, 7 Jun 2017 12:16:18
# 20      18.77        API     True  RunKeeper   Wed, 7 Jun 2017 07:55:39
# 21      16.40        API     True  RunKeeper   Tue, 6 Jun 2017 12:47:04
# 22      18.50        API     True  RunKeeper   Tue, 6 Jun 2017 07:30:32
# 23      15.82        API     True  RunKeeper   Mon, 5 Jun 2017 12:20:58
# 24      19.32        API     True  RunKeeper   Mon, 5 Jun 2017 07:28:30
# 25      35.62        API     True  RunKeeper   Fri, 2 Jun 2017 13:43:00
# 26      18.30        API     True  RunKeeper   Fri, 2 Jun 2017 07:43:33
# 27      17.70        API     True  RunKeeper   Thu, 1 Jun 2017 13:05:46
# 28      18.75        API     True  RunKeeper   Thu, 1 Jun 2017 07:43:24
# 29      17.18        API     True  RunKeeper  Wed, 31 May 2017 13:05:39
# ..        ...        ...      ...        ...                        ...
# 215     30.62        API     True  RunKeeper  Wed, 20 Apr 2016 05:51:15
# 216      7.50        API     True  RunKeeper  Mon, 18 Apr 2016 06:19:21
# 217     26.43        API     True  RunKeeper  Mon, 18 Apr 2016 05:50:48
# 218     27.18        API     True  RunKeeper  Mon, 11 Apr 2016 05:23:04
# 219    133.97        API     True  RunKeeper   Thu, 7 Apr 2016 07:34:36
# 220     39.42        API     True  RunKeeper  Tue, 29 Mar 2016 05:38:59
# 221     27.33        API     True  RunKeeper  Wed, 23 Mar 2016 06:08:51
# 222     28.03        API     True  RunKeeper  Mon, 21 Mar 2016 05:57:29
# 223      4.35        API     True  RunKeeper  Sun, 20 Mar 2016 17:04:57
# 224     27.27        API     True  RunKeeper  Mon, 14 Mar 2016 05:52:20
# 225     14.98        API     True  RunKeeper   Tue, 8 Mar 2016 13:22:25
# 226     28.20        API     True  RunKeeper   Mon, 7 Mar 2016 06:03:09
# 227     58.43        API     True  RunKeeper   Sun, 6 Mar 2016 13:53:27
# 228     26.12        API     True  RunKeeper   Sun, 6 Mar 2016 11:23:33
# 229     30.35        API     True  RunKeeper   Thu, 3 Mar 2016 05:52:24
# 230     48.85        API     True  RunKeeper   Wed, 2 Mar 2016 18:26:34
# 231     31.95        API     True  RunKeeper  Mon, 29 Feb 2016 06:05:33
# 232     56.18        API     True  RunKeeper  Sun, 28 Feb 2016 10:41:56
# 233     29.95        API     True  RunKeeper  Mon, 22 Feb 2016 06:09:37
# 234     31.15        API     True  RunKeeper  Mon, 15 Feb 2016 05:55:11
# 235     24.63        API     True  RunKeeper   Wed, 4 Nov 2015 06:07:28
# 236     23.17        API     True  RunKeeper  Tue, 27 Oct 2015 05:57:52
# 237     22.63        API     True  RunKeeper  Fri, 25 Sep 2015 06:03:30
# 238     23.03        API     True  RunKeeper  Tue, 22 Sep 2015 06:05:45
# 239     24.31        API     True  RunKeeper  Mon, 25 May 2015 05:40:07
# 240     23.62        API     True  RunKeeper  Thu, 30 Apr 2015 05:56:58
# 241     23.29        API     True  RunKeeper  Wed, 22 Apr 2015 05:53:43
# 242     25.00        Web     True  RunKeeper  Mon, 20 Apr 2015 05:40:00
# 243     23.95        API     True  RunKeeper  Sat, 15 Mar 2014 22:15:59
# 244     13.99        API     True  RunKeeper  Sat, 15 Mar 2014 18:25:50
#
#      total_calories  total_distance tracking_mode     type  \
# 0               148     5345.754796       outdoor  Cycling
# 1               143     6081.163900       outdoor  Cycling
# 2               184     6589.616280       outdoor  Cycling
# 3               147     6162.944349       outdoor  Cycling
# 4               156     5382.671145       outdoor  Cycling
# 5               144     6086.986813       outdoor  Cycling
# 6               141     5389.115056       outdoor  Cycling
# 7               156     6143.735127       outdoor  Cycling
# 8               310     8859.432268       outdoor  Cycling
# 9               153     5753.597600       outdoor  Cycling
# 10              144     6045.106265       outdoor  Cycling
# 11              189     6607.603521       outdoor  Cycling
# 12              150     6090.686851       outdoor  Cycling
# 13              166     5779.655064       outdoor  Cycling
# 14              145     6114.832984       outdoor  Cycling
# 15              164     5766.429409       outdoor  Cycling
# 16              144     6105.268997       outdoor  Cycling
# 17              163     5783.286098       outdoor  Cycling
# 18              145     6181.855852       outdoor  Cycling
# 19              154     5759.411910       outdoor  Cycling
# 20              141     6096.464992       outdoor  Cycling
# 21              157     5978.891886       outdoor  Cycling
# 22              142     6111.351864       outdoor  Cycling
# 23              157     5711.356486       outdoor  Cycling
# 24              143     6073.793574       outdoor  Cycling
# 25              351    10489.031544       outdoor  Cycling
# 26              143     6063.576442       outdoor  Cycling
# 27              145     5378.707429       outdoor  Cycling
# 28              142     6095.874086       outdoor  Cycling
# 29              144     5392.255434       outdoor  Cycling
# ..              ...             ...           ...      ...
# 215             456     5734.590753       outdoor  Running
# 216              63     1047.159309       outdoor  Running
# 217             565     5782.770435       outdoor  Running
# 218             458     5895.758993       outdoor  Running
# 219             660     3698.485187       outdoor  Running
# 220             435     5990.805326       outdoor  Running
# 221             454     5749.381591       outdoor  Running
# 222             455     5789.026666       outdoor  Running
# 223              49      779.129465       outdoor  Running
# 224             447     5674.954407       outdoor  Running
# 225              75     1213.077333       outdoor  Running
# 226             462     5838.985723       outdoor  Running
# 227             253     3927.286643       outdoor  Running
# 228             101     1593.608817       outdoor  Running
# 229             489     6154.287592       outdoor  Running
# 230             105      844.110303       outdoor  Running
# 231             467     5805.836798       outdoor  Running
# 232             205     3016.578557       outdoor  Running
# 233             366     4815.522677       outdoor  Running
# 234             353     4555.472434       outdoor  Running
# 235             238     3272.864756       outdoor  Running
# 236             357     4675.896209       outdoor  Running
# 237             365     4683.066562       outdoor  Running
# 238             361     4655.549634       outdoor  Running
# 239             362     4703.835233       outdoor  Running
# 240             360     4672.890077       outdoor  Running
# 241             520     4690.980685       outdoor  Running
# 242             343     4498.636062       outdoor  Running
# 243             130     1984.280938       outdoor  Running
# 244              65      986.246060       outdoor  Running
#
#                                uri  utc_offset
# 0    /fitnessActivities/1005956310          -3
# 1    /fitnessActivities/1005843765          -3
# 2    /fitnessActivities/1005535586          -3
# 3    /fitnessActivities/1005303953          -3
# 4    /fitnessActivities/1004255363          -3
# 5    /fitnessActivities/1004088987          -3
# 6    /fitnessActivities/1003621881          -3
# 7    /fitnessActivities/1003493993          -3
# 8    /fitnessActivities/1002663916          -3
# 9    /fitnessActivities/1000879327          -3
# 10   /fitnessActivities/1000713723          -3
# 11   /fitnessActivities/1000444019          -3
# 12   /fitnessActivities/1000067931          -3
# 13    /fitnessActivities/999721058          -3
# 14    /fitnessActivities/999458777          -3
# 15    /fitnessActivities/997878707          -3
# 16    /fitnessActivities/997716950          -3
# 17    /fitnessActivities/997294049          -3
# 18    /fitnessActivities/997151351          -3
# 19    /fitnessActivities/996701562          -3
# 20    /fitnessActivities/996573146          -3
# 21    /fitnessActivities/996225220          -3
# 22    /fitnessActivities/995999970          -3
# 23    /fitnessActivities/995698428          -3
# 24    /fitnessActivities/995399416          -3
# 25    /fitnessActivities/993855342          -3
# 26    /fitnessActivities/993644394          -3
# 27    /fitnessActivities/993644390          -3
# 28    /fitnessActivities/993050883          -3
# 29    /fitnessActivities/992607843          -3
# ..                             ...         ...
# 215   /fitnessActivities/772361130          -3
# 216   /fitnessActivities/770943625          -3
# 217   /fitnessActivities/770943610          -3
# 218   /fitnessActivities/766282546          -3
# 219   /fitnessActivities/764018100          -3
# 220   /fitnessActivities/759716642          -3
# 221   /fitnessActivities/755079850          -3
# 222   /fitnessActivities/753860205          -3
# 223   /fitnessActivities/753646484          -3
# 224   /fitnessActivities/749797852          -3
# 225   /fitnessActivities/747371294          -3
# 226   /fitnessActivities/745796497          -3
# 227   /fitnessActivities/745656183          -3
# 228   /fitnessActivities/745656175          -3
# 229   /fitnessActivities/743736231          -3
# 230   /fitnessActivities/743518140          -3
# 231   /fitnessActivities/742107339          -3
# 232   /fitnessActivities/742025830          -3
# 233   /fitnessActivities/738351372          -3
# 234   /fitnessActivities/734684880          -3
# 235   /fitnessActivities/695107893          -2
# 236   /fitnessActivities/682306939          -2
# 237   /fitnessActivities/662964078          -3
# 238   /fitnessActivities/660961272          -3
# 239   /fitnessActivities/577596948          -3
# 240   /fitnessActivities/559747998          -3
# 241   /fitnessActivities/554014359          -3
# 242   /fitnessActivities/553679343          -3
# 243   /fitnessActivities/439268589          -3
# 244   /fitnessActivities/439268582          -3
#
# [245 rows x 11 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to visualize the data into an excel file, the cell bellow is responsible for exporting the data.

# %%
# Export the new dataSet to csv
api_df.to_csv('dataSource.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # Statistic section
#
# #### Here in this section, we'll handle the statistics infos.
#
# #### The idea is to use the ***top-down analysis***, from the more generic context to the specific one

# %% [markdown]
# ## 1) Exercises summary

# %% [markdown]
# ## 2) Activites overall times

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Make a bar chart: p
p = Bar(api_df, values='duration', label='type', agg='mean', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            plot_width=750, plot_height=500, tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity overall time'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Average time:',' @height')]

# Configure visual properties on a plot's title attribute
p.title.text = "Overall time by activity type"
p.title.align = "center"
p.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b0dd900e-debd-4ef3-889d-4d473cd9cbc6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="79164f80-1efe-47fd-ba8e-f88c61ce4f7c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("79164f80-1efe-47fd-ba8e-f88c61ce4f7c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79164f80-1efe-47fd-ba8e-f88c61ce4f7c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79164f80-1efe-47fd-ba8e-f88c61ce4f7c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"67cda8cd-fc4f-4085-85e6-c7e6564f28eb":{"roots":{"references":[{"attributes":{"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"}},"id":"c3682d02-6e6c-44e9-8b42-a2307de714fd","type":"SaveTool"},{"attributes":{"callback":null,"overlay":{"id":"2390594e-7787-4d62-bc9c-b4648610665a","type":"BoxAnnotation"},"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"}},"id":"bb438096-4f90-4fd0-8a97-2297a52abbc8","type":"BoxSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5c2548f9-3ae7-4935-829d-72426759f040","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"}},"id":"8eee5b12-1c67-4b87-b0db-23398b9e0248","type":"CrosshairTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2390594e-7787-4d62-bc9c-b4648610665a","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"}},"id":"519c4705-a41d-44bd-9300-7f1acefc3d85","type":"ResizeTool"},{"attributes":{},"id":"c85951a6-bd04-4a81-8e26-9c76180ff573","type":"ToolEvents"},{"attributes":{"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"}},"id":"92dd77ac-45bd-4dda-8afd-01f82786e2e6","type":"ResetTool"},{"attributes":{"callback":null,"plot":{"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"},"tooltips":[["Tipo de atividade","@type"],["Average time:"," @height"]]},"id":"8b47d4af-a4e6-4809-ba4c-54a00694778c","type":"HoverTool"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"7eb513c5-b83d-4b6e-8d8b-0a7e56cee0f4","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"d3081fc8-4e92-4f83-9f8e-677b098d02a3","type":"LinearAxis"}],"plot_height":500,"plot_width":750,"renderers":[{"id":"5c2548f9-3ae7-4935-829d-72426759f040","type":"BoxAnnotation"},{"id":"2390594e-7787-4d62-bc9c-b4648610665a","type":"BoxAnnotation"},{"id":"4a7c115e-9f54-4076-a0d3-9b200bc6cf14","type":"GlyphRenderer"},{"id":"29fc88d4-34df-4767-b247-e73edb2e5109","type":"GlyphRenderer"},{"id":"da7a302e-ffb3-41eb-8d8e-dd2382df8f1d","type":"Legend"},{"id":"7eb513c5-b83d-4b6e-8d8b-0a7e56cee0f4","type":"CategoricalAxis"},{"id":"d3081fc8-4e92-4f83-9f8e-677b098d02a3","type":"LinearAxis"},{"id":"056c412f-94ec-4905-9aaf-afd8b22ef714","type":"Grid"}],"title":{"id":"9376eca1-98dd-417d-9c11-5a5e195526e4","type":"Title"},"tool_events":{"id":"c85951a6-bd04-4a81-8e26-9c76180ff573","type":"ToolEvents"},"toolbar":{"id":"de485f2a-8a86-4654-80fa-b8699a8b23f8","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"1bf5e5ea-e7bb-4b02-9cca-35301b9cfba5","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"de316036-9fb7-4290-8ff8-96519ca290b3","type":"Range1d"}},"id":"735853b2-6a07-407e-aea3-0633ec4e64d3","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"817a7910-6ecf-4d8f-bf3d-ed8a5f5864df","type":"BasicTicker"},{"attributes":{"callback":null,"factors":["Cycling","Running"]},"id":"1bf5e5ea-e7bb-4b02-9cca-35301b9cfba5","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Running"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[34.752777777777766],"label":[{"type":"Running"}],"line_alpha":[1.0],"line_color":["white"],"type":["Running"],"width":[0.8], ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2) Activites calories burning

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

# Make a bar chart: p
bar = Bar(api_df, values='total_calories', label='type', agg='sum', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Make a box plot: unit 1
box = BoxPlot(api_df, values='total_calories', label='type', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity total calories'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Total calories:',' @height')]

# Configure visual properties on a plot's title attribute
bar.title.text = "Total calories burned by activity type"
bar.title.align = "center"
bar.title.text_font_size = "25px"

box.title.text = "Total calories burned by activity type"
box.title.align = "center"
box.title.text_font_size = "25px"

# Create a list containing plots
row1 = [bar,box]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1],sizing_mode='scale_width', plot_height=750)

# Call the output_notebook() 
output_notebook()
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6ffedc81-3da3-4c93-8afa-ce69a5ad91ba">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="32a9f56d-cb57-4615-9981-5571a5594976"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("32a9f56d-cb57-4615-9981-5571a5594976").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("32a9f56d-cb57-4615-9981-5571a5594976");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '32a9f56d-cb57-4615-9981-5571a5594976' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bea01843-4e30-4599-879e-10f11f685c61":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2683d5ea-3291-47f3-8f6d-bfd2b44ce5a9","type":"BoxZoomTool"},{"id":"a8be109d-527b-4dc5-9faa-c83509906b42","type":"BoxSelectTool"},{"id":"7de1246d-9976-463b-8b78-a260601ee23f","type":"CrosshairTool"},{"id":"debcdc32-c7d4-46f1-a855-5802f2eb3042","type":"ResizeTool"},{"id":"dbc2609d-b6f2-4135-9865-0b683efa5cf7","type":"HoverTool"},{"id":"9485320f-24ca-4c46-b6ad-b62d4c2783a6","type":"ResetTool"},{"id":"15e6fbaa-e18b-4bdc-bf63-d58d32cdf13d","type":"SaveTool"}]},"id":"3439aad9-ce46-4ef1-b961-84340473d592","type":"Toolbar"},{"attributes":{"children":[{"id":"836f8068-b0ec-43e2-82b6-e844d2d06af9","type":"ToolbarBox"},{"id":"57dc71a4-bf90-4718-b051-7d70d255fd85","type":"Column"}],"sizing_mode":"scale_width"},"id":"f8a3057f-ce31-414a-921
# %% [markdown]
# <hr>

# %% [markdown]
# ## 3) Activites by period
#
# First of all we need to split the information by period. To achieve that, the idea is apply a group selection by partial string in timestamp column

# %% [markdown]
# ## Timestamp split into columns
#
# In order to have a better way to handle the data by period, it'll be necessary split the timestamp column into separate columns

# %%
# =================================================================================
# Dataframe timestamp split
# =================================================================================

# Copy the data
data_by_period = api_df.copy()
data_by_period["month"] = 0
data_by_period["month_index"] = 0
data_by_period["year"] = 0

# Fill the years
data_by_period.loc[data_by_period['start_time'].str.contains('2017'), 'year'] = '2017'
data_by_period.loc[data_by_period['start_time'].str.contains('2016'), 'year'] = '2016'
data_by_period.loc[data_by_period['start_time'].str.contains('2015'), 'year'] = '2015'
data_by_period.loc[data_by_period['start_time'].str.contains('2014'), 'year'] = '2014'

# Fill the months
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month'] = 'Jan'
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month_index'] = '1'

data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month'] = 'Feb'
data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month_index'] = '2'

data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month'] = 'Mar'
data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month_index'] = '3'

data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month'] = 'Apr'
data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month_index'] = '4'

data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month'] = 'May'
data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month_index'] = '5'

data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month'] = 'Jun'
data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month_index'] = '6'

data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month'] = 'Jul'
data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month_index'] = '7'

data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month'] = 'Aug'
data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month_index'] = '8'

data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month'] = 'Sep'
data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month_index'] = '9'

data_by_period.loc[data_by_period['start_time'].str.contains('Oct-'), 'month'] = 'Oct'
data_by_period.loc[data_by_period['start_time'].str.contains('Oct'), 'month_index'] = '10'

data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month'] = 'Nov'
data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month_index'] = '11'

data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month'] = 'Dec'
data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month_index'] = '12'

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid replacing the timestamp to other columns, we'll export the new dataSet to a csv file. You can skip this operation because the new .csv dataSet is already included in the project

# %%
# Export the new dataSet to csv
data_by_period.to_csv('dataSourceByPeriod.csv', encoding="utf-8")

# %% [markdown]
# ## 2017 overview

# %%
# =================================================================================
# Data selection
# =================================================================================

# Import the fertility.csv data: data
data_by_period = pd.read_csv("dataSourceByPeriod.csv", encoding = 'latin2')

# Filter the activities by year
activities2017 = data_by_period[data_by_period["year"] == 2017].sort_values('month_index')

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

barMonth = Bar(activities2017, values='total_distance', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                      legend='top_left', tools=TOOLS)

barCaloryMonth = Bar(activities2017, values='total_calories', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                      legend='top_left', tools=TOOLS)

# Set the y and x axis label
barMonth.yaxis.axis_label= 'Total distance'
barMonth.xaxis.axis_label= 'Month'

barCaloryMonth.yaxis.axis_label= 'Total calories'
barCaloryMonth.xaxis.axis_label= 'Month'

# Set hover to bars
hover = barMonth.select(dict(type=HoverTool))
hover.tooltips = [('Month', '@x'),('Total distance:',' @height')]

hover = barCaloryMonth.select(dict(type=HoverTool))
hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

# Configure visual properties on a plot's title attribute
barMonth.title.text = "Total distance by month in 2017"
barMonth.title.align = "center"
barMonth.title.text_font_size = "25px"

barCaloryMonth.title.text = "Total calories by month in 2017"
barCaloryMonth.title.align = "center"
barCaloryMonth.title.text_font_size = "25px"

# Create a list containing plots
row1 = [barMonth, barCaloryMonth]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1],sizing_mode='scale_width', plot_height=650, plot_width=900)

# Call the output_notebook() 
output_notebook()
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f24ef1b5-e42b-4fa3-9fdc-9fc56f0cae96">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7efc292c-d51d-4deb-a48d-1c3dc932a0d9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7efc292c-d51d-4deb-a48d-1c3dc932a0d9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7efc292c-d51d-4deb-a48d-1c3dc932a0d9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7efc292c-d51d-4deb-a48d-1c3dc932a0d9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c9866be7-5059-4be8-9913-b12db3da40e9":{"roots":{"references":[{"attributes":{},"id":"de59ef36-3ecb-40e2-bcf0-d98480a4aa50","type":"CategoricalTickFormatter"},{"attributes":{},"id":"c06faeb6-8629-4d16-9599-28bf4ecf8b6a","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e596d5b5-b0cb-46c0-af87-2a07fa9385b8","type":"Rect"},{"attributes":{"children":[{"id":"3564b47a-1f27-490c-8bb6-01095ce77cc7","subtype":"Chart","type":"Plot"},{"id":"752dd24d-9554-442a-bbae-d2dcef0ee9e5","subtype":"Chart","type":"Plot"}],"sizing_mode":"scale_width"},"id":"ddd7bb65-ecc9-414c-ab96-77c9053c0924","type":"Row"},{"attributes":{"callback":null,"overlay":{"id":"3aed6651-df20-4220-9b18-f6efd2351988","type":"BoxAnnotation"},"plot":{"id":"3564b47a-1f27-490c-8bb6-01095ce77cc7","subtype":"Chart","type":"Plot"}},"id":"506ac30c-9ba9-491b-a689-7c7110853d7d","type":"BoxSelectTool"},{"attributes":{"data_source":{"id":"060afeac-7a80-4e4c-9216-53ab7984fbdb","type":"ColumnDataSource"},"glyph":{"id":"62fbc45b-c364-4e47-9326-27c822901d64","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"04ef038c-63f9-4fcb-9174-acd21d28ea8f","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"752dd24d-9554-442a-bbae-d2dcef0ee9e5","subtype":"Chart","type":"Plot"},"ticker":{"id":"2f4c4523-bc7c-4ef0-85bc-08d4808f8241","type":"BasicTicker"}},"id":"a3595440-1dc9-415f-b63e-9f464998559f","type":"Grid"},{"attributes":{},"id":"0364b269-f6aa-4280-b1d3-ed6311408559","type":"CategoricalTicker"},{"attributes":{},"id":"2f4c4523-bc7c-4ef0-85bc-08d4808f8241","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"Jun"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[4767.0],"label":[{"month":"Jun"}],"line_alpha":[1.0],"line_color":["white"],"month":["Jun"],"width":[0.8],"x":["Jun"],"y":[2383.5]}},"id":"060afeac-7a80-4e4c-9216-53ab7984fbdb","type":"ColumnDataSource"},{"attributes":{},"id":"281c59bf-56ef-4b76-b122-560ea83de725","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"ddd7bb65-ecc9-414c-ab96-77c9053c0924","type":"Row"}],"sizing_mode":"scale_width"},"id":"a57db00f-ef7e-41a4-bc40-ec4ea7faef62","type":"Column"},{"attributes":{"axis_label":"Total calories","formatter":{"id":"281c59bf-56ef-4b76-b122-560ea83de725","type":"BasicTickFormatter"},"plot":{"id":"752dd24d-9554-442a-bbae-d2dcef0ee9e5","subtype":"Chart","type":"Plot"},"ticker":{"id":"2f4c4523-bc7c-4ef0-85bc-08d4808f8241","type":"BasicTicker"}},"id":"5ce9f1f7-2674-4f52-b1b1-a79bda227614","type":"LinearAxis"},{"attributes":{"align":"center","plot":null,"text":"Total calories by month in 2017","text_font_size":{"value":"25px"}},"id":"5c1b12e1-7170-4583-94db-95fd35b1fb75","type":"Title"},{"attributes":{},"id":"c60cc405-26f1-4e4d-8bd6-45d7f6ac8dbb","type":"CategoricalTicker"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"bc429c37-9d47-4b2e-b8c3-ba2cde9f342e","type":"BoxZoomTool"},{"id":"506ac30c-9ba9-491b-a689-7c7110853d7d","type":"BoxSelectTool"},{"id":"384dba01-e16f-4d79-933b-a6c02db514fc","type":"CrosshairTool"},{"id":"c534d88c-d25f-4db5-938f-caf62974d4dd","type":"ResizeTool"},{"id":"e9db4530-96f8-49f3-aa1c-1d9b3bf8e62a","type":"HoverTool"},{"id":"78a0d36a-093b-4370-8210-918a01a4dd35","type":"ResetTool"},{"id":"0c07725d-2f40-43e9-88fb-c68585d831f7","type":"SaveTool"},{"id":"bfacaa40-38b5-40a6-ad7d-48ca24e8520f","type":"BoxZoomTool"},{"id":"3fe1a571-4742-40c2-a4b8-eb8dbf03cf21","type":"BoxSelectTool"},{"id":"8036dfb2-a4d5-4d42-865f-75c060ad9c80","type":"CrosshairTool"},{"id":"2cd70dae-5c3f-4b08-86bc-50cda189d33e","type":"ResizeTool"},{"id":"218040bf-8035-45da ...

# %% [markdown]
# ## 5) Overall grades dispersion

# %%
# =================================================================================
# Data selection
# =================================================================================

# Select the subject list
sql = "select overall_grade from Grade where overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0"

# Execute query and store records in DataFrame: data
data = pd.read_sql_query(sql, engine)

# Convert the data into a dataFrame groupped values
grades = data.copy()
grades["Count"] = 0

# Group the overall grades and count the group frequency
grades = pd.DataFrame(grades.groupby(["overall_grade"])['Count'].count()).reset_index()

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Grades between 0.0 and 3.0
grades1 = grades[(0.0 < grades['overall_grade']) & (grades['overall_grade'] < 3.0)]['overall_grade']
frequency1 = grades[(0.0 < grades['overall_grade']) & (grades['overall_grade'] < 3.0)]["Count"]

# 3.1 <= Grades <= 5.0
grades2 = grades[(3.1 <= grades['overall_grade']) & (grades['overall_grade'] <= 5.0)]['overall_grade']
frequency2 = grades[(3.1 <= grades['overall_grade']) & (grades['overall_grade'] <= 5.0)]["Count"]

# 5.1 <= Grades <= 8.0
grades3 = grades[(5.1 <= grades['overall_grade']) & (grades['overall_grade'] <= 8.0)]['overall_grade']
frequency3 = grades[(5.1 <= grades['overall_grade']) & (grades['overall_grade'] <= 8.0)]["Count"]

# 8.1 < Grades
grades4 = grades[grades['overall_grade'] > 8.1]['overall_grade']
frequency4 = grades[grades['overall_grade'] > 8.1]["Count"]

# Create the figure: p
p = figure(x_axis_label='Grades', y_axis_label='Grades frequency', tools=TOOLS)

# Add the data to the plot
p.circle(grades1, frequency1, color="#990990", size=10, alpha=0.8)
p.circle(grades2, frequency2, color="#990000", size=10, alpha=0.8)
p.circle(grades3, frequency3, color="#009900", size=10, alpha=0.8)
p.circle(grades4, frequency4, color="#000099", size=10, alpha=0.8)

# Configure visual properties on a plot's title attribute
p.title.text = "Overall grades dispersion"
p.title.align = "center"
p.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f47ad422-e2ff-4d19-81cb-69aac95ad866">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0f85be67-f2fb-447b-a6f2-461dff600393"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0f85be67-f2fb-447b-a6f2-461dff600393").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0f85be67-f2fb-447b-a6f2-461dff600393");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0f85be67-f2fb-447b-a6f2-461dff600393' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6f90cc75-7258-42c3-8e36-5112af844902":{"roots":{"references":[{"attributes":{"callback":null},"id":"5329ac4c-4b9f-4c68-8660-5fcdc8b709a8","type":"DataRange1d"},{"attributes":{"plot":{"id":"ea4cef33-8f2e-4ba2-aa9b-26f30bea7211","subtype":"Figure","type":"Plot"}},"id":"72e47e92-b738-48fd-a453-39d419e9afa6","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"fdf606ae-a02a-4a7c-9ca0-1f17f66059cb","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"82a24e86-fbce-41b5-b262-ca9a33992b5f","type":"BoxZoomTool"},{"id":"ed26e143-6b63-48d9-bfa0-1c71e28e9961","type":"BoxSelectTool"},{"id":"06e776e4-73a6-4ac4-a34e-b8c59e2f7204","type":"CrosshairTool"},{"id":"4611f5c2-d00f-4693-b6a9-87f6c029f352","type":"ResizeTool"},{"id":"72e47e92-b738-48fd-a453-39d419e9afa6","type":"ResetTool"},{"id":"2295d923-e1dd-4048-aff3-98f5e47e4789","type":"HoverTool"},{"id":"15604eec-0de5-4071-b3a8-4febb4dbf33b","type":"SaveTool"}]},"id":"4b6a64e6-8251-4fe4-aaa8-43695913335f","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[29]},"y":[15,43,47,15,36,16,46,31,26,46,14,39,35,31,34,13,32,23,21,32,16,27,37,13,29,11,23,14,17]}},"id":"af345de9-edaf-48d8-be8e-545460f1c77b","type":"ColumnDataSource"},{"attributes":{},"id":"1f78e774-c7b7-4dc3-9eb3-0ceb7fc52725","type":"ToolEvents"},{"attributes":{"plot":{"id":"ea4cef33-8f2e-4ba2-aa9b-26f30bea7211","subtype":"Figure","type":"Plot"}},"id":"4611f5c2-d00f-4693-b6a9-87f6c029f352","type":"ResizeTool"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"#990000"},"line_alpha":{"value":0.8},"line_color":{"value":"#990000"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a93ba007-ae0e-4cce-9690-7dc7a42ba990","type":"Circle"},{"attributes":{},"id":"d638d659-4db7-43bd-972a-2e43fc8fade2","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"df5491db-67da-4040-838c-7a1e3a0526ad","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"zczMzMzMCECamZmZmZkJQGZmZmZmZgpAMzMzMzMzC0AAAAAAAAAMQM3MzMzMzAxAmpmZmZmZDUBmZmZmZmYOQDMzMzMzMw9AAAAAAAAAEEBmZmZmZmYQQM3MzMzMzBBAMzMzMzMzEUCamZmZmZkRQAAAAAAAABJAZmZmZmZmEkDNzMzMzMwSQDMzMzMzMxNAmpmZmZmZE0AAAAAAAAAUQA==","dtype":"float64","shape":[20]},"y":[7,15,19,12,13,11,13,18,14,16,10,15,12,12,12,8,19,13,3,89]}},"id":"5af5af41-7dd8-43e5-a1b6-64c226f9406b","type":"ColumnDataSource"},{"attributes":{"axis_label":"Grades","formatter":{"id":"4be47bf4-89ca-4521-8943-c403fd7d053e","type":"BasicTickFormatter"},"plot":{"id":"ea4cef33-8f2e-4ba2-aa9b-26f30bea7211","subtype":"Figure","type":"Plot"},"ticker":{"id":"970a40e6-6f94-4b1a-8012-7bcca8c7aba3","type":"BasicTicker"}},"id":"8bbf5093-65b8-46fd-b36a-5054c8cc9610","type":"LinearAxis"},{"attributes":{"callback":null},"id":"c92ed0a8-ea88-499b-918f-995009d84b08","type":"DataRange1d"},{"attributes":{"align":"center","plot":null,"text":"Overall grades dispersion","text_font_size":{"value":"25px"}},"id":"c6484dee-afff-4671-b73b-b1e5404ec464","type":"Title"},{"attributes":{"axis_label":"Grades frequency","formatter":{"id":"d638d659-4db7-43bd-972a-2e43fc8fade2","type":"BasicTickFormatter"},"plot":{"id":"ea4cef33-8f2e-4ba2-aa9b-26f30bea7211","sub ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## 6) Overall grades historic chart

# %%
# =================================================================================
# Data selection
# =================================================================================

# Select the overall grades by period
sql = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2014.1%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

sql2 = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2014.2%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

sql3 = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2015.1%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

sql4 = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2015.2%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

sql5 = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2016.1%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

sql6 = "select subject, period, AVG(overall_grade) as median from Grade where period like '%2016.2%' \
        and overall_grade IS NOT NULL and overall_grade <> '' \
        and overall_grade > 0.0 \
        Group by subject"

# Select the periods (except 2014.1 because the dataSet isn't complete)
sqlPeriod = "select distinct period from Grade where period not Like '%2014.1%'"

# Execute query and store records in DataFrame: data
data = pd.read_sql_query(sql, engine)
data2 = pd.read_sql_query(sql2, engine)
data3 = pd.read_sql_query(sql3, engine)
data4 = pd.read_sql_query(sql4, engine)
data5 = pd.read_sql_query(sql5, engine)
data6 = pd.read_sql_query(sql6, engine)
dataPeriod = pd.read_sql_query(sqlPeriod, engine)

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# (dict, OrderedDict, lists, arrays and DataFrames are valid inputs)
period = np.array(dataPeriod);

values = np.array([data2['median'], data3['median'], data4['median'], 
                   data5['median'], data6['median']])

# Make a line chart with the dataSet
line = Line(data=values, legend="top_left", background_fill_color="#E8DDCB", 
            ylabel='Overall grades', tools=TOOLS, plot_width=900)

# Configure visual properties on a plot's title attribute
line.title.text = "Overall grades historic chart"
line.title.align = "center"
line.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b794d27d-2968-42e2-825a-b3ade36a0717">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f14ac3f1-d556-4d3b-9766-3c29ba7dc943"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f14ac3f1-d556-4d3b-9766-3c29ba7dc943").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f14ac3f1-d556-4d3b-9766-3c29ba7dc943");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f14ac3f1-d556-4d3b-9766-3c29ba7dc943' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c44703ac-90a2-4df0-8255-abf26b85f90d":{"roots":{"references":[{"attributes":{"plot":{"id":"bb230ab8-60c5-4d62-9805-4f0924cb880e","subtype":"Chart","type":"Plot"}},"id":"9969979a-eec7-426d-9045-c2140e081394","type":"CrosshairTool"},{"attributes":{"overlay":{"id":"1491b186-b90d-4792-9979-b285099707d5","type":"BoxAnnotation"},"plot":{"id":"bb230ab8-60c5-4d62-9805-4f0924cb880e","subtype":"Chart","type":"Plot"}},"id":"e4884d95-c51f-4a6b-9534-ec669394e1af","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#00ad9c"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"41f2293b-bc06-470d-becf-7985c36de03d","type":"Line"},{"attributes":{"plot":{"id":"bb230ab8-60c5-4d62-9805-4f0924cb880e","subtype":"Chart","type":"Plot"}},"id":"1d5eef44-e624-467c-8241-64111fc2a79f","type":"ResetTool"},{"attributes":{"data_source":{"id":"4523646b-58bd-41cd-8e91-6c325905890d","type":"ColumnDataSource"},"glyph":{"id":"41f2293b-bc06-470d-becf-7985c36de03d","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b54111b3-693f-47e1-907f-14f5441435c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"bb230ab8-60c5-4d62-9805-4f0924cb880e","subtype":"Chart","type":"Plot"}},"id":"82adeb6b-f515-4e6e-bdb8-6da119768b4a","type":"HoverTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1491b186-b90d-4792-9979-b285099707d5","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"bb230ab8-60c5-4d62-9805-4f0924cb880e","subtype":"Chart","type":"Plot"},"ticker":{"id":"b1163711-84e1-41e0-8e36-84f82de4ab79","type":"BasicTicker"}},"id":"4ec3b475-2a37-468e-b593-03da15ed9765","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"d"},{"series":"d"},{"series":"d"},{"series":"d"},{"series":"d"},{"series":"d"}],"series":["d","d","d","d","d","d"],"x_values":[0,1,2,3,4,5],"y_values":{"__ndarray__":"Jzh6gqOnEEB7eWxF0HAOQM8LvdALfRNAzTrsHpu+EkDj2G2O3eYUQIW/TTFq+BdA","dtype":"float64","shape":[6]}}},"id":"3fe8aa44-88ad-421a-88aa-fceb137331e7","type":"ColumnDataSource"},{"attributes":{"label":{"value":"c"},"renderers":[{"id":"dcc59daa-e69e-4f58-b837-7bf4ea1bac4a","type":"GlyphRenderer"}]},"id":"4b479438-11bb-4d15-9408-45965e0011f5","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1edef950-d28c-4334-a950-7708d3423952","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"c"},{"series":"c"},{"series":"c"},{"series":"c"},{"series":"c"},{"series":"c"}],"series":["c","c","c","c","c","c"],"x_values":[0,1,2,3,4,5],"y_values":{"__ndarray__":"2jJSbFebFEBt0EJIeTIVQOGqf0AfURJAGGnHCoQRFUBR288Q9uIXQJuZmZmZoRhA","dtype":"float64","shape":[6]}}},"id":"8aa0759e-9d39-4d09-ab3d-8352485a8bdc","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"e"},{"series":"e"},{"series":"e"},{"series":"e"},{"series":"e"},{"series":"e"}],"series":["e","e","e","e","e","e"],"x_values":[0,1,2,3,4,5],"y_values":{"__ndarray__":"MgzDMAzDFkBUIGfkS+8VQKQ1WqM1WhNA/P//////DUAp2mrwHIEYQCtsDiRaYRdA","dtype":"float64","shape":[6]}}},"id":"4523646b-58bd-41cd-8e91-6c325905890d","type":"ColumnDataSource"},{"attributes":{"label":{"value":"b"},"renderers":[{"id":"366a881e-580b-459e-8f2a-358c6c3cb66e","type":"GlyphRenderer"}]},"id" ...

# %% [markdown]
# ## 7) Overall students situation

# %%
from bokeh.charts import Bar, output_notebook
from bokeh.models import Legend, LegendItem
from bokeh.models import ColumnDataSource, ranges, LabelSet

# =================================================================================
# Data selection
# =================================================================================

# Select the subject list status
sql = "select subject, situation from Grade"

# Execute query and store records in DataFrame: data
data = pd.read_sql_query(sql, engine)

# Create an specific array to subject status
subjectStatus = data.copy()
subjectStatus["Count"] = 0

# Count the status sum-up
subjectStatus = pd.DataFrame(subjectStatus.groupby(["situation"])['Count'].count()).reset_index()

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Bar chart creation
p = Bar(subjectStatus, values='Count', label='situation', color='situation',
          tools=TOOLS, plot_width=900, plot_height=750)

# Configure visual properties on a plot's title attribute
p.title.text = "Overall students situation"
p.title.align = "center"
p.title.text_font_size = "25px"
p.ylabel = 'Situation frequency'
p.xlabel = 'Situation'
p.legend.location = "top_right"

# Add hover selection for each bar
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Situation name',' $x'),('Frequency',' $y')]

# Call the output_notebook()
output_notebook()
        
# Plota o grafico
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c496bdb-228a-43cc-9e84-93a77c77fec3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51cdc7b9-c28f-4ef5-880f-9d1c8511cbbc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("51cdc7b9-c28f-4ef5-880f-9d1c8511cbbc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51cdc7b9-c28f-4ef5-880f-9d1c8511cbbc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51cdc7b9-c28f-4ef5-880f-9d1c8511cbbc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"24def340-9500-4d0a-a0f7-48bc8ec29c38":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"71ffca5b-e2d3-4bb8-a01c-8539d79d6f48","type":"BoxAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"71ffca5b-e2d3-4bb8-a01c-8539d79d6f48","type":"BoxAnnotation"},"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"}},"id":"a8564782-7403-4e82-89ae-d60c779308cd","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"}},"id":"8d1ec840-8270-496a-8bff-ea2b263d568d","type":"ResetTool"},{"attributes":{"overlay":{"id":"a7ac206a-8322-4ee7-910f-d47e5d6f5c34","type":"BoxAnnotation"},"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"}},"id":"6b35e7c7-2963-48d7-975b-633e6365228e","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a7ac206a-8322-4ee7-910f-d47e5d6f5c34","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"}},"id":"e6eb3645-745f-472e-bd5a-0e963e12a60b","type":"SaveTool"},{"attributes":{"callback":null,"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"},"tooltips":[["Situation name"," $x"],["Frequency"," $y"]]},"id":"816167ed-1e56-4554-b209-d43a9009f324","type":"HoverTool"},{"attributes":{},"id":"752c1929-9b1f-4cba-8391-f4009e68969e","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"situation":"CANCELADO"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[723.0],"label":[{"situation":"CANCELADO"}],"line_alpha":[1.0],"line_color":["white"],"situation":["CANCELADO"],"width":[0.8],"x":["CANCELADO"],"y":[361.5]}},"id":"f7098c9c-b8d4-4f71-9d5a-2b8c8740b8f6","type":"ColumnDataSource"},{"attributes":{"axis_label":"Situation","formatter":{"id":"752c1929-9b1f-4cba-8391-f4009e68969e","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"6017c5f5-5090-4719-992f-8e6311662cf6","subtype":"Chart","type":"Plot"},"ticker":{"id":"24ff4ba4-b390-47cc-af3f-748a8e7a2bd4","type":"CategoricalTicker"}},"id":"84e44285-d6c0-4e63-8423-428a4a51171d","type":"CategoricalAxis"},{"attributes":{"callback":null,"end":879.9},"id":"7cbf8649-fee6-4281-b372-8d4f56ffe4ea","type":"Range1d"},{"attributes":{"data_source":{"id":"1c5670de-5794-436b-861d-b85dc103c357","type":"ColumnDataSource"},"glyph":{"id":"5b47c96a-d30f-462f-839a-e71df66a6c46","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4e635e01-edd9-4d5f-b02c-4499653a9837","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"situation":"INCORPORADO"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[1.0],"label":[{"situation":"INCORPORADO"}],"line_alpha":[1.0],"line_color":["white"],"situation":["INCORPORADO"],"width":[0.8],"x":["INCORPORADO"],"y":[0.5]}},"id":"14d84dcd-a82f-449e-9b1f-84df78764104","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"} ...
