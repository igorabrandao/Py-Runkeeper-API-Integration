# %% [markdown]
# # Programming Project - Unit 3,3
# *by Igor A. Brandão and Leandro Antonio Feliciano da Silva*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Full content of the statistical part seen in the course;
# - Graphs generation;
# - Geolocation analysis and hypotheses should be explained in detail;
# - Web scraping.

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Bokeh charts;
# - Numpy library;
# - Tqdm progress bar
# - Requests;
# - urlopen;
# - HTTPError;
# - BeautifulSoup
# - Regular expression

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate
# !pip install pandas-datareader

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium heatmap
import folium
from folium.plugins import HeatMap

# Import tqdm progressing bar plugin
from tqdm import tqdm

# Import bokeh libraries
from bokeh.plotting import figure
from bokeh.charts import Bar, Histogram, Donut, BoxPlot, Line, output_notebook, show
from bokeh.layouts import row, gridplot, column
from bokeh.models import HoverTool
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.models import HoverTool
from bokeh.charts.attributes import AttrSpec, ColorAttr, MarkerAttr, CatAttr
from bokeh.plotting import ColumnDataSource

# Import request libraries
from urllib.request import Request, urlopen
from urllib.error import HTTPError

# Import web scraping libraries
from bs4 import BeautifulSoup
import re # regular expression

# Import API libraries
import requests
import json
from pandas.io.json import json_normalize

# Imports to output the result as a Markdown
from IPython.display import display, Markdown
from tabulate import tabulate

# %% [markdown]
# <hr>

# %% [markdown]
# # I - API section
#
# ## API data retrieving
#
# #### In the cell bellow, we perform a connection with Health Graph API - Runkeeper.

# %%
# Access token
ACCESS_TOKEN = '25bc30d6dd6f4b99bbeb48e8619103b4'

# Base URI
api_URI = "http://api.runkeeper.com/fitnessActivities"

# Number of results
pageSize = 300

# Final URI
url = '%s?pageSize=%s&access_token=%s' % \
    (api_URI, pageSize, ACCESS_TOKEN,)

# print(url)

# Receive the results from API
api_content = requests.get(url).json()

print(json.dumps(api_content, indent=1))
# Out:
# {
#  "size": 245,
#  "items": [
#   {
#    "utc_offset": -3,
#    "duration": 1037,
#    "start_time": "Fri, 23 Jun 2017 12:40:11",
#    "total_calories": 148,
#    "tracking_mode": "outdoor",
#    "total_distance": 5345.75479639154,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005956310"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1140,
#    "start_time": "Fri, 23 Jun 2017 07:50:54",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6081.16390011933,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005843765"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1285,
#    "start_time": "Thu, 22 Jun 2017 12:41:16",
#    "total_calories": 184,
#    "tracking_mode": "outdoor",
#    "total_distance": 6589.61628038915,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005535586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1235,
#    "start_time": "Thu, 22 Jun 2017 07:37:35",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6162.94434876089,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005303953"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1158,
#    "start_time": "Tue, 20 Jun 2017 12:35:21",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 5382.67114549159,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004255363"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1193,
#    "start_time": "Tue, 20 Jun 2017 07:30:08",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6086.98681262211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004088987"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 

#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/810514835"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8106,
#    "start_time": "Sat, 18 Jun 2016 07:13:03",
#    "total_calories": 781,
#    "tracking_mode": "outdoor",
#    "total_distance": 7463.43806205611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687187"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2563,
#    "start_time": "Sat, 18 Jun 2016 06:08:27",
#    "total_calories": 373,
#    "tracking_mode": "outdoor",
#    "total_distance": 4123.84686293397,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687157"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2087,
#    "start_time": "Wed, 15 Jun 2016 06:02:52",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 6129.74843199285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/807853214"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 789,
#    "start_time": "Mon, 13 Jun 2016 17:06:40",
#    "total_calories": 59,
#    "tracking_mode": "outdoor",
#    "total_distance": 615.714617224684,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806924800"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 606,
#    "start_time": "Mon, 13 Jun 2016 15:03:52",
#    "total_calories": 299,
#    "tracking_mode": "outdoor",
#    "total_distance": 549.757560743894,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806901919"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1594,
#    "start_time": "Mon, 13 Jun 2016 05:50:21",
#    "total_calories": 450,
#    "tracking_mode": "outdoor",
#    "total_distance": 5756.30000050235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806547477"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1634,
#    "start_time": "Fri, 10 Jun 2016 05:58:37",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5797.34713357958,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/804841603"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2209,
#    "start_time": "Mon, 23 May 2016 06:08:33",
#    "total_calories": 429,
#    "tracking_mode": "outdoor",
#    "total_distance": 5884.05329187354,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/793442865"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1661,
#    "start_time": "Mon, 16 May 2016 05:54:44",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5814.90671752075,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/788769831"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1862,
#    "start_time": "Sat, 14 May 2016 06:09:23",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5835.27134531731,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/787533188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Thu, 5 May 2016 05:43:14",
#    "total_calories": 453,
#    "tracking_mode": "outdoor",
#    "total_distance": 5786.59705963899,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/781785039"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1812,
#    "start_time": "Tue, 3 May 2016 05:49:35",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5887.67166192717,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/780351088"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1837,
#    "start_time": "Wed, 20 Apr 2016 05:51:15",
#    "total_calories": 456,
#    "tracking_mode": "outdoor",
#    "total_distance": 5734.59075257851,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/772361130"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 450,
#    "start_time": "Mon, 18 Apr 2016 06:19:21",
#    "total_calories": 63,
#    "tracking_mode": "outdoor",
#    "total_distance": 1047.1593087184,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943625"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1586,
#    "start_time": "Mon, 18 Apr 2016 05:50:48",
#    "total_calories": 565,
#    "tracking_mode": "outdoor",
#    "total_distance": 5782.77043463861,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943610"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1631,
#    "start_time": "Mon, 11 Apr 2016 05:23:04",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 5895.7589925569,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/766282546"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8038,
#    "start_time": "Thu, 7 Apr 2016 07:34:36",
#    "total_calories": 660,
#    "tracking_mode": "outdoor",
#    "total_distance": 3698.48518715936,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/764018100"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2365,
#    "start_time": "Tue, 29 Mar 2016 05:38:59",
#    "total_calories": 435,
#    "tracking_mode": "outdoor",
#    "total_distance": 5990.80532600518,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/759716642"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Wed, 23 Mar 2016 06:08:51",
#    "total_calories": 454,
#    "tracking_mode": "outdoor",
#    "total_distance": 5749.38159142367,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/755079850"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1682,
#    "start_time": "Mon, 21 Mar 2016 05:57:29",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5789.02666560211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753860205"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 261,
#    "start_time": "Sun, 20 Mar 2016 17:04:57",
#    "total_calories": 49,
#    "tracking_mode": "outdoor",
#    "total_distance": 779.129464701952,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753646484"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1636,
#    "start_time": "Mon, 14 Mar 2016 05:52:20",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5674.95440749925,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/749797852"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 899,
#    "start_time": "Tue, 8 Mar 2016 13:22:25",
#    "total_calories": 75,
#    "tracking_mode": "outdoor",
#    "total_distance": 1213.07733323399,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/747371294"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1692,
#    "start_time": "Mon, 7 Mar 2016 06:03:09",
#    "total_calories": 462,
#    "tracking_mode": "outdoor",
#    "total_distance": 5838.98572316034,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745796497"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3506,
#    "start_time": "Sun, 6 Mar 2016 13:53:27",
#    "total_calories": 253,
#    "tracking_mode": "outdoor",
#    "total_distance": 3927.28664301713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656183"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1567,
#    "start_time": "Sun, 6 Mar 2016 11:23:33",
#    "total_calories": 101,
#    "tracking_mode": "outdoor",
#    "total_distance": 1593.60881674515,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656175"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1821,
#    "start_time": "Thu, 3 Mar 2016 05:52:24",
#    "total_calories": 489,
#    "tracking_mode": "outdoor",
#    "total_distance": 6154.28759223911,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743736231"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2931,
#    "start_time": "Wed, 2 Mar 2016 18:26:34",
#    "total_calories": 105,
#    "tracking_mode": "outdoor",
#    "total_distance": 844.110303054361,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743518140"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1917,
#    "start_time": "Mon, 29 Feb 2016 06:05:33",
#    "total_calories": 467,
#    "tracking_mode": "outdoor",
#    "total_distance": 5805.83679757534,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742107339"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3371,
#    "start_time": "Sun, 28 Feb 2016 10:41:56",
#    "total_calories": 205,
#    "tracking_mode": "outdoor",
#    "total_distance": 3016.57855675634,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742025830"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1797,
#    "start_time": "Mon, 22 Feb 2016 06:09:37",
#    "total_calories": 366,
#    "tracking_mode": "outdoor",
#    "total_distance": 4815.5226769624,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/738351372"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1869,
#    "start_time": "Mon, 15 Feb 2016 05:55:11",
#    "total_calories": 353,
#    "tracking_mode": "outdoor",
#    "total_distance": 4555.47243393235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/734684880"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1478,
#    "start_time": "Wed, 4 Nov 2015 06:07:28",
#    "total_calories": 238,
#    "tracking_mode": "outdoor",
#    "total_distance": 3272.86475609347,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/695107893"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1390,
#    "start_time": "Tue, 27 Oct 2015 05:57:52",
#    "total_calories": 357,
#    "tracking_mode": "outdoor",
#    "total_distance": 4675.89620892755,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/682306939"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1358,
#    "start_time": "Fri, 25 Sep 2015 06:03:30",
#    "total_calories": 365,
#    "tracking_mode": "outdoor",
#    "total_distance": 4683.06656215611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/662964078"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1382,
#    "start_time": "Tue, 22 Sep 2015 06:05:45",
#    "total_calories": 361,
#    "tracking_mode": "outdoor",
#    "total_distance": 4655.54963372923,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/660961272"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1458.45,
#    "start_time": "Mon, 25 May 2015 05:40:07",
#    "total_calories": 362,
#    "tracking_mode": "outdoor",
#    "total_distance": 4703.8352331533,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/577596948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1417.324,
#    "start_time": "Thu, 30 Apr 2015 05:56:58",
#    "total_calories": 360,
#    "tracking_mode": "outdoor",
#    "total_distance": 4672.89007690554,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/559747998"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1397.167,
#    "start_time": "Wed, 22 Apr 2015 05:53:43",
#    "total_calories": 520,
#    "tracking_mode": "outdoor",
#    "total_distance": 4690.98068548032,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/554014359"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1500,
#    "start_time": "Mon, 20 Apr 2015 05:40:00",
#    "total_calories": 343,
#    "tracking_mode": "outdoor",
#    "total_distance": 4498.63606169824,
#    "entry_mode": "Web",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/553679343"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1436.981,
#    "start_time": "Sat, 15 Mar 2014 22:15:59",
#    "total_calories": 130,
#    "tracking_mode": "outdoor",
#    "total_distance": 1984.280937576,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268589"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 839.407,
#    "start_time": "Sat, 15 Mar 2014 18:25:50",
#    "total_calories": 65,
#    "tracking_mode": "outdoor",
#    "total_distance": 986.246059611153,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268582"
#   }
#  ]
# }

# %% [markdown]
# ## JSON to Data Frame conversion
#
# In order to have a better data manipulation, in the next cell we perform a conversion of importe in json format from API to pandas data frame

# %%
# Perform a conversion from JSON to Data Frame
api_df = json_normalize(api_content['items'])

# Converts the duration from seconds to minutes
api_df['duration'] = api_df['duration']/60
api_df['duration'] = api_df['duration'].round(2);

# Round the distance
api_df['total_distance'] = api_df['total_distance'].round(2);

api_df
# Out:
#      duration entry_mode has_path     source                 start_time  \
# 0       17.28        API     True  RunKeeper  Fri, 23 Jun 2017 12:40:11
# 1       19.00        API     True  RunKeeper  Fri, 23 Jun 2017 07:50:54
# 2       21.42        API     True  RunKeeper  Thu, 22 Jun 2017 12:41:16
# 3       20.58        API     True  RunKeeper  Thu, 22 Jun 2017 07:37:35
# 4       19.30        API     True  RunKeeper  Tue, 20 Jun 2017 12:35:21
# 5       19.88        API     True  RunKeeper  Tue, 20 Jun 2017 07:30:08
# 6       17.02        API     True  RunKeeper  Mon, 19 Jun 2017 12:36:20
# 7       23.08        API     True  RunKeeper  Mon, 19 Jun 2017 07:43:02
# 8       50.43        API     True  RunKeeper  Sat, 17 Jun 2017 14:47:50
# 9       18.17        API     True  RunKeeper  Wed, 14 Jun 2017 13:26:09
# 10      18.82        API     True  RunKeeper  Wed, 14 Jun 2017 07:53:31
# 11      23.17        API     True  RunKeeper  Tue, 13 Jun 2017 12:48:45
# 12      19.30        API     True  RunKeeper  Tue, 13 Jun 2017 07:42:39
# 13      16.75        API     True  RunKeeper  Mon, 12 Jun 2017 12:12:13
# 14      18.48        API     True  RunKeeper  Mon, 12 Jun 2017 07:29:08
# 15      15.23        API     True  RunKeeper   Fri, 9 Jun 2017 13:47:21
# 16      18.82        API     True  RunKeeper   Fri, 9 Jun 2017 07:58:28
# 17      17.03        API     True  RunKeeper   Thu, 8 Jun 2017 13:01:53
# 18      19.70        API     True  RunKeeper   Thu, 8 Jun 2017 07:51:49
# 19      17.13        API     True  RunKeeper   Wed, 7 Jun 2017 12:16:18
# 20      18.77        API     True  RunKeeper   Wed, 7 Jun 2017 07:55:39
# 21      16.40        API     True  RunKeeper   Tue, 6 Jun 2017 12:47:04
# 22      18.50        API     True  RunKeeper   Tue, 6 Jun 2017 07:30:32
# 23      15.82        API     True  RunKeeper   Mon, 5 Jun 2017 12:20:58
# 24      19.32        API     True  RunKeeper   Mon, 5 Jun 2017 07:28:30
# 25      35.62        API     True  RunKeeper   Fri, 2 Jun 2017 13:43:00
# 26      18.30        API     True  RunKeeper   Fri, 2 Jun 2017 07:43:33
# 27      17.70        API     True  RunKeeper   Thu, 1 Jun 2017 13:05:46
# 28      18.75        API     True  RunKeeper   Thu, 1 Jun 2017 07:43:24
# 29      17.18        API     True  RunKeeper  Wed, 31 May 2017 13:05:39
# ..        ...        ...      ...        ...                        ...
# 215     30.62        API     True  RunKeeper  Wed, 20 Apr 2016 05:51:15
# 216      7.50        API     True  RunKeeper  Mon, 18 Apr 2016 06:19:21
# 217     26.43        API     True  RunKeeper  Mon, 18 Apr 2016 05:50:48
# 218     27.18        API     True  RunKeeper  Mon, 11 Apr 2016 05:23:04
# 219    133.97        API     True  RunKeeper   Thu, 7 Apr 2016 07:34:36
# 220     39.42        API     True  RunKeeper  Tue, 29 Mar 2016 05:38:59
# 221     27.33        API     True  RunKeeper  Wed, 23 Mar 2016 06:08:51
# 222     28.03        API     True  RunKeeper  Mon, 21 Mar 2016 05:57:29
# 223      4.35        API     True  RunKeeper  Sun, 20 Mar 2016 17:04:57
# 224     27.27        API     True  RunKeeper  Mon, 14 Mar 2016 05:52:20
# 225     14.98        API     True  RunKeeper   Tue, 8 Mar 2016 13:22:25
# 226     28.20        API     True  RunKeeper   Mon, 7 Mar 2016 06:03:09
# 227     58.43        API     True  RunKeeper   Sun, 6 Mar 2016 13:53:27
# 228     26.12        API     True  RunKeeper   Sun, 6 Mar 2016 11:23:33
# 229     30.35        API     True  RunKeeper   Thu, 3 Mar 2016 05:52:24
# 230     48.85        API     True  RunKeeper   Wed, 2 Mar 2016 18:26:34
# 231     31.95        API     True  RunKeeper  Mon, 29 Feb 2016 06:05:33
# 232     56.18        API     True  RunKeeper  Sun, 28 Feb 2016 10:41:56
# 233     29.95        API     True  RunKeeper  Mon, 22 Feb 2016 06:09:37
# 234     31.15        API     True  RunKeeper  Mon, 15 Feb 2016 05:55:11
# 235     24.63        API     True  RunKeeper   Wed, 4 Nov 2015 06:07:28
# 236     23.17        API     True  RunKeeper  Tue, 27 Oct 2015 05:57:52
# 237     22.63        API     True  RunKeeper  Fri, 25 Sep 2015 06:03:30
# 238     23.03        API     True  RunKeeper  Tue, 22 Sep 2015 06:05:45
# 239     24.31        API     True  RunKeeper  Mon, 25 May 2015 05:40:07
# 240     23.62        API     True  RunKeeper  Thu, 30 Apr 2015 05:56:58
# 241     23.29        API     True  RunKeeper  Wed, 22 Apr 2015 05:53:43
# 242     25.00        Web     True  RunKeeper  Mon, 20 Apr 2015 05:40:00
# 243     23.95        API     True  RunKeeper  Sat, 15 Mar 2014 22:15:59
# 244     13.99        API     True  RunKeeper  Sat, 15 Mar 2014 18:25:50
#
#      total_calories  total_distance tracking_mode     type  \
# 0               148         5345.75       outdoor  Cycling
# 1               143         6081.16       outdoor  Cycling
# 2               184         6589.62       outdoor  Cycling
# 3               147         6162.94       outdoor  Cycling
# 4               156         5382.67       outdoor  Cycling
# 5               144         6086.99       outdoor  Cycling
# 6               141         5389.12       outdoor  Cycling
# 7               156         6143.74       outdoor  Cycling
# 8               310         8859.43       outdoor  Cycling
# 9               153         5753.60       outdoor  Cycling
# 10              144         6045.11       outdoor  Cycling
# 11              189         6607.60       outdoor  Cycling
# 12              150         6090.69       outdoor  Cycling
# 13              166         5779.66       outdoor  Cycling
# 14              145         6114.83       outdoor  Cycling
# 15              164         5766.43       outdoor  Cycling
# 16              144         6105.27       outdoor  Cycling
# 17              163         5783.29       outdoor  Cycling
# 18              145         6181.86       outdoor  Cycling
# 19              154         5759.41       outdoor  Cycling
# 20              141         6096.46       outdoor  Cycling
# 21              157         5978.89       outdoor  Cycling
# 22              142         6111.35       outdoor  Cycling
# 23              157         5711.36       outdoor  Cycling
# 24              143         6073.79       outdoor  Cycling
# 25              351        10489.03       outdoor  Cycling
# 26              143         6063.58       outdoor  Cycling
# 27              145         5378.71       outdoor  Cycling
# 28              142         6095.87       outdoor  Cycling
# 29              144         5392.26       outdoor  Cycling
# ..              ...             ...           ...      ...
# 215             456         5734.59       outdoor  Running
# 216              63         1047.16       outdoor  Running
# 217             565         5782.77       outdoor  Running
# 218             458         5895.76       outdoor  Running
# 219             660         3698.49       outdoor  Running
# 220             435         5990.81       outdoor  Running
# 221             454         5749.38       outdoor  Running
# 222             455         5789.03       outdoor  Running
# 223              49          779.13       outdoor  Running
# 224             447         5674.95       outdoor  Running
# 225              75         1213.08       outdoor  Running
# 226             462         5838.99       outdoor  Running
# 227             253         3927.29       outdoor  Running
# 228             101         1593.61       outdoor  Running
# 229             489         6154.29       outdoor  Running
# 230             105          844.11       outdoor  Running
# 231             467         5805.84       outdoor  Running
# 232             205         3016.58       outdoor  Running
# 233             366         4815.52       outdoor  Running
# 234             353         4555.47       outdoor  Running
# 235             238         3272.86       outdoor  Running
# 236             357         4675.90       outdoor  Running
# 237             365         4683.07       outdoor  Running
# 238             361         4655.55       outdoor  Running
# 239             362         4703.84       outdoor  Running
# 240             360         4672.89       outdoor  Running
# 241             520         4690.98       outdoor  Running
# 242             343         4498.64       outdoor  Running
# 243             130         1984.28       outdoor  Running
# 244              65          986.25       outdoor  Running
#
#                                uri  utc_offset
# 0    /fitnessActivities/1005956310          -3
# 1    /fitnessActivities/1005843765          -3
# 2    /fitnessActivities/1005535586          -3
# 3    /fitnessActivities/1005303953          -3
# 4    /fitnessActivities/1004255363          -3
# 5    /fitnessActivities/1004088987          -3
# 6    /fitnessActivities/1003621881          -3
# 7    /fitnessActivities/1003493993          -3
# 8    /fitnessActivities/1002663916          -3
# 9    /fitnessActivities/1000879327          -3
# 10   /fitnessActivities/1000713723          -3
# 11   /fitnessActivities/1000444019          -3
# 12   /fitnessActivities/1000067931          -3
# 13    /fitnessActivities/999721058          -3
# 14    /fitnessActivities/999458777          -3
# 15    /fitnessActivities/997878707          -3
# 16    /fitnessActivities/997716950          -3
# 17    /fitnessActivities/997294049          -3
# 18    /fitnessActivities/997151351          -3
# 19    /fitnessActivities/996701562          -3
# 20    /fitnessActivities/996573146          -3
# 21    /fitnessActivities/996225220          -3
# 22    /fitnessActivities/995999970          -3
# 23    /fitnessActivities/995698428          -3
# 24    /fitnessActivities/995399416          -3
# 25    /fitnessActivities/993855342          -3
# 26    /fitnessActivities/993644394          -3
# 27    /fitnessActivities/993644390          -3
# 28    /fitnessActivities/993050883          -3
# 29    /fitnessActivities/992607843          -3
# ..                             ...         ...
# 215   /fitnessActivities/772361130          -3
# 216   /fitnessActivities/770943625          -3
# 217   /fitnessActivities/770943610          -3
# 218   /fitnessActivities/766282546          -3
# 219   /fitnessActivities/764018100          -3
# 220   /fitnessActivities/759716642          -3
# 221   /fitnessActivities/755079850          -3
# 222   /fitnessActivities/753860205          -3
# 223   /fitnessActivities/753646484          -3
# 224   /fitnessActivities/749797852          -3
# 225   /fitnessActivities/747371294          -3
# 226   /fitnessActivities/745796497          -3
# 227   /fitnessActivities/745656183          -3
# 228   /fitnessActivities/745656175          -3
# 229   /fitnessActivities/743736231          -3
# 230   /fitnessActivities/743518140          -3
# 231   /fitnessActivities/742107339          -3
# 232   /fitnessActivities/742025830          -3
# 233   /fitnessActivities/738351372          -3
# 234   /fitnessActivities/734684880          -3
# 235   /fitnessActivities/695107893          -2
# 236   /fitnessActivities/682306939          -2
# 237   /fitnessActivities/662964078          -3
# 238   /fitnessActivities/660961272          -3
# 239   /fitnessActivities/577596948          -3
# 240   /fitnessActivities/559747998          -3
# 241   /fitnessActivities/554014359          -3
# 242   /fitnessActivities/553679343          -3
# 243   /fitnessActivities/439268589          -3
# 244   /fitnessActivities/439268582          -3
#
# [245 rows x 11 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to visualize the data into an excel file, the cell bellow is responsible for exporting the data.

# %%
# Export the new dataSet to csv
api_df.to_csv('dataSource.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # II - Summary section
#
# #### Here in this section, we'll handle the user profile infos.

# %%
# ==========================================================
# User informations request
# ==========================================================

# Base URI
profile_URI = "http://api.runkeeper.com/profile?access_token=" + ACCESS_TOKEN

# Receive the results from API
profile_content = requests.get(profile_URI).json()

# Base URI
weight_URI = "http://api.runkeeper.com/weight?access_token=" + ACCESS_TOKEN

# Receive the results from API
weight_content = requests.get(weight_URI).json()
weight_df = json_normalize(weight_content['items'])

# ==========================================================
# Display informations
# ==========================================================
display(Markdown('# Hello, ' + str(profile_content['name']) + '!'))

# Name
if profile_content['name']:
    display(Markdown('**Your name:** ' + str(profile_content['name'])))

# Birthday
if profile_content['birthday']:
    display(Markdown('**Birthday:** ' + str(profile_content['birthday'])))
    
# Gender
if profile_content['gender']:
    display(Markdown('**Gender:** ' + str(profile_content['gender'])))

# Location
if profile_content['location']:
    display(Markdown('**Location:** ' + str(profile_content['location'])))
    
# Profile
if profile_content['profile']:
    display(Markdown('**Profile:** ' + str(profile_content['profile'])))
    
display(Markdown('<hr>'))

# ==========================================================
# Weight chart
# ==========================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

data_weight = weight_df[np.isfinite(weight_df['weight'])].reset_index()
data_weight = data_weight['weight'].sort_index(ascending=False)

# Make a line chart with the dataSet
line = Line(data=data_weight, legend="top_left", background_fill_color="#E8DDCB", 
            ylabel='Weight', tools=TOOLS, plot_width=900)

# Configure visual properties on a plot's title attribute
line.title.text = "Historical weight"
line.title.align = "center"
line.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(line)

# ==========================================================
# Body fat chart
# ==========================================================

data_fat = weight_df[np.isfinite(weight_df['fat_percent'])]
data_fat = data_fat['fat_percent']

# Make a line chart with the dataSet
line = Line(data=data_fat, legend="top_left", background_fill_color="#E8DDCB", 
            ylabel='Fat(%)', tools=TOOLS, plot_width=900)

# Configure visual properties on a plot's title attribute
line.title.text = "Historical fat %"
line.title.align = "center"
line.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(line)
# Out:
# # Hello, Igor!
# **Your name:** Igor
# **Birthday:** Sun, 26 Apr 1992 00:00:00
# **Gender:** M
# **Location:** Natal - RN, Brazil
# **Profile:** https://runkeeper.com/user/igorbrandao
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4c62b1b1-5a4f-4472-a9ee-a72ffa277645">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ede0b743-14c8-4213-aaf6-4b57b10b3141"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ede0b743-14c8-4213-aaf6-4b57b10b3141").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ede0b743-14c8-4213-aaf6-4b57b10b3141");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ede0b743-14c8-4213-aaf6-4b57b10b3141' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e9352c03-0ea2-47df-b59f-4445258b8f7a":{"roots":{"references":[{"attributes":{},"id":"f71d2e73-ae5e-4bb2-bdc0-22e292a6423e","type":"BasicTicker"},{"attributes":{"plot":{"id":"e50d1252-3e7f-4a57-8864-b2e99f18abd6","subtype":"Chart","type":"Plot"},"ticker":{"id":"fd50a89c-5272-4d93-b140-2a3930bbed14","type":"BasicTicker"}},"id":"c96e267c-6255-4a1c-9270-77343375831c","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"},{"series":"weight"}],"series":["weight","weight","weight","weight","weight","weight","weight","weight","weight"],"x_values":[8,7,6,5,4,3,2,1,0],"y_values":{"__ndarray__":"AAAAAACgU0AAAAAAAIBSQAAAAAAAAFNAAAAAAACAUkAAAAAAAGBSQAAAAAAAwFFAAAAAAABAUkAzMzMzM9NSQAAAAAAAoFJA","dtype":"float64","shape":[9]}}},"id":"7ab1894b-418b-4dce-b3a9-aae1c2e2d1a6","type":"ColumnDataSource"},{"attributes":{"axis_label":"index","formatter":{"id":"db6389e5-3066-4e23-a59c-fed3d9b91fda","type":"BasicTickFormatter"},"plot":{"id":"e50d1252-3e7f-4a57-8864-b2e99f18abd6","subtype":"Chart","type":"Plot"},"ticker":{"id":"fd50a89c-5272-4d93-b140-2a3930bbed14","type":"BasicTicker"}},"id":"394b0911-d3f7-4ae6-b91d-43392e8ec05f","type":"LinearAxis"},{"attributes":{"plot":{"id":"e50d1252-3e7f-4a57-8864-b2e99f18abd6","subtype":"Chart","type":"Plot
type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"13a887a4-ca7b-43ac-949f-f128b8236cea","type":"BoxAnnotation"},"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"be10e9e2-341e-4ce9-bcf1-b9ef377cf747","type":"BoxZoomTool"},{"attributes":{},"id":"df9af566-92ce-4ea2-9544-9f449613546f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"d8d105df-ae01-4033-8cec-4cea4ff862bb","type":"HoverTool"},{"attributes":{"axis_label":"Fat(%)","formatter":{"id":"7884502b-1e01-493f-89ed-62fc9f79c1ed","type":"BasicTickFormatter"},"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"},"ticker":{"id":"1d041048-8dca-4a3f-b7cb-c6d435b206cb","type":"BasicTicker"}},"id":"b13c07f3-3d75-4fc2-9b1c-c8b2590c6e50","type":"LinearAxis"},{"attributes":{},"id":"7884502b-1e01-493f-89ed-62fc9f79c1ed","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":14.1,"start":0.8999999999999999},"id":"8964e4d4-af06-4a9b-a116-5db24d9e3b8c","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1b719995-6d2c-4c2c-bda4-528f23e063a2","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"abf9db5d-2e1b-4c83-ae71-1a75adf29271","type":"ResizeTool"},{"attributes":{"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"035bca05-208e-4c71-91fc-15fc506a00e9","type":"CrosshairTool"},{"attributes":{"callback":null,"overlay":{"id":"1b719995-6d2c-4c2c-bda4-528f23e063a2","type":"BoxAnnotation"},"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"b831fcad-152a-4b20-a27b-57836c95207d","type":"BoxSelectTool"},{"attributes":{"items":[{"id":"6e2d7bdd-044a-4259-86ad-1bbae17b8085","type":"LegendItem"}],"location":"top_left","plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"ece89630-1d71-4fe5-a956-1b107a994909","type":"Legend"},{"attributes":{"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"}},"id":"d7c12c75-6643-4739-9458-cc77992260db","type":"ResetTool"},{"attributes":{"plot":{"id":"5128a964-1513-4f82-98f7-cb8e5d7f58a5","subtype":"Chart","type":"Plot"},"ticker":{"id":"6d9b3a30-5bd1-4e29-8b5f-398cd233c157","type":"BasicTicker"}},"id":"08e19e4f-83c4-477d-8ec2-ff12f472616a","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"be10e9e2-341e-4ce9-bcf1-b9ef377cf747","type":"BoxZoomTool"},{"id":"b831fcad-152a-4b20-a27b-57836c95207d","type":"BoxSelectTool"},{"id":"035bca05-208e-4c71-91fc-15fc506a00e9","type":"CrosshairTool"},{"id":"abf9db5d-2e1b-4c83-ae71-1a75adf29271","type":"ResizeTool"},{"id":"d8d105df-ae01-4033-8cec-4cea4ff862bb","type":"HoverTool"},{"id":"d7c12c75-6643-4739-9458-cc77992260db","type":"ResetTool"},{"id":"6404af90-bf3d-4669-ac22-369945a00d0c"," ...

# %% [markdown]
# # III - Statistic section
#
# #### Here in this section, we'll handle the statistics infos.
#
# #### The idea is to use the ***top-down analysis***, from the more generic context to the specific one

# %% [markdown]
# ## 1) Activites summary

# %%
# ==========================================================
# Display activites summary
# ==========================================================
display(Markdown('## Activites summary'))

display(Markdown('** Total activites:** ' + str(api_content['size'])))
display(Markdown('** Total duration:** ' + str("%.2f" % api_df['duration'].sum()) + ' minutes' + 
                ' or ' + str("%.0f" % (api_df['duration'].sum()/60)) + ' hours'))
display(Markdown('** Total distance:** ' + str("%.2f" % api_df['total_distance'].sum()) + ' km'))
display(Markdown('** Total calories burned:** ' + str(api_df['total_calories'].sum()) + ' kcal'))
# Out:
# ## Activites summary
# ** Total activites:** 245
# ** Total duration:** 7134.45 minutes or 119 hours
# ** Total distance:** 1280447.78 km
# ** Total calories burned:** 57597 kcal

# %% [markdown]
# ## 2) Activites overall times
#
# **[Analysis]: ** In this chart we can see the dedicated time by the user *(in hours)* for each activity type.
#
# He/she spent approximately **35 hours** running and about **25** hours for cycling.

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Make a bar chart: p
p = Bar(api_df, values='duration', label='type', agg='mean', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            plot_width=750, plot_height=500, tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity overall time'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Average time:',' @height')]

# Configure visual properties on a plot's title attribute
p.title.text = "Overall time by activity type"
p.title.align = "center"
p.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9061e2c5-4274-46aa-af56-39f2acaea1be">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="62ba0614-b47a-404d-8a6c-55b2c8dba584"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("62ba0614-b47a-404d-8a6c-55b2c8dba584").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("62ba0614-b47a-404d-8a6c-55b2c8dba584");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '62ba0614-b47a-404d-8a6c-55b2c8dba584' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6a46e399-3c3c-49f1-9e1b-0c244638932b":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","type":"Plot"},"ticker":{"id":"ea75e8c5-3238-4e6f-8aa3-9fe4bf8c0666","type":"BasicTicker"}},"id":"c6d905ef-9868-4b6c-b1fb-a09d75c21780","type":"Grid"},{"attributes":{"data_source":{"id":"419d3872-4f1f-4e24-a191-38370c44b50a","type":"ColumnDataSource"},"glyph":{"id":"377b8881-836e-4fc5-8897-303195d582fd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6df2368e-3d0b-43db-abf9-1ecedd1c82a4","type":"GlyphRenderer"},{"attributes":{},"id":"6bfd5f30-11b0-46d4-a2c9-2fbfa4c414e9","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0a8e8eaf-2a0d-420e-8070-7a18453e3fa6","type":"BoxZoomTool"},{"id":"220b08a0-3823-43d6-ac41-d0dfff4e5e60","type":"BoxSelectTool"},{"id":"083ec55c-f7f8-45f3-ad3a-ba9af0c88f94","type":"CrosshairTool"},{"id":"53c73e1d-c730-495c-b7ed-75f880281b59","type":"ResizeTool"},{"id":"eacd94be-e92d-4c79-a431-22752da535d0","type":"ResetTool"},{"id":"4773c908-d3fa-4750-b73f-1c679b01b410","type":"HoverTool"},{"id":"aed2d73b-d5e1-4b7e-871d-29d6889fe9bd","type":"SaveTool"}]},"id":"9dfdf4d5-a63f-4c17-9f8b-79aa9affdccf","type":"Toolbar"},{"attributes":{"align":"center","plot":null,"text":"Overall time by activity type","text_font_size":{"value":"25px"}},"id":"330bf0f2-26ce-4c25-8c30-45dc9f586cb3","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9fda7175-56a2-441e-8188-db87aa619f70","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","type":"Plot"}},"id":"083ec55c-f7f8-45f3-ad3a-ba9af0c88f94","type":"CrosshairTool"},{"attributes":{"axis_label":"Activity overall time","formatter":{"id":"dac6a567-6bab-4f28-ae51-e3d3fc203c88","type":"BasicTickFormatter"},"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","type":"Plot"},"ticker":{"id":"ea75e8c5-3238-4e6f-8aa3-9fe4bf8c0666","type":"BasicTicker"}},"id":"541c78d1-e930-425b-beee-34b970fb6e93","type":"LinearAxis"},{"attributes":{"label":{"value":"Running"},"renderers":[{"id":"6df2368e-3d0b-43db-abf9-1ecedd1c82a4","type":"GlyphRenderer"}]},"id":"1835db15-2821-4d92-b137-d66fce16dfa1","type":"LegendItem"},{"attributes":{},"id":"ea75e8c5-3238-4e6f-8aa3-9fe4bf8c0666","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Running"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[34.752777777777766],"label":[{"type":"Running"}],"line_alpha":[1.0],"line_color":["white"],"type":["Running"],"width":[0.8],"x":["Running"],"y":[17.376388888888883]}},"id":"419d3872-4f1f-4e24-a191-38370c44b50a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","type":"Plot"}},"id":"eacd94be-e92d-4c79-a431-22752da535d0","type":"ResetTool"},{"attributes":{"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","type":"Plot"}},"id":"53c73e1d-c730-495c-b7ed-75f880281b59","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"69efa666-1506-4516-a6fe-3fc040b27e54","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"64561477-5e5a-424a-b8e2-c95b3f43d667","subtype":"Chart","typ ...

# %% [markdown]
# ## 3) Activites calories burning
#
# **[Analysis]:** In this chart, we can see that the user spends **more calories running than cycling**.
#
# Besides that, through the bar chart we can see the total calories burned summing. In this case the user burnt about ***33 thousand calories with running against 25000 with cycling***.
#
# The boxplot chart presents the difference between running and cycling activities in terms of calories use, where **running activities burnt more calories than cycling**.

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

# Make a bar chart: p
bar = Bar(api_df, values='total_calories', label='type', agg='sum', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Make a box plot: unit 1
box = BoxPlot(api_df, values='total_calories', label='type', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity total calories'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Total calories:',' @height')]

# Configure visual properties on a plot's title attribute
bar.title.text = "Total calories burned by activity type"
bar.title.align = "center"
bar.title.text_font_size = "25px"

box.title.text = "Total calories burned by activity type"
box.title.align = "center"
box.title.text_font_size = "25px"

# Create a list containing plots
row1 = [bar,box]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1],sizing_mode='scale_width', plot_height=750)

# Call the output_notebook() 
output_notebook()
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="03192060-125f-4ce5-b524-bb09830a10a3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a69b4441-68b6-4b4c-bdb0-aeb2d6917235"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a69b4441-68b6-4b4c-bdb0-aeb2d6917235").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a69b4441-68b6-4b4c-bdb0-aeb2d6917235");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a69b4441-68b6-4b4c-bdb0-aeb2d6917235' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"229dbdb1-3294-4f34-8463-58273f70587c":{"roots":{"references":[{"attributes":{"axis_label":"Type","formatter":{"id":"89e001ac-7709-41ea-9716-5c26861bff5e","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":
}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[24942.0],"label":[{"type":"Cycling"}],"line_alpha":[1.0],"line_color":["white"],"type":["Cycling"],"width":[0.8],"x":["Cycling"],"y":[12471.0]}},"id":"c73f2ea4-de5a-448d-b88e-c20f55f74df7","typ ...

# %% [markdown]
# ## 4) Activites by period
#
# First of all we need to split the information by period. To achieve that, the idea is apply a group selection by partial string in timestamp column

# %% [markdown]
# ## Timestamp split into columns
#
# In order to have a better way to handle the data by period, it'll be necessary split the timestamp column into separate columns

# %%
# =================================================================================
# Dataframe timestamp split
# =================================================================================

# Copy the data
data_by_period = api_df.copy()
data_by_period["month"] = 0
data_by_period["month_index"] = 0
data_by_period["year"] = 0

# Fill the years
data_by_period.loc[data_by_period['start_time'].str.contains('2017'), 'year'] = '2017'
data_by_period.loc[data_by_period['start_time'].str.contains('2016'), 'year'] = '2016'
data_by_period.loc[data_by_period['start_time'].str.contains('2015'), 'year'] = '2015'
data_by_period.loc[data_by_period['start_time'].str.contains('2014'), 'year'] = '2014'

# Fill the months
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month'] = 'Jan'
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month_index'] = '1'

data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month'] = 'Feb'
data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month_index'] = '2'

data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month'] = 'Mar'
data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month_index'] = '3'

data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month'] = 'Apr'
data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month_index'] = '4'

data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month'] = 'May'
data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month_index'] = '5'

data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month'] = 'Jun'
data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month_index'] = '6'

data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month'] = 'Jul'
data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month_index'] = '7'

data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month'] = 'Aug'
data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month_index'] = '8'

data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month'] = 'Sep'
data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month_index'] = '9'

data_by_period.loc[data_by_period['start_time'].str.contains('Oct-'), 'month'] = 'Oct'
data_by_period.loc[data_by_period['start_time'].str.contains('Oct'), 'month_index'] = '10'

data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month'] = 'Nov'
data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month_index'] = '11'

data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month'] = 'Dec'
data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month_index'] = '12'

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid replacing the timestamp to other columns, we'll export the new dataSet to a csv file. You can skip this operation because the new .csv dataSet is already included in the project

# %%
# Export the new dataSet to csv
data_by_period.to_csv('dataSourceByPeriod.csv', encoding="utf-8")

# %% [markdown]
# ## All years overview

# %%
# =================================================================================
# Data import
# =================================================================================

# Import the fertility.csv data: data
data_by_period = pd.read_csv("dataSourceByPeriod.csv", encoding = 'latin2')

# =================================================================================
# Year selection
# =================================================================================

yearList = data_by_period.year.unique()

for idx, val in enumerate(yearList):

    # =================================================================================
    # Data selection
    # =================================================================================

    year = val

    # Filter the activities by year
    activitiesYear = data_by_period[data_by_period["year"] == year].sort_values('month_index')

    # =================================================================================
    # Data count
    # =================================================================================

    # Do some fix in disciplineStatus
    activityType = activitiesYear.copy()
    activityType["Count"] = 0

    # Count the status sum-up
    activityType = pd.DataFrame(activityType.groupby(["type"])['Count'].count()).reset_index()

    # =================================================================================
    # Chart plotting
    # =================================================================================

    # Tools
    TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

    barMonth = Bar(activitiesYear, values='total_distance', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barCaloryMonth = Bar(activitiesYear, values='total_calories', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barDurationMonth = Bar(activitiesYear, values='duration', label=CatAttr(columns=['month'], sort=False), color='month', agg='mean', 
                          legend='top_left', tools=TOOLS)

    # Donut chart settings
    donutType = Donut(activityType, label=['type', 'Count'], values='Count',
              text_font_size='14pt', legend='top_left', 
              tools=TOOLS, background_fill_color="#E8DDCB", title='Discipline status', 
              color='type')

    # Set the y and x axis label
    barMonth.yaxis.axis_label= 'Total distance'
    barMonth.xaxis.axis_label= 'Month'

    barCaloryMonth.yaxis.axis_label= 'Total calories'
    barCaloryMonth.xaxis.axis_label= 'Month'

    barDurationMonth.yaxis.axis_label= 'Total duration'
    barDurationMonth.xaxis.axis_label= 'Month'

    # Set hover to bars
    hover = barMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total distance:',' @height')]

    hover = barCaloryMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = barDurationMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = donutType.select(dict(type=HoverTool))
    hover.tooltips = [('Activity', '@x'),('Count:',' @height')]

    # Configure visual properties on a plot's title attribute
    barMonth.title.text = "Total distance by month in " + str(year)
    barMonth.title.align = "center"
    barMonth.title.text_font_size = "25px"

    barCaloryMonth.title.text = "Total calories by month in " + str(year)
    barCaloryMonth.title.align = "center"
    barCaloryMonth.title.text_font_size = "25px"

    barDurationMonth.title.text = "Average duration by month in " + str(year)
    barDurationMonth.title.align = "center"
    barDurationMonth.title.text_font_size = "25px"

    donutType.title.text = "Activities types in " + str(year)
    donutType.title.align = "center"
    donutType.title.text_font_size = "25px"

    # Create a list containing plots
    row1 = [barMonth, barCaloryMonth]
    row2 = [barDurationMonth, donutType]

    # Create a gridplot using row1 and row2: layout
    layout = gridplot([row1, row2],sizing_mode='scale_width', plot_height=650, plot_width=900)

    # Call the output_notebook()
    display(Markdown('# Activities overview in ' + str(year)))
    display(Markdown('<hr>'))

    output_notebook()
    show(layout)
# Out:
# # Activities overview in 2017
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4b5d9bc2-359a-4b15-92ec-4c86d5f2dbde","type":"BoxZoomTool"},{"id":"5655f53e-2f99-4a98-ae36-a08676c686cd","type":"BoxSelectTool"},{"id":"0d2217c4-eac5-4dd5-8418-96f41ff53ff9","type":"CrosshairTool"},{"id":"9ab17127-0943-4ff1-b6ae-bf48c033cf1b","type":"ResizeTool"},{"id":"045e6073-067c-4544-be5c-5e3857a5c124","type":"HoverTool"},{"id":"da4d84c1-dbcc-44c1-b495-8d1ae96acd23","type":"ResetTool"},{"id":"423f4df6-fb7c-44c7-a2e1-f5793571d9fa","type":"SaveTool"}]},"id":"91ccc160-0ce3-46df-bad0-87e78ecd7318","type":"Toolbar"},{"attributes":{"overlay":{"id":"e0a97b27-9f55-4b9d-812d-116ce9586558","type":"BoxAnnotation"},"plot":{"id":"5e3a5ded-e0e4-4b92-ab0c-8987c69ddf57","subtype":"Chart","type":"Plot"}},"id":"4b5d9 ...

# %% [markdown]
# # IV - Geolocation section
#
# #### Here in this section, we'll handle the geolocation infos.

# %% [markdown]
# ## Location import [warning: too heavy]
#
# The cell below perform multiple requests to Runkeep Health Graph API, in order to retrieve all activities in details to get location informations such as: latitude/longitude

# %%
# =================================================================================
# Geolocation data
# =================================================================================

# Copy the data
geolocation_data = pd.DataFrame()

# =================================================================================
# API single activity request
# =================================================================================

# Base URI
base_URI = "http://api.runkeeper.com"

limit = 2

# Run through all activites
for idx, row in tqdm(api_df.iterrows()):
    
    # Final activity URI
    activity_url = base_URI + row['uri'] + "?access_token=" + ACCESS_TOKEN

    # Receive the results from API
    activity_content = requests.get(activity_url).json()

    # Perform a conversion from JSON to Data Frame
    activity_df = json_normalize(activity_content['path'])
    
    # Add the activity path data to geolocation
    geolocation_data = pd.concat([geolocation_data, activity_df])
    
geolocation_data

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid processing the cell above, here we are saving the processed geolocationd data.

# %%
# Export the new dataSet to csv
geolocation_data.to_csv('geolocation.csv', encoding="utf-8")

# %% [markdown]
# ## Geolocation data import [optional]

# %%
# Import the fertility.csv data: data
geolocation_data = pd.read_csv("geolocation.csv", encoding = 'latin2')

# %% [markdown]
# ## 1) Heatmap

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Heatmap generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.ix[i,'latitude'], geodata.ix[i,'longitude'], geodata.ix[i,'count']])):
        coordinates.append([geodata.ix[i,'latitude'], geodata.ix[i,'longitude'], geodata.ix[i,'count']])

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Print the heatMap
htMap

# %% [markdown]
# ## 2) Map markers

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Map markers generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# For speed purposes
MAX_RECORDS = 100

# Create map object
map_activities = folium.Map(location=mapc, zoom_start=zoom)

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    
    if i == MAX_RECORDS:
        break;
    
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.ix[i,'latitude'], geodata.ix[i,'longitude']])):
        folium.Marker(location = [geodata.ix[i,'latitude'],geodata.ix[i,'longitude']]).add_to(map_activities)

# Show the map
map_activities

# %% [markdown]
# # V - Web scraping section
#
# #### Here in this section, we'll try to get user friends informations.

# %% [markdown]
# ## Web scraping functions

# %%
# Return an soup Object
def getSoup(url):
    try:
        html = requests.get(url)
    except HTTPError as e:
        return None
    try:
        soup = BeautifulSoup(html.content, 'html.parser')
    except AttributeError as e:
        return None
    return soup

# %%
# Remove the dirty part from link
def getLink(url, dirty):
    result = url.split(dirty)
    return result[0]

# %% [markdown]
# ## Web scraping flow starts here
#
# This cell'll provide the user and its friends basic stats such as: [total activities, total distance and total calories burned]

# %%
# Profile
if profile_content:

    # =================================================================================
    # Web scraping
    # =================================================================================
    
    # Get the content from user profile
    soup = getSoup(profile_content['profile'] + '/friends')
    
    # Array with users URI
    friends_URI = []
    friends_name = []
    
    # Get the friends ID
    for item in soup.findAll(class_='usernameLinkNoSpace user-name'):
        
        # Check if it's a link
        if 'href' in item.attrs:
                
            # Check if the link URI has a specifc string
            if '/user/' in str(item.attrs):

                # Append the link URI
                friends_URI.append(item.attrs['href'])
                
                # Append the friend name
                friends_name.append(item.text.strip(' \t\n\r'))
                
    # Friends info array
    friends = []
    temp = []
    
    # Run through friends profile URI array
    for idx, val in enumerate(friends_URI):
    
        # Get the content from profile friends page
        friend_uri = 'https://runkeeper.com' + val
        soup_friend = getSoup(friend_uri)
        
        # Get the friends ID
        for item in soup_friend.findAll('div', id='statsSection'):
            
            if item:

                # Get the stats
                for subitem in item.findAll(class_='statValue'):
                    
                    # Add the stats to a temporary array
                    if subitem.text.strip():
                        temp.append(subitem.text.strip(' \t\n\r'))
                        
                break;
                    
        # Add the stats to friends array
        friends.append(temp)
        temp = []
    
else:
    print('No data available')

# %%
# =================================================================================
# Data presentation
# =================================================================================

display(Markdown('# Friends activites summary'))

# Run through friends information
for idx, val in enumerate(friends_name):

    display(Markdown('#  ' + val))
    display(Markdown('**Total activities:** ' + friends[idx][0]))
    display(Markdown('**Total distance:** ' + friends[idx][1] + ' km'))
    display(Markdown('**Total calories burned:** ' + friends[idx][2] + ' kcal'))
# Out:
# # Friends activites summary
# #  Igor
# **Total activities:** 245
# **Total distance:** 1280.45 km
# **Total calories burned:** 57597 kcal
# #  Leandro Max
# **Total activities:** 14
# **Total distance:** 31.17 km
# **Total calories burned:** 2486 kcal
# #  Ivan Alisson
# **Total activities:** 24
# **Total distance:** 85.96 km
# **Total calories burned:** 5304 kcal
# #  Diego BrandĂŁo
# **Total activities:** 2
# **Total distance:** 8.81 km
# **Total calories burned:** 653 kcal
