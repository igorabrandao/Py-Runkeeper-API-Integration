# %% [markdown]
# # Programming Project - Unit 3,3
# *by Igor A. Brandão and Leandro Antonio Feliciano da Silva*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Full content of the statistical part seen in the course;
# - Graphs generation;
# - Geolocation analysis and hypotheses should be explained in detail;
# - Web scraping.

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Bokeh charts;
# - Numpy library;
# - Tqdm progress bar
# - Requests;
# - urlopen;
# - HTTPError;
# - BeautifulSoup
# - Regular expression

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: geocoder in c:\anac3\lib\site-packages
# Requirement already satisfied: six in c:\anac3\lib\site-packages (from geocoder)
# Requirement already satisfied: requests in c:\anac3\lib\site-packages (from geocoder)
# Requirement already satisfied: ratelim in c:\anac3\lib\site-packages (from geocoder)
# Requirement already satisfied: click in c:\anac3\lib\site-packages (from geocoder)
# Requirement already satisfied: decorator in c:\anac3\lib\site-packages (from ratelim->geocoder)
# Requirement already satisfied: folium in c:\anac3\lib\site-packages
# Requirement already satisfied: six in c:\anac3\lib\site-packages (from folium)
# Requirement already satisfied: branca in c:\anac3\lib\site-packages (from folium)
# Requirement already satisfied: Jinja2 in c:\anac3\lib\site-packages (from folium)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anac3\lib\site-packages (from Jinja2->folium)
# Requirement already satisfied: tqdm in c:\anac3\lib\site-packages
# Requirement already satisfied: tabulate in c:\anac3\lib\site-packages
# Requirement already satisfied: pandas-datareader in c:\anac3\lib\site-packages
# Requirement already satisfied: requests-ftp in c:\anac3\lib\site-packages (from pandas-datareader)
# Requirement already satisfied: requests>=2.3.0 in c:\anac3\lib\site-packages (from pandas-datareader)
# Requirement already satisfied: requests-file in c:\anac3\lib\site-packages (from pandas-datareader)
# Requirement already satisfied: pandas in c:\anac3\lib\site-packages (from pandas-datareader)
# Requirement already satisfied: six in c:\anac3\lib\site-packages (from requests-file->pandas-datareader)
# Requirement already satisfied: python-dateutil>=2 in c:\anac3\lib\site-packages (from pandas->pandas-datareader)
# Requirement already satisfied: pytz>=2011k in c:\anac3\lib\site-packages (from pandas->pandas-datareader)
# Requirement already satisfied: numpy>=1.7.0 in c:\anac3\lib\site-packages (from pandas->pandas-datareader)

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium heatmap
import folium
from folium.plugins import HeatMap

# Import tqdm progressing bar plugin
from tqdm import tqdm

# Import bokeh libraries
from bokeh.plotting import figure
from bokeh.charts import Bar, Histogram, Donut, BoxPlot, Line, output_notebook, show
from bokeh.layouts import row, gridplot, column
from bokeh.models import HoverTool
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.models import HoverTool
from bokeh.charts.attributes import AttrSpec, ColorAttr, MarkerAttr, CatAttr
from bokeh.plotting import ColumnDataSource

# Import request libraries
from urllib.request import Request, urlopen
from urllib.error import HTTPError

# Import web scraping libraries
from bs4 import BeautifulSoup
import re # regular expression

# Import API libraries
import requests
import json
from pandas.io.json import json_normalize

# Imports to output the result as a Markdown
from IPython.display import display, Markdown
from tabulate import tabulate

# %% [markdown]
# <hr>

# %% [markdown]
# # I - API section
#
# ## API data retrieving
#
# #### In the cell bellow, we perform a connection with Health Graph API - Runkeeper.

# %%
# Access token
ACCESS_TOKEN = '25bc30d6dd6f4b99bbeb48e8619103b4'

# Base URI
api_URI = "http://api.runkeeper.com/fitnessActivities"

# Number of results
pageSize = 300

# Final URI
url = '%s?pageSize=%s&access_token=%s' % \
    (api_URI, pageSize, ACCESS_TOKEN,)

# print(url)

# Receive the results from API
api_content = requests.get(url).json()

print(json.dumps(api_content, indent=1))
# Out:
# {
#  "size": 246,
#  "items": [
#   {
#    "utc_offset": -3,
#    "duration": 1319,
#    "start_time": "Mon, 26 Jun 2017 07:41:03",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6112.76566998993,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1007493795"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1037,
#    "start_time": "Fri, 23 Jun 2017 12:40:11",
#    "total_calories": 148,
#    "tracking_mode": "outdoor",
#    "total_distance": 5345.75479639154,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005956310"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1140,
#    "start_time": "Fri, 23 Jun 2017 07:50:54",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6081.16390011933,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005843765"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1285,
#    "start_time": "Thu, 22 Jun 2017 12:41:16",
#    "total_calories": 184,
#    "tracking_mode": "outdoor",
#    "total_distance": 6589.61628038915,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005535586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1235,
#    "start_time": "Thu, 22 Jun 2017 07:37:35",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6162.94434876089,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005303953"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1158,
#    "start_time": "Tue, 20 Jun 2017 12:35:21",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 5382.67114549159,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004255363"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1193,
#    "start_time": "Tue, 20 Jun 2017 07:30:08",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6086.98681262211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004088987"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1021,
#    "start_time": "Mon, 19 Jun 2017 12:36:20",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5389.11505599285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1003621881"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1385,
#    "start_time": "Mon, 19 Jun 2017 07:43:02",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 6143.73512742271,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1003493993"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3026,
#    "start_time": "Sat, 17 Jun 2017 14:47:50",
#    "total_calories": 310,
#    "tracking_mode": "outdoor",
#    "total_distance": 8859.43226805176,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1002663916"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1090,
#    "start_time": "Wed, 14 Jun 2017 13:26:09",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5753.59760001431,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000879327"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1129,
#    "start_time": "Wed, 14 Jun 2017 07:53:31",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6045.10626534744,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000713723"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1390,
#    "start_time": "Tue, 13 Jun 2017 12:48:45",
#    "total_calories": 189,
#    "tracking_mode": "outdoor",
#    "total_distance": 6607.60352123956,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/

#   },
#   {
#    "utc_offset": -3,
#    "duration": 1031,
#    "start_time": "Wed, 31 May 2017 13:05:39",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 5392.25543387091,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/992607843"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1056,
#    "start_time": "Wed, 31 May 2017 07:46:06",
#    "total_calories": 139,
#    "tracking_mode": "outdoor",
#    "total_distance": 6063.0725208611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/992431836"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1069,
#    "start_time": "Tue, 30 May 2017 12:53:08",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 5400.76576414881,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991962764"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1211,
#    "start_time": "Tue, 30 May 2017 07:39:01",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 6109.72501667069,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991820391"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1074,
#    "start_time": "Mon, 29 May 2017 12:20:50",
#    "total_calories": 157,
#    "tracking_mode": "outdoor",
#    "total_distance": 5775.48218009307,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991365627"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1131,
#    "start_time": "Mon, 29 May 2017 07:26:13",
#    "total_calories": 138,
#    "tracking_mode": "outdoor",
#    "total_distance": 6099.26870387646,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991169558"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 591,
#    "start_time": "Sat, 27 May 2017 19:08:21",
#    "total_calories": 67,
#    "tracking_mode": "outdoor",
#    "total_distance": 1985.59809947508,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/990327649"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 973,
#    "start_time": "Fri, 26 May 2017 13:17:12",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 5410.65388208804,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989611023"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1319,
#    "start_time": "Fri, 26 May 2017 07:51:10",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6065.57169437408,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989441355"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1252,
#    "start_time": "Thu, 25 May 2017 12:27:02",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5704.26981685631,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989057824"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1269,
#    "start_time": "Thu, 25 May 2017 07:45:48",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6113.02788518738,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988912391"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 999,
#    "start_time": "Wed, 24 May 2017 13:28:54",
#    "total_calories": 154,
#    "tracking_mode": "outdoor",
#    "total_distance": 5434.65276040979,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988482373"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1094,
#    "start_time": "Wed, 24 May 2017 07:46:28",
#    "total_calories": 142,
#    "tracking_mode": "outdoor",
#    "total_distance": 6097.58289751998,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988314136"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 956,
#    "start_time": "Tue, 23 May 2017 13:04:33",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5445.85348275805,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987853465"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1128,
#    "start_time": "Tue, 23 May 2017 07:52:58",
#    "total_calories": 139,
#    "tracking_mode": "outdoor",
#    "total_distance": 6107.04559950437,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987694354"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1111,
#    "start_time": "Mon, 22 May 2017 12:11:33",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 5787.55896118107,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987202459"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1232,
#    "start_time": "Mon, 22 May 2017 07:45:33",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6170.41363482883,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987043645"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 7848,
#    "start_time": "Sun, 21 May 2017 09:03:56",
#    "total_calories": 1065,
#    "tracking_mode": "outdoor",
#    "total_distance": 40466.6970482901,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/986599297"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1115,
#    "start_time": "Fri, 19 May 2017 12:40:16",
#    "total_calories": 163,
#    "tracking_mode": "outdoor",
#    "total_distance": 5751.74859031716,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/985427280"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1093,
#    "start_time": "Fri, 19 May 2017 07:42:15",
#    "total_calories": 135,
#    "tracking_mode": "outdoor",
#    "total_distance": 6120.64413572644,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/985287008"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1102,
#    "start_time": "Thu, 18 May 2017 13:27:24",
#    "total_calories": 168,
#    "tracking_mode": "outdoor",
#    "total_distance": 5833.48101763434,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984890548"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1263,
#    "start_time": "Thu, 18 May 2017 07:30:12",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6102.21516145924,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984721244"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1010,
#    "start_time": "Wed, 17 May 2017 13:31:55",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5816.76723063048,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984721232"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1094,
#    "start_time": "Wed, 17 May 2017 07:20:05",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6158.04864716445,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984092295"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 999,
#    "start_time": "Tue, 16 May 2017 13:56:29",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 5399.93032230139,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/983704882"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1732,
#    "start_time": "Tue, 16 May 2017 08:47:10",
#    "total_calories": 197,
#    "tracking_mode": "outdoor",
#    "total_distance": 5560.4563963911,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/983486533"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1145,
#    "start_time": "Mon, 15 May 2017 12:12:42",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5799.03624628713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/982953586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1157,
#    "start_time": "Mon, 15 May 2017 07:40:40",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6146.10443694347,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/982791179"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 997,
#    "start_time": "Fri, 12 May 2017 13:15:44",
#    "total_calories": 159,
#    "tracking_mode": "outdoor",
#    "total_distance": 5844.7428641494,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/981236810"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1181,
#    "start_time": "Fri, 12 May 2017 07:33:09",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6080.95116871364,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/981074411"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1081,
#    "start_time": "Thu, 11 May 2017 12:17:38",
#    "total_calories": 163,
#    "tracking_mode": "outdoor",
#    "total_distance": 5729.95729085945,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/980742720"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1106,
#    "start_time": "Thu, 11 May 2017 07:34:52",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6008.50511794807,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/980533500"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2369,
#    "start_time": "Tue, 9 May 2017 13:37:33",
#    "total_calories": 203,
#    "tracking_mode": "outdoor",
#    "total_distance": 5970.05867350263,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/979587799"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2037,
#    "start_time": "Tue, 9 May 2017 07:18:08",
#    "total_calories": 193,
#    "tracking_mode": "outdoor",
#    "total_distance": 6190.0199079668,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/979308286"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1089,
#    "start_time": "Thu, 4 May 2017 12:13:05",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 5761.69009138035,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/976665485"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1255,
#    "start_time": "Thu, 4 May 2017 07:29:09",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6188.70012124096,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/976345577"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1124,
#    "start_time": "Wed, 3 May 2017 12:20:03",
#    "total_calories": 170,
#    "tracking_mode": "outdoor",
#    "total_distance": 5784.50584486548,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities

#   },
#   {
#    "utc_offset": -3,
#    "duration": 2563,
#    "start_time": "Sat, 18 Jun 2016 06:08:27",
#    "total_calories": 373,
#    "tracking_mode": "outdoor",
#    "total_distance": 4123.84686293397,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687157"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2087,
#    "start_time": "Wed, 15 Jun 2016 06:02:52",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 6129.74843199285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/807853214"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 789,
#    "start_time": "Mon, 13 Jun 2016 17:06:40",
#    "total_calories": 59,
#    "tracking_mode": "outdoor",
#    "total_distance": 615.714617224684,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806924800"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 606,
#    "start_time": "Mon, 13 Jun 2016 15:03:52",
#    "total_calories": 299,
#    "tracking_mode": "outdoor",
#    "total_distance": 549.757560743894,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806901919"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1594,
#    "start_time": "Mon, 13 Jun 2016 05:50:21",
#    "total_calories": 450,
#    "tracking_mode": "outdoor",
#    "total_distance": 5756.30000050235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806547477"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1634,
#    "start_time": "Fri, 10 Jun 2016 05:58:37",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5797.34713357958,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/804841603"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2209,
#    "start_time": "Mon, 23 May 2016 06:08:33",
#    "total_calories": 429,
#    "tracking_mode": "outdoor",
#    "total_distance": 5884.05329187354,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/793442865"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1661,
#    "start_time": "Mon, 16 May 2016 05:54:44",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5814.90671752075,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/788769831"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1862,
#    "start_time": "Sat, 14 May 2016 06:09:23",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5835.27134531731,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/787533188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Thu, 5 May 2016 05:43:14",
#    "total_calories": 453,
#    "tracking_mode": "outdoor",
#    "total_distance": 5786.59705963899,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/781785039"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1812,
#    "start_time": "Tue, 3 May 2016 05:49:35",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5887.67166192717,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/780351088"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1837,
#    "start_time": "Wed, 20 Apr 2016 05:51:15",
#    "total_calories": 456,
#    "tracking_mode": "outdoor",
#    "total_distance": 5734.59075257851,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/772361130"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 450,
#    "start_time": "Mon, 18 Apr 2016 06:19:21",
#    "total_calories": 63,
#    "tracking_mode": "outdoor",
#    "total_distance": 1047.1593087184,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943625"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1586,
#    "start_time": "Mon, 18 Apr 2016 05:50:48",
#    "total_calories": 565,
#    "tracking_mode": "outdoor",
#    "total_distance": 5782.77043463861,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943610"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1631,
#    "start_time": "Mon, 11 Apr 2016 05:23:04",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 5895.7589925569,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/766282546"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8038,
#    "start_time": "Thu, 7 Apr 2016 07:34:36",
#    "total_calories": 660,
#    "tracking_mode": "outdoor",
#    "total_distance": 3698.48518715936,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/764018100"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2365,
#    "start_time": "Tue, 29 Mar 2016 05:38:59",
#    "total_calories": 435,
#    "tracking_mode": "outdoor",
#    "total_distance": 5990.80532600518,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/759716642"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Wed, 23 Mar 2016 06:08:51",
#    "total_calories": 454,
#    "tracking_mode": "outdoor",
#    "total_distance": 5749.38159142367,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/755079850"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1682,
#    "start_time": "Mon, 21 Mar 2016 05:57:29",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5789.02666560211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753860205"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 261,
#    "start_time": "Sun, 20 Mar 2016 17:04:57",
#    "total_calories": 49,
#    "tracking_mode": "outdoor",
#    "total_distance": 779.129464701952,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753646484"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1636,
#    "start_time": "Mon, 14 Mar 2016 05:52:20",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5674.95440749925,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/749797852"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 899,
#    "start_time": "Tue, 8 Mar 2016 13:22:25",
#    "total_calories": 75,
#    "tracking_mode": "outdoor",
#    "total_distance": 1213.07733323399,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/747371294"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1692,
#    "start_time": "Mon, 7 Mar 2016 06:03:09",
#    "total_calories": 462,
#    "tracking_mode": "outdoor",
#    "total_distance": 5838.98572316034,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745796497"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3506,
#    "start_time": "Sun, 6 Mar 2016 13:53:27",
#    "total_calories": 253,
#    "tracking_mode": "outdoor",
#    "total_distance": 3927.28664301713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656183"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1567,
#    "start_time": "Sun, 6 Mar 2016 11:23:33",
#    "total_calories": 101,
#    "tracking_mode": "outdoor",
#    "total_distance": 1593.60881674515,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656175"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1821,
#    "start_time": "Thu, 3 Mar 2016 05:52:24",
#    "total_calories": 489,
#    "tracking_mode": "outdoor",
#    "total_distance": 6154.28759223911,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743736231"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2931,
#    "start_time": "Wed, 2 Mar 2016 18:26:34",
#    "total_calories": 105,
#    "tracking_mode": "outdoor",
#    "total_distance": 844.110303054361,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743518140"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1917,
#    "start_time": "Mon, 29 Feb 2016 06:05:33",
#    "total_calories": 467,
#    "tracking_mode": "outdoor",
#    "total_distance": 5805.83679757534,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742107339"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3371,
#    "start_time": "Sun, 28 Feb 2016 10:41:56",
#    "total_calories": 205,
#    "tracking_mode": "outdoor",
#    "total_distance": 3016.57855675634,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742025830"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1797,
#    "start_time": "Mon, 22 Feb 2016 06:09:37",
#    "total_calories": 366,
#    "tracking_mode": "outdoor",
#    "total_distance": 4815.5226769624,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/738351372"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1869,
#    "start_time": "Mon, 15 Feb 2016 05:55:11",
#    "total_calories": 353,
#    "tracking_mode": "outdoor",
#    "total_distance": 4555.47243393235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/734684880"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1478,
#    "start_time": "Wed, 4 Nov 2015 06:07:28",
#    "total_calories": 238,
#    "tracking_mode": "outdoor",
#    "total_distance": 3272.86475609347,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/695107893"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1390,
#    "start_time": "Tue, 27 Oct 2015 05:57:52",
#    "total_calories": 357,
#    "tracking_mode": "outdoor",
#    "total_distance": 4675.89620892755,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/682306939"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1358,
#    "start_time": "Fri, 25 Sep 2015 06:03:30",
#    "total_calories": 365,
#    "tracking_mode": "outdoor",
#    "total_distance": 4683.06656215611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/662964078"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1382,
#    "start_time": "Tue, 22 Sep 2015 06:05:45",
#    "total_calories": 361,
#    "tracking_mode": "outdoor",
#    "total_distance": 4655.54963372923,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/660961272"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1458.45,
#    "start_time": "Mon, 25 May 2015 05:40:07",
#    "total_calories": 362,
#    "tracking_mode": "outdoor",
#    "total_distance": 4703.8352331533,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/577596948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1417.324,
#    "start_time": "Thu, 30 Apr 2015 05:56:58",
#    "total_calories": 360,
#    "tracking_mode": "outdoor",
#    "total_distance": 4672.89007690554,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/559747998"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1397.167,
#    "start_time": "Wed, 22 Apr 2015 05:53:43",
#    "total_calories": 520,
#    "tracking_mode": "outdoor",
#    "total_distance": 4690.98068548032,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/554014359"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1500,
#    "start_time": "Mon, 20 Apr 2015 05:40:00",
#    "total_calories": 343,
#    "tracking_mode": "outdoor",
#    "total_distance": 4498.63606169824,
#    "entry_mode": "Web",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/553679343"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1436.981,
#    "start_time": "Sat, 15 Mar 2014 22:15:59",
#    "total_calories": 130,
#    "tracking_mode": "outdoor",
#    "total_distance": 1984.280937576,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268589"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 839.407,
#    "start_time": "Sat, 15 Mar 2014 18:25:50",
#    "total_calories": 65,
#    "tracking_mode": "outdoor",
#    "total_distance": 986.246059611153,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268582"
#   }
#  ]
# }

# %% [markdown]
# ## JSON to Data Frame conversion
#
# In order to have a better data manipulation, in the next cell we perform a conversion of importe in json format from API to pandas data frame

# %%
# Perform a conversion from JSON to Data Frame
api_df = json_normalize(api_content['items'])

# Converts the duration from seconds to minutes
api_df['duration'] = api_df['duration']/60
api_df['duration'] = api_df['duration'].round(2);

# Round the distance
api_df['total_distance'] = api_df['total_distance'].round(2);

api_df
# Out:
#      duration entry_mode has_path     source                 start_time  \
# 0       21.98        API     True  RunKeeper  Mon, 26 Jun 2017 07:41:03
# 1       17.28        API     True  RunKeeper  Fri, 23 Jun 2017 12:40:11
# 2       19.00        API     True  RunKeeper  Fri, 23 Jun 2017 07:50:54
# 3       21.42        API     True  RunKeeper  Thu, 22 Jun 2017 12:41:16
# 4       20.58        API     True  RunKeeper  Thu, 22 Jun 2017 07:37:35
# 5       19.30        API     True  RunKeeper  Tue, 20 Jun 2017 12:35:21
# 6       19.88        API     True  RunKeeper  Tue, 20 Jun 2017 07:30:08
# 7       17.02        API     True  RunKeeper  Mon, 19 Jun 2017 12:36:20
# 8       23.08        API     True  RunKeeper  Mon, 19 Jun 2017 07:43:02
# 9       50.43        API     True  RunKeeper  Sat, 17 Jun 2017 14:47:50
# 10      18.17        API     True  RunKeeper  Wed, 14 Jun 2017 13:26:09
# 11      18.82        API     True  RunKeeper  Wed, 14 Jun 2017 07:53:31
# 12      23.17        API     True  RunKeeper  Tue, 13 Jun 2017 12:48:45
# 13      19.30        API     True  RunKeeper  Tue, 13 Jun 2017 07:42:39
# 14      16.75        API     True  RunKeeper  Mon, 12 Jun 2017 12:12:13
# 15      18.48        API     True  RunKeeper  Mon, 12 Jun 2017 07:29:08
# 16      15.23        API     True  RunKeeper   Fri, 9 Jun 2017 13:47:21
# 17      18.82        API     True  RunKeeper   Fri, 9 Jun 2017 07:58:28
# 18      17.03        API     True  RunKeeper   Thu, 8 Jun 2017 13:01:53
# 19      19.70        API     True  RunKeeper   Thu, 8 Jun 2017 07:51:49
# 20      17.13        API     True  RunKeeper   Wed, 7 Jun 2017 12:16:18
# 21      18.77        API     True  RunKeeper   Wed, 7 Jun 2017 07:55:39
# 22      16.40        API     True  RunKeeper   Tue, 6 Jun 2017 12:47:04
# 23      18.50        API     True  RunKeeper   Tue, 6 Jun 2017 07:30:32
# 24      15.82        API     True  RunKeeper   Mon, 5 Jun 2017 12:20:58
# 25      19.32        API     True  RunKeeper   Mon, 5 Jun 2017 07:28:30
# 26      35.62        API     True  RunKeeper   Fri, 2 Jun 2017 13:43:00
# 27      18.30        API     True  RunKeeper   Fri, 2 Jun 2017 07:43:33
# 28      17.70        API     True  RunKeeper   Thu, 1 Jun 2017 13:05:46
# 29      18.75        API     True  RunKeeper   Thu, 1 Jun 2017 07:43:24
# ..        ...        ...      ...        ...                        ...
# 216     30.62        API     True  RunKeeper  Wed, 20 Apr 2016 05:51:15
# 217      7.50        API     True  RunKeeper  Mon, 18 Apr 2016 06:19:21
# 218     26.43        API     True  RunKeeper  Mon, 18 Apr 2016 05:50:48
# 219     27.18        API     True  RunKeeper  Mon, 11 Apr 2016 05:23:04
# 220    133.97        API     True  RunKeeper   Thu, 7 Apr 2016 07:34:36
# 221     39.42        API     True  RunKeeper  Tue, 29 Mar 2016 05:38:59
# 222     27.33        API     True  RunKeeper  Wed, 23 Mar 2016 06:08:51
# 223     28.03        API     True  RunKeeper  Mon, 21 Mar 2016 05:57:29
# 224      4.35        API     True  RunKeeper  Sun, 20 Mar 2016 17:04:57
# 225     27.27        API     True  RunKeeper  Mon, 14 Mar 2016 05:52:20
# 226     14.98        API     True  RunKeeper   Tue, 8 Mar 2016 13:22:25
# 227     28.20        API     True  RunKeeper   Mon, 7 Mar 2016 06:03:09
# 228     58.43        API     True  RunKeeper   Sun, 6 Mar 2016 13:53:27
# 229     26.12        API     True  RunKeeper   Sun, 6 Mar 2016 11:23:33
# 230     30.35        API     True  RunKeeper   Thu, 3 Mar 2016 05:52:24
# 231     48.85        API     True  RunKeeper   Wed, 2 Mar 2016 18:26:34
# 232     31.95        API     True  RunKeeper  Mon, 29 Feb 2016 06:05:33
# 233     56.18        API     True  RunKeeper  Sun, 28 Feb 2016 10:41:56
# 234     29.95        API     True  RunKeeper  Mon, 22 Feb 2016 06:09:37
# 235     31.15        API     True  RunKeeper  Mon, 15 Feb 2016 05:55:11
# 236     24.63        API     True  RunKeeper   Wed, 4 Nov 2015 06:07:28
# 237     23.17        API     True  RunKeeper  Tue, 27 Oct 2015 05:57:52
# 238     22.63        API     True  RunKeeper  Fri, 25 Sep 2015 06:03:30
# 239     23.03        API     True  RunKeeper  Tue, 22 Sep 2015 06:05:45
# 240     24.31        API     True  RunKeeper  Mon, 25 May 2015 05:40:07
# 241     23.62        API     True  RunKeeper  Thu, 30 Apr 2015 05:56:58
# 242     23.29        API     True  RunKeeper  Wed, 22 Apr 2015 05:53:43
# 243     25.00        Web     True  RunKeeper  Mon, 20 Apr 2015 05:40:00
# 244     23.95        API     True  RunKeeper  Sat, 15 Mar 2014 22:15:59
# 245     13.99        API     True  RunKeeper  Sat, 15 Mar 2014 18:25:50
#
#      total_calories  total_distance tracking_mode     type  \
# 0               145         6112.77       outdoor  Cycling
# 1               148         5345.75       outdoor  Cycling
# 2               143         6081.16       outdoor  Cycling
# 3               184         6589.62       outdoor  Cycling
# 4               147         6162.94       outdoor  Cycling
# 5               156         5382.67       outdoor  Cycling
# 6               144         6086.99       outdoor  Cycling
# 7               141         5389.12       outdoor  Cycling
# 8               156         6143.74       outdoor  Cycling
# 9               310         8859.43       outdoor  Cycling
# 10              153         5753.60       outdoor  Cycling
# 11              144         6045.11       outdoor  Cycling
# 12              189         6607.60       outdoor  Cycling
# 13              150         6090.69       outdoor  Cycling
# 14              166         5779.66       outdoor  Cycling
# 15              145         6114.83       outdoor  Cycling
# 16              164         5766.43       outdoor  Cycling
# 17              144         6105.27       outdoor  Cycling
# 18              163         5783.29       outdoor  Cycling
# 19              145         6181.86       outdoor  Cycling
# 20              154         5759.41       outdoor  Cycling
# 21              141         6096.46       outdoor  Cycling
# 22              157         5978.89       outdoor  Cycling
# 23              142         6111.35       outdoor  Cycling
# 24              157         5711.36       outdoor  Cycling
# 25              143         6073.79       outdoor  Cycling
# 26              351        10489.03       outdoor  Cycling
# 27              143         6063.58       outdoor  Cycling
# 28              145         5378.71       outdoor  Cycling
# 29              142         6095.87       outdoor  Cycling
# ..              ...             ...           ...      ...
# 216             456         5734.59       outdoor  Running
# 217              63         1047.16       outdoor  Running
# 218             565         5782.77       outdoor  Running
# 219             458         5895.76       outdoor  Running
# 220             660         3698.49       outdoor  Running
# 221             435         5990.81       outdoor  Running
# 222             454         5749.38       outdoor  Running
# 223             455         5789.03       outdoor  Running
# 224              49          779.13       outdoor  Running
# 225             447         5674.95       outdoor  Running
# 226              75         1213.08       outdoor  Running
# 227             462         5838.99       outdoor  Running
# 228             253         3927.29       outdoor  Running
# 229             101         1593.61       outdoor  Running
# 230             489         6154.29       outdoor  Running
# 231             105          844.11       outdoor  Running
# 232             467         5805.84       outdoor  Running
# 233             205         3016.58       outdoor  Running
# 234             366         4815.52       outdoor  Running
# 235             353         4555.47       outdoor  Running
# 236             238         3272.86       outdoor  Running
# 237             357         4675.90       outdoor  Running
# 238             365         4683.07       outdoor  Running
# 239             361         4655.55       outdoor  Running
# 240             362         4703.84       outdoor  Running
# 241             360         4672.89       outdoor  Running
# 242             520         4690.98       outdoor  Running
# 243             343         4498.64       outdoor  Running
# 244             130         1984.28       outdoor  Running
# 245              65          986.25       outdoor  Running
#
#                                uri  utc_offset
# 0    /fitnessActivities/1007493795          -3
# 1    /fitnessActivities/1005956310          -3
# 2    /fitnessActivities/1005843765          -3
# 3    /fitnessActivities/1005535586          -3
# 4    /fitnessActivities/1005303953          -3
# 5    /fitnessActivities/1004255363          -3
# 6    /fitnessActivities/1004088987          -3
# 7    /fitnessActivities/1003621881          -3
# 8    /fitnessActivities/1003493993          -3
# 9    /fitnessActivities/1002663916          -3
# 10   /fitnessActivities/1000879327          -3
# 11   /fitnessActivities/1000713723          -3
# 12   /fitnessActivities/1000444019          -3
# 13   /fitnessActivities/1000067931          -3
# 14    /fitnessActivities/999721058          -3
# 15    /fitnessActivities/999458777          -3
# 16    /fitnessActivities/997878707          -3
# 17    /fitnessActivities/997716950          -3
# 18    /fitnessActivities/997294049          -3
# 19    /fitnessActivities/997151351          -3
# 20    /fitnessActivities/996701562          -3
# 21    /fitnessActivities/996573146          -3
# 22    /fitnessActivities/996225220          -3
# 23    /fitnessActivities/995999970          -3
# 24    /fitnessActivities/995698428          -3
# 25    /fitnessActivities/995399416          -3
# 26    /fitnessActivities/993855342          -3
# 27    /fitnessActivities/993644394          -3
# 28    /fitnessActivities/993644390          -3
# 29    /fitnessActivities/993050883          -3
# ..                             ...         ...
# 216   /fitnessActivities/772361130          -3
# 217   /fitnessActivities/770943625          -3
# 218   /fitnessActivities/770943610          -3
# 219   /fitnessActivities/766282546          -3
# 220   /fitnessActivities/764018100          -3
# 221   /fitnessActivities/759716642          -3
# 222   /fitnessActivities/755079850          -3
# 223   /fitnessActivities/753860205          -3
# 224   /fitnessActivities/753646484          -3
# 225   /fitnessActivities/749797852          -3
# 226   /fitnessActivities/747371294          -3
# 227   /fitnessActivities/745796497          -3
# 228   /fitnessActivities/745656183          -3
# 229   /fitnessActivities/745656175          -3
# 230   /fitnessActivities/743736231          -3
# 231   /fitnessActivities/743518140          -3
# 232   /fitnessActivities/742107339          -3
# 233   /fitnessActivities/742025830          -3
# 234   /fitnessActivities/738351372          -3
# 235   /fitnessActivities/734684880          -3
# 236   /fitnessActivities/695107893          -2
# 237   /fitnessActivities/682306939          -2
# 238   /fitnessActivities/662964078          -3
# 239   /fitnessActivities/660961272          -3
# 240   /fitnessActivities/577596948          -3
# 241   /fitnessActivities/559747998          -3
# 242   /fitnessActivities/554014359          -3
# 243   /fitnessActivities/553679343          -3
# 244   /fitnessActivities/439268589          -3
# 245   /fitnessActivities/439268582          -3
#
# [246 rows x 11 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to visualize the data into an excel file, the cell bellow is responsible for exporting the data.

# %%
# Export the new dataSet to csv
api_df.to_csv('dataSource.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # II - Summary section
#
# #### Here in this section, we'll handle the user profile infos.

# %%
# ==========================================================
# User informations request
# ==========================================================

# Base URI
profile_URI = "http://api.runkeeper.com/profile?access_token=" + ACCESS_TOKEN

# Receive the results from API
profile_content = requests.get(profile_URI).json()

# Base URI
weight_URI = "http://api.runkeeper.com/weight?access_token=" + ACCESS_TOKEN

# Receive the results from API
weight_content = requests.get(weight_URI).json()
weight_df = json_normalize(weight_content['items'])

# ==========================================================
# Display informations
# ==========================================================
display(Markdown('# Hello, ' + str(profile_content['name']) + '!'))

# Name
if profile_content['name']:
    display(Markdown('**Your name:** ' + str(profile_content['name'])))

# Birthday
if profile_content['birthday']:
    display(Markdown('**Birthday:** ' + str(profile_content['birthday'])))
    
# Gender
if profile_content['gender']:
    display(Markdown('**Gender:** ' + str(profile_content['gender'])))

# Location
if profile_content['location']:
    display(Markdown('**Location:** ' + str(profile_content['location'])))
    
# Profile
if profile_content['profile']:
    display(Markdown('**Profile:** ' + str(profile_content['profile'])))
    
display(Markdown('<hr>'))

# ==========================================================
# Weight chart
# ==========================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

data_weight = weight_df[np.isfinite(weight_df['weight'])].reset_index()
data_weight = data_weight['weight'].sort_index(ascending=False)

# Make a line chart with the dataSet
line = Line(data=data_weight, legend="top_left", background_fill_color="#E8DDCB", 
            ylabel='Weight', tools=TOOLS, plot_width=900)

# Configure visual properties on a plot's title attribute
line.title.text = "Historical weight"
line.title.align = "center"
line.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(line)

# ==========================================================
# Body fat chart
# ==========================================================

data_fat = weight_df[np.isfinite(weight_df['fat_percent'])]
data_fat = data_fat['fat_percent']

# Make a line chart with the dataSet
line = Line(data=data_fat, legend="top_left", background_fill_color="#E8DDCB", 
            ylabel='Fat(%)', tools=TOOLS, plot_width=900)

# Configure visual properties on a plot's title attribute
line.title.text = "Historical fat %"
line.title.align = "center"
line.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()

# Display the plot
show(line)
# Out:
# # Hello, Igor!
# **Your name:** Igor
# **Birthday:** Sun, 26 Apr 1992 00:00:00
# **Gender:** M
# **Location:** Natal - RN, Brazil
# **Profile:** https://runkeeper.com/user/igorbrandao
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c0c3ac6-643d-4344-a77f-98ccee45dab9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eb3ab707-9202-4d5c-879e-5d151fcfc121"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("eb3ab707-9202-4d5c-879e-5d151fcfc121").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eb3ab707-9202-4d5c-879e-5d151fcfc121");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eb3ab707-9202-4d5c-879e-5d151fcfc121' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"31574743-d495-4548-9633-99f710f184b1":{"roots":{"references":[{"attributes":{"axis_label":"index","formatter":{"id":"a5022f75-8e2a-4afa-85bb-6281c558dd17","type":"BasicTickFormatter"},"plot":{"id":"869c8760-0f9b-49a5-85aa-6f00329da1eb","subtype":"Chart","type":"Plot"},"ticker":{"id":"6199194b-2922-43ba-8c1c-4037f8d270dd","type":"BasicTicker"}},"id":"80b58633-c3ca-47e8-ae0a-10a5d605737c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"65553ba7-0397-417d-aabd-45900e02cd11","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"869c8760-0f9b-49a5-85aa-6f00329da1eb","subtype":"Chart","type":"Plot"}},"id":"b1d5a55b-1dc5-4c94-bfa0-9b4b7ef8ae8d","type":"ResetTool"},{"attributes":{},"id":"9fcdb33b-4fe5-48c5-85d2-eb992013812f","type":"BasicTicker"},{"attributes":{"callback":null,"end":8.8,"start":-0.8},"id":"6a9a0ad1-f260-4c06-bc2a-18b36433513b","type":"Range1d"},{"attributes":{"items":[{"id":"70649a0b-502e-47f9-869e-4838dd7389d4","type":"LegendItem"}],"location":"top_left","
type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x": ...

# %% [markdown]
# # Analysis
#
# **Unfortunately**, the weight and fat percentage history tables were left with their values reversed and we were unable to repair them in a timely manner, **But** if we analyze by abstracting the fact that they are inverted we will see a loss of weight together with a drop in fat percentage.

# %% [markdown]
# # III - Statistic section
#
# #### Here in this section, we'll handle the statistics infos.
#
# #### The idea is to use the ***top-down analysis***, from the more generic context to the specific one

# %% [markdown]
# ## 1) Activites summary

# %%
# ==========================================================
# Display activites summary
# ==========================================================
display(Markdown('## Activites summary'))

display(Markdown('** Total activites:** ' + str(api_content['size'])))
display(Markdown('** Total duration:** ' + str("%.2f" % api_df['duration'].sum()) + ' minutes' + 
                ' or ' + str("%.0f" % (api_df['duration'].sum()/60)) + ' hours'))
display(Markdown('** Total distance:** ' + str("%.2f" % api_df['total_distance'].sum()) + ' km'))
display(Markdown('** Total calories burned:** ' + str(api_df['total_calories'].sum()) + ' kcal'))
# Out:
# ## Activites summary
# ** Total activites:** 246
# ** Total duration:** 7156.43 minutes or 119 hours
# ** Total distance:** 1286560.55 km
# ** Total calories burned:** 57742 kcal

# %% [markdown]
# ## 2) Activites overall times
#
# **[Analysis]: ** In this chart we can see the dedicated time by the user *(in hours)* for each activity type.
#
# He/she spent approximately **35 hours** running and about **25** hours for cycling.

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Make a bar chart: p
p = Bar(api_df, values='duration', label='type', agg='mean', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            plot_width=750, plot_height=500, tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity overall time'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Average time:',' @height')]

# Configure visual properties on a plot's title attribute
p.title.text = "Overall time by activity type"
p.title.align = "center"
p.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d1f8c7a1-f64f-42b6-b869-5e93fbe5d888">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e85f5c89-3bef-4339-b104-213b1f7ec93c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e85f5c89-3bef-4339-b104-213b1f7ec93c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e85f5c89-3bef-4339-b104-213b1f7ec93c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e85f5c89-3bef-4339-b104-213b1f7ec93c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2cf9b063-7047-4af2-a8d2-e90a0e86d54b":{"roots":{"references":[{"attributes":{"axis_label":"Activity overall time","formatter":{"id":"8d77ef61-740a-448c-99d6-6d2c9d9552da","type":"BasicTickFormatter"},"plot":{"id":"7dbe9257-a715-4514-ac7d-eded46778d50","subtype":"Chart","type":"Plot"},"ticker":{"id":"270b52ca-8119-4771-9f7d-f86f5fc09c85","type":"BasicTicker"}},"id":"f44a66c9-b471-41d8-b076-74e4c37217ed","type":"LinearAxis"},{"attributes":{},"id":"270b52ca-8119-4771-9f7d-f86f5fc09c85","type":"BasicTicker"},{"attributes":{"items":[{"id":"45839b64-deb7-4f59-80f0-d14145aef92f","type":"LegendItem"},{"id":"83ad6a0f-e2c6-4a08-bbce-4c564f7c5fab","type":"LegendItem"}],"location":"bottom_right","plot":{"id":
# **[Analysis]:** In this chart, we can see that the user spends **more calories running than cycling**.
#
# Besides that, through the bar chart we can see the total calories burned summing. In this case the user burnt about ***33 thousand calories with running against 25000 with cycling***.
#
# The boxplot chart presents the difference between running and cycling activities in terms of calories use, where **running activities burnt more calories than cycling**.

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

# Make a bar chart: p
bar = Bar(api_df, values='total_calories', label='type', agg='sum', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Make a box plot: unit 1
box = BoxPlot(api_df, values='total_calories', label='type', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity total calories'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Total calories:',' @height')]

# Configure visual properties on a plot's title attribute
bar.title.text = "Total calories burned by activity type"
bar.title.align = "center"
bar.title.text_font_size = "25px"

box.title.text = "Total calories burned by activity type"
box.title.align = "center"
box.title.text_font_size = "25px"

# Create a list containing plots
row1 = [bar,box]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1],sizing_mode='scale_width', plot_height=750)

# Call the output_notebook() 
output_notebook()
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="62edc975-8eb1-4dcf-9a73-f453b68414fc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="97461c34-7968-49b6-b885-2dc9d5c97283"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("97461c34-7968-49b6-b885-2dc9d5c97283").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97461c34-7968-49b6-b885-2dc9d5c97283");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97461c34-7968-49b6-b885-2dc9d5c97283' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"36e133da-160e-40b2-ad39-198146655444":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa633faf-e372-4580-8c75-5b4d782643a1","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Cycling"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[25087.0],"label":[{"type":"Cycling"}],"line_alpha":[1.0],"line_color":["white"],"type":["Cycling"],"width":[0.8],"x":["Cycling"],"y":[12543.5]}},"id":"f72db5e5-ba1a-4e0f-a999-84ba61af462d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"21ad4ac7-3928-4e0f-8749-9becb5445e1b","type":"ColumnDataSource"},"glyph":{"id":"0983052d-f928-4439-8464-16bd46f2fa2c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c5c776ef-1ae6-4f12-84a1-a8c0f9ad3ed1","type":"GlyphRenderer"},{"attributes":{},"id":"8e81233e-1943-4391-ac35-920d7fca08b7","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Running"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[93.75],"label":[{"type":"Running"}],"line_alpha":[1.0],"line_color":["black"],"type":["Running"],"width":[0.8],"x":["Running"],"y":[405.375]}},"id":"21ad4ac7-3928-4e0f-8749-9becb5445e1b","type":"ColumnDataSource"},{"attributes":{"axis_label":"Sum( Total_Calories )","formatter":{"id":"bc5c5c88-85ac-4909-a43c-f9f1d706bc1b","type":"BasicTickFormatter"},"plot":{"id":"4a1d1175-5d1e-40e5-aec6-4c73d6531fef","subtype":"Chart","type":"Plot"},"ticker":{"id":"8e81233e-1943-4391-ac35-920d7fca08b7","type":"BasicTicker"}},"id":"916c8b01-0ec2-4f95-b667-bda86996a426","type":"LinearAxis"},{"attributes":{"data_source":{"id":"f72db5e5-ba1a-4e0f-a999-84ba61af462d","type":"ColumnDataSource"},"glyph":{"id":"aa633faf-e372-4580-8c75-5b4d782643a1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5f4c576e-ff59-4a65-a4ce-02dd4830af90","type":"GlyphRenderer"},{"attributes":{},"id":"95d8ac78-5b22-4d1a-a90e-763fcd14f3e2","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"54e493c6-ec4f-431a-8dca-514e7059abd5","type":"Rect"},{"attributes":{},"id":"bc5c5c88-85ac-4909-a43c-f9f1d706bc1b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"factors":["Cycling","Running"]},"id":"001d4ed7-f0c2-4829-b40a-ee8802466b6e","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Running"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[32655.0],"label":[{"type":"Running"}],"line_alpha":[1.0],"line_color":["white"],"type":["Running"],"width":[0.8],"x":["Running"],"y":[16327.5]}},"id":"caad232e-3396-4754-94cd-59f2e8942eba","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"f3699127-4512-4003-9401-ae4e46576265","type":"Segment"},{"attributes":{},"id":"7d7e19f6-16ce-4e88-8cd6-6e2386fbc8f6","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"type":"Running"},{"type":"Running"},{"type":"Running"},{"type":"Running"}],"type":["Running","Running","Running","Running"],"x0s":["Running:0.5","Running:0.65","Running:0.5","Running:0.65"],"x1s":["Running:0.5","Running:0.35","Running:0.5","Running:0.35"]," ...

# %% [markdown]
# # Analysis
# <p>In the above graphs, we can see that the user spends more calories with the running activity than with a cycling activity, In the chart on the left we can see a sum of the total calories burned and we see that the user burned about 33 thousand calories with running against 25000 with cycling, and in the right chart, we can have a clear notion of an activity performed More calories than cycling.</p>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 4) Activites by period
#
# First of all we need to split the information by period. To achieve that, the idea is apply a group selection by partial string in timestamp column

# %% [markdown]
# ## Timestamp split into columns
#
# In order to have a better way to handle the data by period, it'll be necessary split the timestamp column into separate columns

# %%
# =================================================================================
# Dataframe timestamp split
# =================================================================================

# Copy the data
data_by_period = api_df.copy()
data_by_period["month"] = 0
data_by_period["month_index"] = 0
data_by_period["year"] = 0

# Fill the years
data_by_period.loc[data_by_period['start_time'].str.contains('2017'), 'year'] = '2017'
data_by_period.loc[data_by_period['start_time'].str.contains('2016'), 'year'] = '2016'
data_by_period.loc[data_by_period['start_time'].str.contains('2015'), 'year'] = '2015'
data_by_period.loc[data_by_period['start_time'].str.contains('2014'), 'year'] = '2014'

# Fill the months
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month'] = 'Jan'
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month_index'] = '1'

data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month'] = 'Feb'
data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month_index'] = '2'

data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month'] = 'Mar'
data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month_index'] = '3'

data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month'] = 'Apr'
data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month_index'] = '4'

data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month'] = 'May'
data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month_index'] = '5'

data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month'] = 'Jun'
data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month_index'] = '6'

data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month'] = 'Jul'
data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month_index'] = '7'

data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month'] = 'Aug'
data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month_index'] = '8'

data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month'] = 'Sep'
data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month_index'] = '9'

data_by_period.loc[data_by_period['start_time'].str.contains('Oct-'), 'month'] = 'Oct'
data_by_period.loc[data_by_period['start_time'].str.contains('Oct'), 'month_index'] = '10'

data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month'] = 'Nov'
data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month_index'] = '11'

data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month'] = 'Dec'
data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month_index'] = '12'

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid replacing the timestamp to other columns, we'll export the new dataSet to a csv file. You can skip this operation because the new .csv dataSet is already included in the project

# %%
# Export the new dataSet to csv
data_by_period.to_csv('dataSourceByPeriod.csv', encoding="utf-8")

# %% [markdown]
# ## All years overview

# %%
# =================================================================================
# Data import
# =================================================================================

# Import the fertility.csv data: data
data_by_period = pd.read_csv("dataSourceByPeriod.csv", encoding = 'latin2')

# =================================================================================
# Year selection
# =================================================================================

yearList = data_by_period.year.unique()

for idx, val in enumerate(yearList):

    # =================================================================================
    # Data selection
    # =================================================================================

    year = val

    # Filter the activities by year
    activitiesYear = data_by_period[data_by_period["year"] == year].sort_values('month_index')

    # =================================================================================
    # Data count
    # =================================================================================

    # Do some fix in disciplineStatus
    activityType = activitiesYear.copy()
    activityType["Count"] = 0

    # Count the status sum-up
    activityType = pd.DataFrame(activityType.groupby(["type"])['Count'].count()).reset_index()

    # =================================================================================
    # Chart plotting
    # =================================================================================

    # Tools
    TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

    barMonth = Bar(activitiesYear, values='total_distance', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barCaloryMonth = Bar(activitiesYear, values='total_calories', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barDurationMonth = Bar(activitiesYear, values='duration', label=CatAttr(columns=['month'], sort=False), color='month', agg='mean', 
                          legend='top_left', tools=TOOLS)

    # Donut chart settings
    donutType = Donut(activityType, label=['type', 'Count'], values='Count',
              text_font_size='14pt', legend='top_left', 
              tools=TOOLS, background_fill_color="#E8DDCB", title='Discipline status', 
              color='type')

    # Set the y and x axis label
    barMonth.yaxis.axis_label= 'Total distance'
    barMonth.xaxis.axis_label= 'Month'

    barCaloryMonth.yaxis.axis_label= 'Total calories'
    barCaloryMonth.xaxis.axis_label= 'Month'

    barDurationMonth.yaxis.axis_label= 'Total duration'
    barDurationMonth.xaxis.axis_label= 'Month'

    # Set hover to bars
    hover = barMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total distance:',' @height')]

    hover = barCaloryMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = barDurationMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = donutType.select(dict(type=HoverTool))
    hover.tooltips = [('Activity', '@x'),('Count:',' @height')]

    # Configure visual properties on a plot's title attribute
    barMonth.title.text = "Total distance by month in " + str(year)
    barMonth.title.align = "center"
    barMonth.title.text_font_size = "25px"

    barCaloryMonth.title.text = "Total calories by month in " + str(year)
    barCaloryMonth.title.align = "center"
    barCaloryMonth.title.text_font_size = "25px"

    barDurationMonth.title.text = "Average duration by month in " + str(year)
    barDurationMonth.title.align = "center"
    barDurationMonth.title.text_font_size = "25px"

    donutType.title.text = "Activities types in " + str(year)
    donutType.title.align = "center"
    donutType.title.text_font_size = "25px"

    # Create a list containing plots
    row1 = [barMonth, barCaloryMonth]
    row2 = [barDurationMonth, donutType]

    # Create a gridplot using row1 and row2: layout
    layout = gridplot([row1, row2],sizing_mode='scale_width', plot_height=650, plot_width=900)

    # Call the output_notebook()
    display(Markdown('# Activities overview in ' + str(year)))
    display(Markdown('<hr>'))

    output_notebook()
    show(layout)
# Out:
# # Activities overview in 2017
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c0ad43b2-8860-4e87-8979-1cb1fca6dc41">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="565c9909-c0d9-4e63-9200-638caaa26ff5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("565c9909-c0d9-4e63-9200-638caaa26ff5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("565c9909-c0d9-4e63-9200-638caaa26ff5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '565c9909-c0d9-4e63-9200-638caaa26ff5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"16f8e995-8acb-445c-b836-40cd075e1c24":{"roots":{"references":[{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"4541dfd7-e909-4e83-93cd-6e91fcdaa730","type":"BoxZoomTool"},{"id":"cabb5168-eae5-40ab-aec4-d3fedbed8615","type":"BoxSelectTool"},{"id":"aac8579a-348f-4b35-9979-23d501bbf5c6","type":"CrosshairTool"},{"id":"e90a1b9b-8da9-4167-81c9-4131aea9f74b","type":"ResizeTool"},{"id":"5ea75b11-b38c-49b9-b358-adbfefa04fa6","type":"HoverTool"},{"id":"d39825dd-1fcb-4b5f-bc3b-a6f19d4cfb40","type":"ResetTool"},{"id":"c843cc91-1d60-44a7-9a6c-a7aebd458141","type":"SaveTool"},{"id":"50a53acb-a88e-4432-a6ec-51e940c1ad04","type":"BoxZoomTool"},{"id":"b7d64a75-8a77-4cca-98ef-ecfa86dedd06","type":"BoxSelectTool"},{"id":"4ffb389b-06b5-4978-96c4-aed0aad03d57","type":"CrosshairTool"},{"id":"57aa9077-852b-4887-84a3-bf73d23b3d96","type":"ResizeTool"},{"id":"81c68a03-9a18-4a98-9591-33bd
},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"14pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b0fbe7d-a2b8-430c-83ec-88ae1d42ca88","type":"Text"},{"attributes":{"plot":{"id":"e4044e0f-c7ee-40ff-aa5e-45771dd5cc97","subtype":"Chart","type":"Plot"}},"id":"14912094-4926-4e50-bf7e-15509fb09886","type":"ResizeTool"},{"attributes":{"callback":null,"plot":{"id":"e4044e0f-c7ee-40ff-aa5e-45771dd5cc97","subtype":"Chart","type":"Plot"},"tooltips":[["Month","@x"],["Total distance:"," @height"]]},"id":"ae5434b4-af7b-4954-a3d0-d8433c09e735","type":"HoverTool"},{"attributes":{"axis_label":null,"formatter":{"id":"14f7aab1-6690-42aa-84dd-b358af55cdd5","type":"BasicTickFormatter"},"plot":{"id":"a341cf67-5d42-4374-95a8-a0df229dba43","subtype":"Chart","type":"Plot"},"ticker":{"id":"95b14092-7251-4d8e-8c5e-d70dbca64d06","type":"BasicTicker"},"visible":false},"id":"93af8ce4-4b36-4788-8916-d25665b7a8f9","type":"LinearAxis"},{"attributes":{"plot":{"id":"e4044e0f-c7ee-40ff-aa5e-45771dd5cc97","subtype":"Chart","type":"Plot"}},"id":"07164fcf-7a09-41bf-a23f-fa8feb6d54ec","type":"ResetTool"},{"attributes":{},"id":"b5535e12-96df-4eef-9f55-be846ef62de9","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"e4044e0f-c7ee-40ff-aa5e-45771dd5cc97","subtype":"Chart","type":"Plot"}},"id":"3081177b-c280-4313-8335-dba59ffbb38e","type":"SaveTool"},{"attributes":{"data_source":{"id":"94319746-d12f-4972-aeb4-5556e1c27b07","type":"ColumnDataSource"},"glyph":{"id":"9b0fbe7d-a2b8-430c-83ec-88ae1d42ca88","type":"Text"},"hover_glyph":null,"nonselection_glyph" ...

# %% [markdown]
# # Analysis
#
# ## 2017 Summary
# <p>If we analyze the total in 2017 we will realize that the distance has continued to increase, however, with a drop in the last month, most probably due to the end of the semester. While the average time spent with exercise decreased, which indicates that there may have been an increase in performance of the training, as the amount of distance continued to increase.</p>
#
# <p>If we take into account the total of calories spent in the period we will notice that in the months of March to April, calorie expenditure remained at a very close level, close to 7000 calories per month, decreasing only in June.</p>
#
# <p>About activities we see a drastic change of activities, being almost 96% of the activities of cycling and only about 4% of running activity, being that in the previous years the activities were 100% of running activity.</p>
#
# ## 2016 Summary
# <p>In 2016 we can see a situation where the athlete continued to evolve in training by the total distance traveled in the month, but there was a break in the middle of the year, resuming training soon after and achieving better results in the second half than in the first.</p>
#
# <p>The total of calories burned followed the same level of distance traveled, with a decrease in the evolution at the end of the first and second semester.</p>
#
# <p>Unlike the year 2017, in 2016 no cycling exercise was registered, being dedicated 100% of the training only to the running training.</p>
#
# ## 2015 and 2014 Summary
# <p>In 2015 no data were recorded and in 2014 the number of activities was insufficient for any analysis.</p>

# %% [markdown]
# # IV - Geolocation section
#
# #### Here in this section, we'll handle the geolocation infos.

# %% [markdown]
# ## Location import [warning: too heavy]
#
# The cell below perform multiple requests to Runkeep Health Graph API, in order to retrieve all activities in details to get location informations such as: latitude/longitude

# %%
# =================================================================================
# Geolocation data
# =================================================================================

# Copy the data
geolocation_data = pd.DataFrame()

# =================================================================================
# API single activity request
# =================================================================================

# Base URI
base_URI = "http://api.runkeeper.com"

limit = 2

# Run through all activites
for idx, row in tqdm(api_df.iterrows()):
    
    # Final activity URI
    activity_url = base_URI + row['uri'] + "?access_token=" + ACCESS_TOKEN

    # Receive the results from API
    activity_content = requests.get(activity_url).json()

    # Perform a conversion from JSON to Data Frame
    activity_df = json_normalize(activity_content['path'])
    
    # Add the activity path data to geolocation
    geolocation_data = pd.concat([geolocation_data, activity_df])
    
geolocation_data
# Out:
# 246it [01:51,  2.43it/s]
#      altitude  latitude  longitude  timestamp   type
# 0   54.666667 -5.833640 -35.203724      0.000  start
# 1   54.857143 -5.833620 -35.203640     42.732    gps
# 2   55.000000 -5.833648 -35.203544     47.737    gps
# 3   55.000000 -5.833698 -35.203472     49.737    gps
# 4   55.000000 -5.833726 -35.203382     51.742    gps
# 5   55.000000 -5.833743 -35.203273     54.742    gps
# 6   55.090909 -5.833760 -35.203162     57.730    gps
# 7   55.181818 -5.833783 -35.203067     60.727    gps
# 8   55.181818 -5.833680 -35.203037     63.740    gps
# 9   54.909091 -5.833562 -35.203016     66.733    gps
# 10  54.454545 -5.833457 -35.202992     69.733    gps
# 11  53.818182 -5.833375 -35.202994     72.734    gps
# 12  53.272727 -5.833286 -35.202983     76.727    gps
# 13  52.818182 -5.833205 -35.202961     81.739    gps
# 14  52.454545 -5.833109 -35.202936     86.735    gps
# 15  52.090909 -5.833086 -35.202810     88.732    gps
# 16  51.636364 -5.833122 -35.202698     90.735    gps
# 17  51.090909 -5.833166 -35.202587     92.724    gps
# 18  50.363636 -5.833228 -35.202494     94.736    gps
# 19  49.727273 -5.833296 -35.202401     96.738    gps
# 20  49.363636 -5.833362 -35.202307     98.727    gps
# 21  49.272727 -5.833433 -35.202214    100.736    gps
# 22  49.363636 -5.833504 -35.202115    102.736    gps
# 23  49.454545 -5.833575 -35.202015    104.738    gps
# 24  49.454545 -5.833646 -35.201922    106.742    gps
# 25  49.363636 -5.833722 -35.201831    108.745    gps
# 26  49.181818 -5.833785 -35.201736    110.743    gps
# 27  49.000000 -5.833859 -35.201647    112.730    gps
# 28  48.818182 -5.833934 -35.201554    114.734    gps
# 29  48.727273 -5.834001 -35.201468    116.725    gps
# ..        ...       ...        ...        ...    ...
# 62  41.272727 -5.837374 -35.204052    566.278    gps
# 63  41.909091 -5.837378 -35.204152    572.286    gps
# 64  42.545455 -5.837391 -35.204265    579.283    gps
# 65  42.727273 -5.837394 -35.204383    589.266    gps
# 66  42.909091 -5.837407 -35.204485    597.286    gps
# 67  43.090909 -5.837423 -35.204580    605.260    gps
# 68  43.272727 -5.837428 -35.204679    612.236    gps
# 69  43.454545 -5.837404 -35.204768    618.284    gps
# 70  43.636364 -5.837390 -35.204863    625.431    gps
# 71  44.181818 -5.837403 -35.204956    634.283    gps
# 72  44.727273 -5.837385 -35.205051    640.278    gps
# 73  45.090909 -5.837381 -35.205143    647.295    gps
# 74  45.454545 -5.837340 -35.205233    654.279    gps
# 75  45.818182 -5.837297 -35.205318    660.267    gps
# 76  46.181818 -5.837257 -35.205409    667.273    gps
# 77  46.545455 -5.837231 -35.205499    674.283    gps
# 78  46.909091 -5.837232 -35.205598    682.242    gps
# 79  47.272727 -5.837292 -35.205686    689.260    gps
# 80  47.636364 -5.837355 -35.205753    694.275    gps
# 81  48.181818 -5.837433 -35.205801    700.279    gps
# 82  48.363636 -5.837550 -35.205871    711.240    gps
# 83  48.545455 -5.837620 -35.205942    716.287    gps
# 84  48.727273 -5.837649 -35.206036    722.284    gps
# 85  48.909091 -5.837644 -35.206134    727.275    gps
# 86  49.090909 -5.837651 -35.206233    734.278    gps
# 87  49.200000 -5.837656 -35.206339    741.285    gps
# 88  49.333333 -5.837683 -35.206428    747.271    gps
# 89  49.500000 -5.837591 -35.206457    755.242    gps
# 90  49.714286 -5.837495 -35.206484    768.285    gps
# 91  50.000000 -5.837505 -35.206520    839.407    end
#
# [100289 rows x 5 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid processing the cell above, here we are saving the processed geolocationd data.

# %%
# Export the new dataSet to csv
geolocation_data.to_csv('geolocation.csv', encoding="utf-8")

# %% [markdown]
# ## Geolocation data import [optional]

# %%
# Import the fertility.csv data: data
geolocation_data = pd.read_csv("geolocation.csv", encoding = 'latin2')

# %% [markdown]
# ## 1) Heatmap

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Heatmap generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.ix[i,'latitude'], geodata.ix[i,'longitude'], geodata.ix[i,'count']])):
        coordinates.append([geodata.ix[i,'latitude'], geodata.ix[i,'longitude'], geodata.ix[i,'count']])

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Print the heatMap
htMap
# Out:
# 100%|█████████████████████████████████| 99785/99785 [00:09<00:00, 10029.58it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## 2) Map markers

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Map markers generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# For speed purposes
MAX_RECORDS = 100

# Create map object
map_activities = folium.Map(location=mapc, zoom_start=zoom)

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    
    if i == MAX_RECORDS:
        break;
    
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.ix[i,'latitude'], geodata.ix[i,'longitude']])):
        folium.Marker(location = [geodata.ix[i,'latitude'],geodata.ix[i,'longitude']]).add_to(map_activities)

# Show the map
map_activities
# Out:
#   0%|                                      | 93/99785 [00:00<12:57, 128.19it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # V - Web scraping section
#
# #### Here in this section, we'll try to get user friends informations.

# %% [markdown]
# ## Web scraping functions

# %%
# Return an soup Object
def getSoup(url):
    try:
        html = requests.get(url)
    except HTTPError as e:
        return None
    try:
        soup = BeautifulSoup(html.content, 'html.parser')
    except AttributeError as e:
        return None
    return soup

# %%
# Remove the dirty part from link
def getLink(url, dirty):
    result = url.split(dirty)
    return result[0]

# %% [markdown]
# ## Web scraping flow starts here
#
# This cell'll provide the user and its friends basic stats such as: [total activities, total distance and total calories burned]

# %%
# Profile
if profile_content:

    # =================================================================================
    # Web scraping
    # =================================================================================
    
    # Get the content from user profile
    soup = getSoup(profile_content['profile'] + '/friends')
    
    # Array with users URI
    friends_URI = []
    friends_name = []
    
    # Get the friends ID
    for item in soup.findAll(class_='usernameLinkNoSpace user-name'):
        
        # Check if it's a link
        if 'href' in item.attrs:
                
            # Check if the link URI has a specifc string
            if '/user/' in str(item.attrs):

                # Append the link URI
                friends_URI.append(item.attrs['href'])
                
                # Append the friend name
                friends_name.append(item.text.strip(' \t\n\r'))
                
    # Friends info array
    friends = []
    temp = []
    
    # Run through friends profile URI array
    for idx, val in enumerate(friends_URI):
    
        # Get the content from profile friends page
        friend_uri = 'https://runkeeper.com' + val
        soup_friend = getSoup(friend_uri)
        
        # Get the friends ID
        for item in soup_friend.findAll('div', id='statsSection'):
            
            if item:

                # Get the stats
                for subitem in item.findAll(class_='statValue'):
                    
                    # Add the stats to a temporary array
                    if subitem.text.strip():
                        temp.append(subitem.text.strip(' \t\n\r'))
                        
                break;
                    
        # Add the stats to friends array
        friends.append(temp)
        temp = []
    
else:
    print('No data available')

# %%
# =================================================================================
# Data presentation
# =================================================================================

display(Markdown('# Friends activites summary'))

# Run through friends information
for idx, val in enumerate(friends_name):

    display(Markdown('#  ' + val))
    display(Markdown('**Total activities:** ' + friends[idx][0]))
    display(Markdown('**Total distance:** ' + friends[idx][1] + ' km'))
    display(Markdown('**Total calories burned:** ' + friends[idx][2] + ' kcal'))
# Out:
# # Friends activites summary
# #  Igor
# **Total activities:** 246
# **Total distance:** 1286.56 km
# **Total calories burned:** 57742 kcal
# #  Leandro Max
# **Total activities:** 14
# **Total distance:** 31.17 km
# **Total calories burned:** 2486 kcal
# #  Ivan Alisson
# **Total activities:** 24
# **Total distance:** 85.96 km
# **Total calories burned:** 5304 kcal
# #  Diego BrandĂŁo
# **Total activities:** 2
# **Total distance:** 8.81 km
# **Total calories burned:** 653 kcal

# %% [markdown]
# # Final analysis
#
# Here in the final part of web scraping we take the data that is exposed on the activities of the friends of a user, in case we are using the profile of Igor as an example. By this data we can see who is active, and who does not continue doing exercises, this data could be used in various ways such as offering training plans for those who are not so active or selling products of sports materials to those who are more active.
