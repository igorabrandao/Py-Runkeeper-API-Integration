# %% [markdown]
# # Programming Project - Unit 3,3
# *by Igor A. Brandão and Leandro Antonio Feliciano da Silva*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Full content of the statistical part seen in the course;
# - Graphs generation;
# - Geolocation analysis and hypotheses should be explained in detail;
# - Web scraping.

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Bokeh charts;
# - Numpy library;
# - Tqdm progress bar
# - Requests;
# - urlopen;
# - HTTPError;
# - BeautifulSoup
# - Regular expression

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium heatmap
import folium
from folium.plugins import HeatMap

# Import tqdm progressing bar plugin
from tqdm import tqdm

# Import bokeh libraries
from bokeh.plotting import figure
from bokeh.charts import Bar, Histogram, Donut, BoxPlot, Line, output_notebook, show
from bokeh.layouts import row, gridplot, column
from bokeh.models import HoverTool
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.models import HoverTool
from bokeh.charts.attributes import AttrSpec, ColorAttr, MarkerAttr, CatAttr

# Import request libraries
from urllib.request import Request, urlopen
from urllib.error import HTTPError

# Import web scraping libraries
from bs4 import BeautifulSoup
import re # regular expression

# Import API libraries
import requests
import json
from pandas.io.json import json_normalize

# Imports to output the result as a Markdown
from IPython.display import display, Markdown

# %% [markdown]
# <hr>

# %% [markdown]
# # API section
#
# ## API data retrieving
#
# #### In the cell bellow, we perform a connection with Health Graph API - Runkeeper.

# %%
# Access token
ACCESS_TOKEN = '25bc30d6dd6f4b99bbeb48e8619103b4'

# Base URI
api_URI = "http://api.runkeeper.com/fitnessActivities"

# Number of results
pageSize = 300

# Final URI
url = '%s?pageSize=%s&access_token=%s' % \
    (api_URI, pageSize, ACCESS_TOKEN,)

# print(url)

# Receive the results from API
api_content = requests.get(url).json()

print(json.dumps(api_content, indent=1))
# Out:
# {
#  "size": 245,
#  "items": [
#   {
#    "utc_offset": -3,
#    "duration": 1037,
#    "start_time": "Fri, 23 Jun 2017 12:40:11",
#    "total_calories": 148,
#    "tracking_mode": "outdoor",
#    "total_distance": 5345.75479639154,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005956310"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1140,
#    "start_time": "Fri, 23 Jun 2017 07:50:54",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6081.16390011933,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005843765"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1285,
#    "start_time": "Thu, 22 Jun 2017 12:41:16",
#    "total_calories": 184,
#    "tracking_mode": "outdoor",
#    "total_distance": 6589.61628038915,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005535586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1235,
#    "start_time": "Thu, 22 Jun 2017 07:37:35",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6162.94434876089,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1005303953"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1158,
#    "start_time": "Tue, 20 Jun 2017 12:35:21",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 5382.67114549159,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004255363"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1193,
#    "start_time": "Tue, 20 Jun 2017 07:30:08",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6086.98681262211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1004088987"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1021,
#    "start_time": "Mon, 19 Jun 2017 12:36:20",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5389.11505599285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1003621881"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1385,
#    "start_time": "Mon, 19 Jun 2017 07:43:02",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 6143.73512742271,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1003493993"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3026,
#    "start_time": "Sat, 17 Jun 2017 14:47:50",
#    "total_calories": 310,
#    "tracking_mode": "outdoor",
#    "total_distance": 8859.43226805176,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1002663916"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1090,
#    "start_time": "Wed, 14 Jun 2017 13:26:09",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5753.59760001431,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000879327"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1129,
#    "start_time": "Wed, 14 Jun 2017 07:53:31",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6045.10626534744,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000713723"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1390,
#    "start_time": "Tue, 13 Jun 2017 12:48:45",
#    "total_calories": 189,
#    "tracking_mode": "outdoor",
#    "total_distance": 6607.60352123956,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000444019"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1158,
#    "start_time": "Tue, 13 Jun 2017 07:42:39",
#    "total_calories": 150,
#    "tracking_mode": "outdoor",
#    "total_distance": 6090.68685113152,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/1000067931"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1005,
#    "start_time": "Mon, 12 Jun 2017 12:12:13",
#    "total_calories": 166,
#    "tracking_mode": "outdoor",
#    "total_distance": 5779.65506397961,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/999721058"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1109,
#    "start_time": "Mon, 12 Jun 2017 07:29:08",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6114.83298395792,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/999458777"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 914,
#    "start_time": "Fri, 9 Jun 2017 13:47:21",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5766.42940864071,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/997878707"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1129,
#    "start_time": "Fri, 9 Jun 2017 07:58:28",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 6105.26899701842,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/997716950"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1022,
#    "start_time": "Thu, 8 Jun 2017 13:01:53",
#    "total_calories": 163,
#    "tracking_mode": "outdoor",
#    "total_distance": 5783.2860976375,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/997294049"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1182,
#    "start_time": "Thu, 8 Jun 2017 07:51:49",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6181.85585235652,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/997151351"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1028,
#    "start_time": "Wed, 7 Jun 2017 12:16:18",
#    "total_calories": 154,
#    "tracking_mode": "outdoor",
#    "total_distance": 5759.41191021388,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/996701562"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1126,
#    "start_time": "Wed, 7 Jun 2017 07:55:39",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 6096.46499172934,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/996573146"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 984,
#    "start_time": "Tue, 6 Jun 2017 12:47:04",
#    "total_calories": 157,
#    "tracking_mode": "outdoor",
#    "total_distance": 5978.89188627146,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/996225220"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1110,
#    "start_time": "Tue, 6 Jun 2017 07:30:32",
#    "total_calories": 142,
#    "tracking_mode": "outdoor",
#    "total_distance": 6111.3518639629,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/995999970"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 949,
#    "start_time": "Mon, 5 Jun 2017 12:20:58",
#    "total_calories": 157,
#    "tracking_mode": "outdoor",
#    "total_distance": 5711.35648591223,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/995698428"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1159,
#    "start_time": "Mon, 5 Jun 2017 07:28:30",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6073.79357373555,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/995399416"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2137,
#    "start_time": "Fri, 2 Jun 2017 13:43:00",
#    "total_calories": 351,
#    "tracking_mode": "outdoor",
#    "total_distance": 10489.031544429,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/993855342"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1098,
#    "start_time": "Fri, 2 Jun 2017 07:43:33",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6063.57644244861,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/993644394"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1062,
#    "start_time": "Thu, 1 Jun 2017 13:05:46",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 5378.70742903567,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/993644390"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1125,
#    "start_time": "Thu, 1 Jun 2017 07:43:24",
#    "total_calories": 142,
#    "tracking_mode": "outdoor",
#    "total_distance": 6095.87408602636,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/993050883"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1031,
#    "start_time": "Wed, 31 May 2017 13:05:39",
#    "total_calories": 144,
#    "tracking_mode": "outdoor",
#    "total_distance": 5392.25543387091,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/992607843"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1056,
#    "start_time": "Wed, 31 May 2017 07:46:06",
#    "total_calories": 139,
#    "tracking_mode": "outdoor",
#    "total_distance": 6063.0725208611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/992431836"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1069,
#    "start_time": "Tue, 30 May 2017 12:53:08",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 5400.76576414881,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991962764"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1211,
#    "start_time": "Tue, 30 May 2017 07:39:01",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 6109.72501667069,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991820391"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1074,
#    "start_time": "Mon, 29 May 2017 12:20:50",
#    "total_calories": 157,
#    "tracking_mode": "outdoor",
#    "total_distance": 5775.48218009307,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991365627"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1131,
#    "start_time": "Mon, 29 May 2017 07:26:13",
#    "total_calories": 138,
#    "tracking_mode": "outdoor",
#    "total_distance": 6099.26870387646,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/991169558"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 591,
#    "start_time": "Sat, 27 May 2017 19:08:21",
#    "total_calories": 67,
#    "tracking_mode": "outdoor",
#    "total_distance": 1985.59809947508,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/990327649"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 973,
#    "start_time": "Fri, 26 May 2017 13:17:12",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 5410.65388208804,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989611023"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1319,
#    "start_time": "Fri, 26 May 2017 07:51:10",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6065.57169437408,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989441355"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1252,
#    "start_time": "Thu, 25 May 2017 12:27:02",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5704.26981685631,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/989057824"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1269,
#    "start_time": "Thu, 25 May 2017 07:45:48",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6113.02788518738,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988912391"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 999,
#    "start_time": "Wed, 24 May 2017 13:28:54",
#    "total_calories": 154,
#    "tracking_mode": "outdoor",
#    "total_distance": 5434.65276040979,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988482373"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1094,
#    "start_time": "Wed, 24 May 2017 07:46:28",
#    "total_calories": 142,
#    "tracking_mode": "outdoor",
#    "total_distance": 6097.58289751998,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/988314136"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 956,
#    "start_time": "Tue, 23 May 2017 13:04:33",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5445.85348275805,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987853465"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1128,
#    "start_time": "Tue, 23 May 2017 07:52:58",
#    "total_calories": 139,
#    "tracking_mode": "outdoor",
#    "total_distance": 6107.04559950437,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987694354"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1111,
#    "start_time": "Mon, 22 May 2017 12:11:33",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 5787.55896118107,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987202459"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1232,
#    "start_time": "Mon, 22 May 2017 07:45:33",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6170.41363482883,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/987043645"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 7848,
#    "start_time": "Sun, 21 May 2017 09:03:56",
#    "total_calories": 1065,
#    "tracking_mode": "outdoor",
#    "total_distance": 40466.6970482901,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/986599297"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1115,
#    "start_time": "Fri, 19 May 2017 12:40:16",
#    "total_calories": 163,
#    "tracking_mode": "outdoor",
#    "total_distance": 5751.74859031716,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/985427280"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1093,
#    "start_time": "Fri, 19 May 2017 07:42:15",
#    "total_calories": 135,
#    "tracking_mode": "outdoor",
#    "total_distance": 6120.64413572644,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/985287008"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1102,
#    "start_time": "Thu, 18 May 2017 13:27:24",
#    "total_calories": 168,
#    "tracking_mode": "outdoor",
#    "total_distance": 5833.48101763434,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984890548"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1263,
#    "start_time": "Thu, 18 May 2017 07:30:12",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6102.21516145924,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984721244"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1010,
#    "start_time": "Wed, 17 May 2017 13:31:55",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5816.76723063048,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984721232"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1094,
#    "start_time": "Wed, 17 May 2017 07:20:05",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6158.04864716445,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/984092295"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 999,
#    "start_time": "Tue, 16 May 2017 13:56:29",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 5399.93032230139,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/983704882"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1732,
#    "start_time": "Tue, 16 May 2017 08:47:10",
#    "total_calories": 197,
#    "tracking_mode": "outdoor",
#    "total_distance": 5560.4563963911,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/983486533"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1145,
#    "start_time": "Mon, 15 May 2017 12:12:42",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5799.03624628713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/982953586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1157,
#    "start_time": "Mon, 15 May 2017 07:40:40",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6146.10443694347,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/982791179"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 997,
#    "start_time": "Fri, 12 May 2017 13:15:44",
#    "total_calories": 159,
#    "tracking_mode": "outdoor",
#    "total_distance": 5844.7428641494,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/981236810"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1181,
#    "start_time": "Fri, 12 May 2017 07:33:09",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6080.95116871364,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/981074411"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1081,
#    "start_time": "Thu, 11 May 2017 12:17:38",
#    "total_calories": 163,
#    "tracking_mode": "outdoor",
#    "total_distance": 5729.95729085945,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/980742720"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1106,
#    "start_time": "Thu, 11 May 2017 07:34:52",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6008.50511794807,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/980533500"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2369,
#    "start_time": "Tue, 9 May 2017 13:37:33",
#    "total_calories": 203,
#    "tracking_mode": "outdoor",
#    "total_distance": 5970.05867350263,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/979587799"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2037,
#    "start_time": "Tue, 9 May 2017 07:18:08",
#    "total_calories": 193,
#    "tracking_mode": "outdoor",
#    "total_distance": 6190.0199079668,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/979308286"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1089,
#    "start_time": "Thu, 4 May 2017 12:13:05",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 5761.69009138035,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/976665485"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1255,
#    "start_time": "Thu, 4 May 2017 07:29:09",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6188.70012124096,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/976345577"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1124,
#    "start_time": "Wed, 3 May 2017 12:20:03",
#    "total_calories": 170,
#    "tracking_mode": "outdoor",
#    "total_distance": 5784.50584486548,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/975907857"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1337,
#    "start_time": "Wed, 3 May 2017 07:21:28",
#    "total_calories": 154,
#    "tracking_mode": "outdoor",
#    "total_distance": 6224.30698600637,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/975702948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1227,
#    "start_time": "Tue, 2 May 2017 12:23:54",
#    "total_calories": 169,
#    "tracking_mode": "outdoor",
#    "total_distance": 5784.76747737179,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/975260773"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1242,
#    "start_time": "Tue, 2 May 2017 07:22:43",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 6201.45968127213,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/975049820"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1099,
#    "start_time": "Thu, 27 Apr 2017 12:11:11",
#    "total_calories": 169,
#    "tracking_mode": "outdoor",
#    "total_distance": 5810.11751606895,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/972323598"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1296,
#    "start_time": "Thu, 27 Apr 2017 07:35:35",
#    "total_calories": 162,
#    "tracking_mode": "outdoor",
#    "total_distance": 6204.89122350621,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/972211895"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1120,
#    "start_time": "Wed, 26 Apr 2017 12:14:36",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 5790.87387050615,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/971839244"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1257,
#    "start_time": "Wed, 26 Apr 2017 07:47:45",
#    "total_calories": 148,
#    "tracking_mode": "outdoor",
#    "total_distance": 6095.7539061302,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/971664256"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1048,
#    "start_time": "Tue, 25 Apr 2017 12:44:52",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5414.19002764523,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/971256877"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1244,
#    "start_time": "Tue, 25 Apr 2017 07:25:36",
#    "total_calories": 155,
#    "tracking_mode": "outdoor",
#    "total_distance": 6142.63097037646,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/971118141"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1023,
#    "start_time": "Mon, 24 Apr 2017 12:44:38",
#    "total_calories": 159,
#    "tracking_mode": "outdoor",
#    "total_distance": 5796.21457810536,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/970745621"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1727,
#    "start_time": "Mon, 24 Apr 2017 08:14:05",
#    "total_calories": 196,
#    "tracking_mode": "outdoor",
#    "total_distance": 6253.00366131011,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/970558430"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 920,
#    "start_time": "Thu, 20 Apr 2017 12:44:07",
#    "total_calories": 154,
#    "tracking_mode": "outdoor",
#    "total_distance": 5488.60296259517,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/968373359"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1219,
#    "start_time": "Thu, 20 Apr 2017 07:28:23",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 6098.45926783777,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/968240153"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1160,
#    "start_time": "Wed, 19 Apr 2017 12:21:31",
#    "total_calories": 155,
#    "tracking_mode": "outdoor",
#    "total_distance": 5768.53146210135,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/967920264"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1106,
#    "start_time": "Wed, 19 Apr 2017 07:49:14",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6094.88269692644,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/967686440"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1146,
#    "start_time": "Tue, 18 Apr 2017 12:21:35",
#    "total_calories": 156,
#    "tracking_mode": "outdoor",
#    "total_distance": 5776.06172330338,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/967225275"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1366,
#    "start_time": "Tue, 18 Apr 2017 07:28:04",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6132.79672348382,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/967029131"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1089,
#    "start_time": "Mon, 17 Apr 2017 12:30:57",
#    "total_calories": 166,
#    "tracking_mode": "outdoor",
#    "total_distance": 5803.53683235887,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/966689592"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1240,
#    "start_time": "Mon, 17 Apr 2017 07:15:50",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6144.40790067876,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/966444941"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1422,
#    "start_time": "Thu, 13 Apr 2017 13:45:08",
#    "total_calories": 186,
#    "tracking_mode": "outdoor",
#    "total_distance": 6263.59575507788,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/964335495"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1139,
#    "start_time": "Thu, 13 Apr 2017 07:51:42",
#    "total_calories": 139,
#    "tracking_mode": "outdoor",
#    "total_distance": 6111.29098339216,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/964156871"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 4016,
#    "start_time": "Wed, 12 Apr 2017 12:17:37",
#    "total_calories": 380,
#    "tracking_mode": "outdoor",
#    "total_distance": 9557.77326300319,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/963760886"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2031,
#    "start_time": "Wed, 12 Apr 2017 07:39:17",
#    "total_calories": 188,
#    "tracking_mode": "outdoor",
#    "total_distance": 5487.13803269454,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/963616414"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1173,
#    "start_time": "Tue, 11 Apr 2017 12:51:58",
#    "total_calories": 170,
#    "tracking_mode": "outdoor",
#    "total_distance": 6285.1933488333,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/963195152"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2796,
#    "start_time": "Tue, 11 Apr 2017 07:38:17",
#    "total_calories": 204,
#    "tracking_mode": "outdoor",
#    "total_distance": 5220.66887003385,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/963021872"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2138,
#    "start_time": "Mon, 10 Apr 2017 07:25:19",
#    "total_calories": 220,
#    "tracking_mode": "outdoor",
#    "total_distance": 9533.34046397726,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/962406121"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 9093,
#    "start_time": "Fri, 7 Apr 2017 13:45:13",
#    "total_calories": 842,
#    "tracking_mode": "outdoor",
#    "total_distance": 14777.7232812607,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/960873625"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1224,
#    "start_time": "Fri, 7 Apr 2017 13:01:57",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 5369.03519201719,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/960800080"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1717,
#    "start_time": "Fri, 7 Apr 2017 07:28:52",
#    "total_calories": 177,
#    "tracking_mode": "outdoor",
#    "total_distance": 6268.99414633035,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/960676322"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1062,
#    "start_time": "Thu, 6 Apr 2017 13:05:23",
#    "total_calories": 140,
#    "tracking_mode": "outdoor",
#    "total_distance": 5383.60791086735,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/960424958"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1225,
#    "start_time": "Thu, 6 Apr 2017 07:32:34",
#    "total_calories": 141,
#    "tracking_mode": "outdoor",
#    "total_distance": 6102.48851718931,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/960173864"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1094,
#    "start_time": "Wed, 5 Apr 2017 12:49:08",
#    "total_calories": 137,
#    "tracking_mode": "outdoor",
#    "total_distance": 5402.77101276102,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/959785466"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1298,
#    "start_time": "Wed, 5 Apr 2017 07:16:02",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 6130.09183163074,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/959599038"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1138,
#    "start_time": "Tue, 4 Apr 2017 12:13:26",
#    "total_calories": 145,
#    "tracking_mode": "outdoor",
#    "total_distance": 5659.57715682041,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/959191539"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1219,
#    "start_time": "Tue, 4 Apr 2017 07:19:24",
#    "total_calories": 137,
#    "tracking_mode": "outdoor",
#    "total_distance": 6073.75481459306,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/958993092"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2544,
#    "start_time": "Mon, 3 Apr 2017 14:18:55",
#    "total_calories": 185,
#    "tracking_mode": "outdoor",
#    "total_distance": 4311.70946913724,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/958666225"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1177,
#    "start_time": "Mon, 3 Apr 2017 12:24:43",
#    "total_calories": 155,
#    "tracking_mode": "outdoor",
#    "total_distance": 5814.81937525709,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/958568955"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1231,
#    "start_time": "Mon, 3 Apr 2017 07:14:20",
#    "total_calories": 150,
#    "tracking_mode": "outdoor",
#    "total_distance": 6133.12758788262,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/958434365"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1110,
#    "start_time": "Fri, 31 Mar 2017 13:44:54",
#    "total_calories": 146,
#    "tracking_mode": "outdoor",
#    "total_distance": 5452.86644388047,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/956832278"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1292,
#    "start_time": "Fri, 31 Mar 2017 07:26:36",
#    "total_calories": 147,
#    "tracking_mode": "outdoor",
#    "total_distance": 6143.57283463604,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/956686607"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1102,
#    "start_time": "Wed, 29 Mar 2017 12:48:42",
#    "total_calories": 149,
#    "tracking_mode": "outdoor",
#    "total_distance": 5411.02142258913,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/955927398"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1250,
#    "start_time": "Wed, 29 Mar 2017 07:26:42",
#    "total_calories": 149,
#    "tracking_mode": "outdoor",
#    "total_distance": 6166.21434792163,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/955625417"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1185,
#    "start_time": "Tue, 28 Mar 2017 12:16:16",
#    "total_calories": 151,
#    "tracking_mode": "outdoor",
#    "total_distance": 5843.45413331713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/955163006"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1181,
#    "start_time": "Tue, 28 Mar 2017 07:21:22",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6147.91621223373,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/955056613"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1215,
#    "start_time": "Mon, 27 Mar 2017 12:13:40",
#    "total_calories": 172,
#    "tracking_mode": "outdoor",
#    "total_distance": 5776.37124524035,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/954779927"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1165,
#    "start_time": "Mon, 27 Mar 2017 07:23:44",
#    "total_calories": 397,
#    "tracking_mode": "outdoor",
#    "total_distance": 6215.31966441684,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/954403419"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1170,
#    "start_time": "Sat, 25 Mar 2017 11:53:10",
#    "total_calories": 81,
#    "tracking_mode": "outdoor",
#    "total_distance": 1256.55937646671,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/953431739"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1939,
#    "start_time": "Fri, 24 Mar 2017 09:06:11",
#    "total_calories": 689,
#    "tracking_mode": "outdoor",
#    "total_distance": 2473.81966221175,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/952818602"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1181,
#    "start_time": "Thu, 23 Mar 2017 12:21:22",
#    "total_calories": 164,
#    "tracking_mode": "outdoor",
#    "total_distance": 5949.37511979543,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/952356241"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1324,
#    "start_time": "Thu, 23 Mar 2017 07:17:11",
#    "total_calories": 150,
#    "tracking_mode": "outdoor",
#    "total_distance": 6092.70326072207,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/952221797"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1135,
#    "start_time": "Wed, 22 Mar 2017 12:16:25",
#    "total_calories": 159,
#    "tracking_mode": "outdoor",
#    "total_distance": 5809.7526561037,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/951835521"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1331,
#    "start_time": "Wed, 22 Mar 2017 07:27:36",
#    "total_calories": 165,
#    "tracking_mode": "outdoor",
#    "total_distance": 6173.13959683879,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/951705339"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1013,
#    "start_time": "Tue, 21 Mar 2017 13:14:27",
#    "total_calories": 137,
#    "tracking_mode": "outdoor",
#    "total_distance": 5241.59622973536,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/951302785"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1255,
#    "start_time": "Tue, 21 Mar 2017 07:29:01",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 6100.94951116161,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/951142045"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1231,
#    "start_time": "Mon, 20 Mar 2017 12:29:09",
#    "total_calories": 167,
#    "tracking_mode": "outdoor",
#    "total_distance": 5752.56544714797,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/950739888"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1368,
#    "start_time": "Mon, 20 Mar 2017 07:27:58",
#    "total_calories": 143,
#    "tracking_mode": "outdoor",
#    "total_distance": 6241.93061205645,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/950614247"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3898,
#    "start_time": "Sat, 18 Mar 2017 11:56:07",
#    "total_calories": 252,
#    "tracking_mode": "outdoor",
#    "total_distance": 1607.37436262857,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/949667031"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1814,
#    "start_time": "Fri, 17 Mar 2017 13:24:18",
#    "total_calories": 280,
#    "tracking_mode": "outdoor",
#    "total_distance": 6833.63008121848,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/949194303"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1286,
#    "start_time": "Fri, 17 Mar 2017 07:17:38",
#    "total_calories": 138,
#    "tracking_mode": "outdoor",
#    "total_distance": 6134.5887920694,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/949044196"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 614,
#    "start_time": "Thu, 16 Mar 2017 16:58:34",
#    "total_calories": 57,
#    "tracking_mode": "outdoor",
#    "total_distance": 1925.60933328206,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/948816948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2395,
#    "start_time": "Thu, 16 Mar 2017 12:24:48",
#    "total_calories": 390,
#    "tracking_mode": "outdoor",
#    "total_distance": 9733.72455067262,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/948695024"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1380,
#    "start_time": "Thu, 16 Mar 2017 07:18:32",
#    "total_calories": 149,
#    "tracking_mode": "outdoor",
#    "total_distance": 5784.89254009878,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/948550492"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1466,
#    "start_time": "Wed, 15 Mar 2017 12:54:09",
#    "total_calories": 149,
#    "tracking_mode": "outdoor",
#    "total_distance": 5408.97609903985,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/948550472"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1571,
#    "start_time": "Wed, 15 Mar 2017 07:27:36",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 6219.80625497748,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/948053143"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 718,
#    "start_time": "Tue, 14 Mar 2017 16:44:51",
#    "total_calories": 75,
#    "tracking_mode": "outdoor",
#    "total_distance": 3186.50768162342,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/947792586"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1675,
#    "start_time": "Tue, 14 Mar 2017 12:42:29",
#    "total_calories": 178,
#    "tracking_mode": "outdoor",
#    "total_distance": 6436.58844717528,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/947673675"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1364,
#    "start_time": "Tue, 14 Mar 2017 07:29:18",
#    "total_calories": 140,
#    "tracking_mode": "outdoor",
#    "total_distance": 6129.88617548276,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/947550866"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1571,
#    "start_time": "Mon, 13 Mar 2017 12:22:32",
#    "total_calories": 165,
#    "tracking_mode": "outdoor",
#    "total_distance": 5742.84090264129,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/947158011"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 725,
#    "start_time": "Mon, 13 Mar 2017 07:37:39",
#    "total_calories": 195,
#    "tracking_mode": "outdoor",
#    "total_distance": 4675.9492354458,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/947145706"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 10423,
#    "start_time": "Fri, 10 Mar 2017 13:46:12",
#    "total_calories": 871,
#    "tracking_mode": "outdoor",
#    "total_distance": 11115.6928490891,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/945649023"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1681,
#    "start_time": "Fri, 10 Mar 2017 07:19:42",
#    "total_calories": 158,
#    "tracking_mode": "outdoor",
#    "total_distance": 6176.70235310102,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/945430472"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1311,
#    "start_time": "Thu, 9 Mar 2017 12:22:35",
#    "total_calories": 153,
#    "tracking_mode": "outdoor",
#    "total_distance": 5797.95218057037,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/945061620"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1584,
#    "start_time": "Thu, 9 Mar 2017 07:29:31",
#    "total_calories": 152,
#    "tracking_mode": "outdoor",
#    "total_distance": 6147.42827100742,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Cycling",
#    "uri": "/fitnessActivities/944935090"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1789,
#    "start_time": "Mon, 20 Feb 2017 05:40:38",
#    "total_calories": 474,
#    "tracking_mode": "outdoor",
#    "total_distance": 5946.00640149185,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/936614445"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2388,
#    "start_time": "Tue, 14 Feb 2017 05:50:34",
#    "total_calories": 445,
#    "tracking_mode": "outdoor",
#    "total_distance": 5919.99555156505,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/933583716"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1717,
#    "start_time": "Sat, 28 Jan 2017 16:32:16",
#    "total_calories": 452,
#    "tracking_mode": "outdoor",
#    "total_distance": 5806.37373337041,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/925910560"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2010,
#    "start_time": "Mon, 23 Jan 2017 06:35:55",
#    "total_calories": 465,
#    "tracking_mode": "outdoor",
#    "total_distance": 6008.50993024907,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/923464813"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 6552,
#    "start_time": "Fri, 16 Dec 2016 13:04:25",
#    "total_calories": 407,
#    "tracking_mode": "outdoor",
#    "total_distance": 4875.07966067005,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/908047763"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3603,
#    "start_time": "Mon, 12 Dec 2016 14:14:01",
#    "total_calories": 379,
#    "tracking_mode": "outdoor",
#    "total_distance": 7773.93738137742,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/907093870"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1849,
#    "start_time": "Sat, 10 Dec 2016 10:38:44",
#    "total_calories": 110,
#    "tracking_mode": "outdoor",
#    "total_distance": 1818.40197190632,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/906057975"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1777,
#    "start_time": "Sat, 10 Dec 2016 09:21:21",
#    "total_calories": 162,
#    "tracking_mode": "outdoor",
#    "total_distance": 2530.61673356708,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
# ...
#    "duration": 3017,
#    "start_time": "Fri, 19 Aug 2016 11:27:59",
#    "total_calories": 210,
#    "tracking_mode": "outdoor",
#    "total_distance": 3358.48742727089,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/847529088"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2367,
#    "start_time": "Fri, 19 Aug 2016 09:18:05",
#    "total_calories": 324,
#    "tracking_mode": "outdoor",
#    "total_distance": 3093.12656949486,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/847476808"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2036,
#    "start_time": "Sun, 14 Aug 2016 14:58:01",
#    "total_calories": 228,
#    "tracking_mode": "outdoor",
#    "total_distance": 3470.17075871582,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/844532207"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 794,
#    "start_time": "Sun, 14 Aug 2016 14:24:10",
#    "total_calories": 182,
#    "tracking_mode": "outdoor",
#    "total_distance": 2418.75009664913,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/844501490"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1109,
#    "start_time": "Sun, 31 Jul 2016 12:30:27",
#    "total_calories": 261,
#    "tracking_mode": "outdoor",
#    "total_distance": 3526.11015333881,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/835895196"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2982,
#    "start_time": "Sun, 31 Jul 2016 11:39:30",
#    "total_calories": 193,
#    "tracking_mode": "outdoor",
#    "total_distance": 2272.81277948962,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/835895188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2271,
#    "start_time": "Sun, 19 Jun 2016 15:54:04",
#    "total_calories": 420,
#    "tracking_mode": "outdoor",
#    "total_distance": 5850.37512732216,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/810514835"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8106,
#    "start_time": "Sat, 18 Jun 2016 07:13:03",
#    "total_calories": 781,
#    "tracking_mode": "outdoor",
#    "total_distance": 7463.43806205611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687187"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2563,
#    "start_time": "Sat, 18 Jun 2016 06:08:27",
#    "total_calories": 373,
#    "tracking_mode": "outdoor",
#    "total_distance": 4123.84686293397,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/809687157"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2087,
#    "start_time": "Wed, 15 Jun 2016 06:02:52",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 6129.74843199285,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/807853214"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 789,
#    "start_time": "Mon, 13 Jun 2016 17:06:40",
#    "total_calories": 59,
#    "tracking_mode": "outdoor",
#    "total_distance": 615.714617224684,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806924800"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 606,
#    "start_time": "Mon, 13 Jun 2016 15:03:52",
#    "total_calories": 299,
#    "tracking_mode": "outdoor",
#    "total_distance": 549.757560743894,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806901919"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1594,
#    "start_time": "Mon, 13 Jun 2016 05:50:21",
#    "total_calories": 450,
#    "tracking_mode": "outdoor",
#    "total_distance": 5756.30000050235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/806547477"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1634,
#    "start_time": "Fri, 10 Jun 2016 05:58:37",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5797.34713357958,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/804841603"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2209,
#    "start_time": "Mon, 23 May 2016 06:08:33",
#    "total_calories": 429,
#    "tracking_mode": "outdoor",
#    "total_distance": 5884.05329187354,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/793442865"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1661,
#    "start_time": "Mon, 16 May 2016 05:54:44",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5814.90671752075,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/788769831"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1862,
#    "start_time": "Sat, 14 May 2016 06:09:23",
#    "total_calories": 451,
#    "tracking_mode": "outdoor",
#    "total_distance": 5835.27134531731,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/787533188"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Thu, 5 May 2016 05:43:14",
#    "total_calories": 453,
#    "tracking_mode": "outdoor",
#    "total_distance": 5786.59705963899,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/781785039"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1812,
#    "start_time": "Tue, 3 May 2016 05:49:35",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5887.67166192717,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/780351088"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1837,
#    "start_time": "Wed, 20 Apr 2016 05:51:15",
#    "total_calories": 456,
#    "tracking_mode": "outdoor",
#    "total_distance": 5734.59075257851,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/772361130"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 450,
#    "start_time": "Mon, 18 Apr 2016 06:19:21",
#    "total_calories": 63,
#    "tracking_mode": "outdoor",
#    "total_distance": 1047.1593087184,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943625"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1586,
#    "start_time": "Mon, 18 Apr 2016 05:50:48",
#    "total_calories": 565,
#    "tracking_mode": "outdoor",
#    "total_distance": 5782.77043463861,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/770943610"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1631,
#    "start_time": "Mon, 11 Apr 2016 05:23:04",
#    "total_calories": 458,
#    "tracking_mode": "outdoor",
#    "total_distance": 5895.7589925569,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/766282546"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 8038,
#    "start_time": "Thu, 7 Apr 2016 07:34:36",
#    "total_calories": 660,
#    "tracking_mode": "outdoor",
#    "total_distance": 3698.48518715936,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/764018100"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2365,
#    "start_time": "Tue, 29 Mar 2016 05:38:59",
#    "total_calories": 435,
#    "tracking_mode": "outdoor",
#    "total_distance": 5990.80532600518,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/759716642"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1640,
#    "start_time": "Wed, 23 Mar 2016 06:08:51",
#    "total_calories": 454,
#    "tracking_mode": "outdoor",
#    "total_distance": 5749.38159142367,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/755079850"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1682,
#    "start_time": "Mon, 21 Mar 2016 05:57:29",
#    "total_calories": 455,
#    "tracking_mode": "outdoor",
#    "total_distance": 5789.02666560211,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753860205"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 261,
#    "start_time": "Sun, 20 Mar 2016 17:04:57",
#    "total_calories": 49,
#    "tracking_mode": "outdoor",
#    "total_distance": 779.129464701952,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/753646484"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1636,
#    "start_time": "Mon, 14 Mar 2016 05:52:20",
#    "total_calories": 447,
#    "tracking_mode": "outdoor",
#    "total_distance": 5674.95440749925,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/749797852"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 899,
#    "start_time": "Tue, 8 Mar 2016 13:22:25",
#    "total_calories": 75,
#    "tracking_mode": "outdoor",
#    "total_distance": 1213.07733323399,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/747371294"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1692,
#    "start_time": "Mon, 7 Mar 2016 06:03:09",
#    "total_calories": 462,
#    "tracking_mode": "outdoor",
#    "total_distance": 5838.98572316034,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745796497"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3506,
#    "start_time": "Sun, 6 Mar 2016 13:53:27",
#    "total_calories": 253,
#    "tracking_mode": "outdoor",
#    "total_distance": 3927.28664301713,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656183"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1567,
#    "start_time": "Sun, 6 Mar 2016 11:23:33",
#    "total_calories": 101,
#    "tracking_mode": "outdoor",
#    "total_distance": 1593.60881674515,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/745656175"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1821,
#    "start_time": "Thu, 3 Mar 2016 05:52:24",
#    "total_calories": 489,
#    "tracking_mode": "outdoor",
#    "total_distance": 6154.28759223911,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743736231"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 2931,
#    "start_time": "Wed, 2 Mar 2016 18:26:34",
#    "total_calories": 105,
#    "tracking_mode": "outdoor",
#    "total_distance": 844.110303054361,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/743518140"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1917,
#    "start_time": "Mon, 29 Feb 2016 06:05:33",
#    "total_calories": 467,
#    "tracking_mode": "outdoor",
#    "total_distance": 5805.83679757534,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742107339"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 3371,
#    "start_time": "Sun, 28 Feb 2016 10:41:56",
#    "total_calories": 205,
#    "tracking_mode": "outdoor",
#    "total_distance": 3016.57855675634,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/742025830"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1797,
#    "start_time": "Mon, 22 Feb 2016 06:09:37",
#    "total_calories": 366,
#    "tracking_mode": "outdoor",
#    "total_distance": 4815.5226769624,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/738351372"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1869,
#    "start_time": "Mon, 15 Feb 2016 05:55:11",
#    "total_calories": 353,
#    "tracking_mode": "outdoor",
#    "total_distance": 4555.47243393235,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/734684880"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1478,
#    "start_time": "Wed, 4 Nov 2015 06:07:28",
#    "total_calories": 238,
#    "tracking_mode": "outdoor",
#    "total_distance": 3272.86475609347,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/695107893"
#   },
#   {
#    "utc_offset": -2,
#    "duration": 1390,
#    "start_time": "Tue, 27 Oct 2015 05:57:52",
#    "total_calories": 357,
#    "tracking_mode": "outdoor",
#    "total_distance": 4675.89620892755,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/682306939"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1358,
#    "start_time": "Fri, 25 Sep 2015 06:03:30",
#    "total_calories": 365,
#    "tracking_mode": "outdoor",
#    "total_distance": 4683.06656215611,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/662964078"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1382,
#    "start_time": "Tue, 22 Sep 2015 06:05:45",
#    "total_calories": 361,
#    "tracking_mode": "outdoor",
#    "total_distance": 4655.54963372923,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/660961272"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1458.45,
#    "start_time": "Mon, 25 May 2015 05:40:07",
#    "total_calories": 362,
#    "tracking_mode": "outdoor",
#    "total_distance": 4703.8352331533,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/577596948"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1417.324,
#    "start_time": "Thu, 30 Apr 2015 05:56:58",
#    "total_calories": 360,
#    "tracking_mode": "outdoor",
#    "total_distance": 4672.89007690554,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/559747998"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1397.167,
#    "start_time": "Wed, 22 Apr 2015 05:53:43",
#    "total_calories": 520,
#    "tracking_mode": "outdoor",
#    "total_distance": 4690.98068548032,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/554014359"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1500,
#    "start_time": "Mon, 20 Apr 2015 05:40:00",
#    "total_calories": 343,
#    "tracking_mode": "outdoor",
#    "total_distance": 4498.63606169824,
#    "entry_mode": "Web",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/553679343"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 1436.981,
#    "start_time": "Sat, 15 Mar 2014 22:15:59",
#    "total_calories": 130,
#    "tracking_mode": "outdoor",
#    "total_distance": 1984.280937576,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268589"
#   },
#   {
#    "utc_offset": -3,
#    "duration": 839.407,
#    "start_time": "Sat, 15 Mar 2014 18:25:50",
#    "total_calories": 65,
#    "tracking_mode": "outdoor",
#    "total_distance": 986.246059611153,
#    "entry_mode": "API",
#    "has_path": true,
#    "source": "RunKeeper",
#    "type": "Running",
#    "uri": "/fitnessActivities/439268582"
#   }
#  ]
# }

# %% [markdown]
# ## JSON to Data Frame conversion
#
# In order to have a better data manipulation, in the next cell we perform a conversion of importe in json format from API to pandas data frame

# %%
# Perform a conversion from JSON to Data Frame
api_df = json_normalize(api_content['items'])

# Converts the duration from seconds to minutes
api_df['duration'] = api_df['duration']/60
api_df['duration'] = api_df['duration'].round(2);

# Round the distance
api_df['total_distance'] = api_df['total_distance'].round(2);

api_df
# Out:
#      duration entry_mode has_path     source                 start_time  \
# 0       17.28        API     True  RunKeeper  Fri, 23 Jun 2017 12:40:11
# 1       19.00        API     True  RunKeeper  Fri, 23 Jun 2017 07:50:54
# 2       21.42        API     True  RunKeeper  Thu, 22 Jun 2017 12:41:16
# 3       20.58        API     True  RunKeeper  Thu, 22 Jun 2017 07:37:35
# 4       19.30        API     True  RunKeeper  Tue, 20 Jun 2017 12:35:21
# 5       19.88        API     True  RunKeeper  Tue, 20 Jun 2017 07:30:08
# 6       17.02        API     True  RunKeeper  Mon, 19 Jun 2017 12:36:20
# 7       23.08        API     True  RunKeeper  Mon, 19 Jun 2017 07:43:02
# 8       50.43        API     True  RunKeeper  Sat, 17 Jun 2017 14:47:50
# 9       18.17        API     True  RunKeeper  Wed, 14 Jun 2017 13:26:09
# 10      18.82        API     True  RunKeeper  Wed, 14 Jun 2017 07:53:31
# 11      23.17        API     True  RunKeeper  Tue, 13 Jun 2017 12:48:45
# 12      19.30        API     True  RunKeeper  Tue, 13 Jun 2017 07:42:39
# 13      16.75        API     True  RunKeeper  Mon, 12 Jun 2017 12:12:13
# 14      18.48        API     True  RunKeeper  Mon, 12 Jun 2017 07:29:08
# 15      15.23        API     True  RunKeeper   Fri, 9 Jun 2017 13:47:21
# 16      18.82        API     True  RunKeeper   Fri, 9 Jun 2017 07:58:28
# 17      17.03        API     True  RunKeeper   Thu, 8 Jun 2017 13:01:53
# 18      19.70        API     True  RunKeeper   Thu, 8 Jun 2017 07:51:49
# 19      17.13        API     True  RunKeeper   Wed, 7 Jun 2017 12:16:18
# 20      18.77        API     True  RunKeeper   Wed, 7 Jun 2017 07:55:39
# 21      16.40        API     True  RunKeeper   Tue, 6 Jun 2017 12:47:04
# 22      18.50        API     True  RunKeeper   Tue, 6 Jun 2017 07:30:32
# 23      15.82        API     True  RunKeeper   Mon, 5 Jun 2017 12:20:58
# 24      19.32        API     True  RunKeeper   Mon, 5 Jun 2017 07:28:30
# 25      35.62        API     True  RunKeeper   Fri, 2 Jun 2017 13:43:00
# 26      18.30        API     True  RunKeeper   Fri, 2 Jun 2017 07:43:33
# 27      17.70        API     True  RunKeeper   Thu, 1 Jun 2017 13:05:46
# 28      18.75        API     True  RunKeeper   Thu, 1 Jun 2017 07:43:24
# 29      17.18        API     True  RunKeeper  Wed, 31 May 2017 13:05:39
# ..        ...        ...      ...        ...                        ...
# 215     30.62        API     True  RunKeeper  Wed, 20 Apr 2016 05:51:15
# 216      7.50        API     True  RunKeeper  Mon, 18 Apr 2016 06:19:21
# 217     26.43        API     True  RunKeeper  Mon, 18 Apr 2016 05:50:48
# 218     27.18        API     True  RunKeeper  Mon, 11 Apr 2016 05:23:04
# 219    133.97        API     True  RunKeeper   Thu, 7 Apr 2016 07:34:36
# 220     39.42        API     True  RunKeeper  Tue, 29 Mar 2016 05:38:59
# 221     27.33        API     True  RunKeeper  Wed, 23 Mar 2016 06:08:51
# 222     28.03        API     True  RunKeeper  Mon, 21 Mar 2016 05:57:29
# 223      4.35        API     True  RunKeeper  Sun, 20 Mar 2016 17:04:57
# 224     27.27        API     True  RunKeeper  Mon, 14 Mar 2016 05:52:20
# 225     14.98        API     True  RunKeeper   Tue, 8 Mar 2016 13:22:25
# 226     28.20        API     True  RunKeeper   Mon, 7 Mar 2016 06:03:09
# 227     58.43        API     True  RunKeeper   Sun, 6 Mar 2016 13:53:27
# 228     26.12        API     True  RunKeeper   Sun, 6 Mar 2016 11:23:33
# 229     30.35        API     True  RunKeeper   Thu, 3 Mar 2016 05:52:24
# 230     48.85        API     True  RunKeeper   Wed, 2 Mar 2016 18:26:34
# 231     31.95        API     True  RunKeeper  Mon, 29 Feb 2016 06:05:33
# 232     56.18        API     True  RunKeeper  Sun, 28 Feb 2016 10:41:56
# 233     29.95        API     True  RunKeeper  Mon, 22 Feb 2016 06:09:37
# 234     31.15        API     True  RunKeeper  Mon, 15 Feb 2016 05:55:11
# 235     24.63        API     True  RunKeeper   Wed, 4 Nov 2015 06:07:28
# 236     23.17        API     True  RunKeeper  Tue, 27 Oct 2015 05:57:52
# 237     22.63        API     True  RunKeeper  Fri, 25 Sep 2015 06:03:30
# 238     23.03        API     True  RunKeeper  Tue, 22 Sep 2015 06:05:45
# 239     24.31        API     True  RunKeeper  Mon, 25 May 2015 05:40:07
# 240     23.62        API     True  RunKeeper  Thu, 30 Apr 2015 05:56:58
# 241     23.29        API     True  RunKeeper  Wed, 22 Apr 2015 05:53:43
# 242     25.00        Web     True  RunKeeper  Mon, 20 Apr 2015 05:40:00
# 243     23.95        API     True  RunKeeper  Sat, 15 Mar 2014 22:15:59
# 244     13.99        API     True  RunKeeper  Sat, 15 Mar 2014 18:25:50
#
#      total_calories  total_distance tracking_mode     type  \
# 0               148         5345.75       outdoor  Cycling
# 1               143         6081.16       outdoor  Cycling
# 2               184         6589.62       outdoor  Cycling
# 3               147         6162.94       outdoor  Cycling
# 4               156         5382.67       outdoor  Cycling
# 5               144         6086.99       outdoor  Cycling
# 6               141         5389.12       outdoor  Cycling
# 7               156         6143.74       outdoor  Cycling
# 8               310         8859.43       outdoor  Cycling
# 9               153         5753.60       outdoor  Cycling
# 10              144         6045.11       outdoor  Cycling
# 11              189         6607.60       outdoor  Cycling
# 12              150         6090.69       outdoor  Cycling
# 13              166         5779.66       outdoor  Cycling
# 14              145         6114.83       outdoor  Cycling
# 15              164         5766.43       outdoor  Cycling
# 16              144         6105.27       outdoor  Cycling
# 17              163         5783.29       outdoor  Cycling
# 18              145         6181.86       outdoor  Cycling
# 19              154         5759.41       outdoor  Cycling
# 20              141         6096.46       outdoor  Cycling
# 21              157         5978.89       outdoor  Cycling
# 22              142         6111.35       outdoor  Cycling
# 23              157         5711.36       outdoor  Cycling
# 24              143         6073.79       outdoor  Cycling
# 25              351        10489.03       outdoor  Cycling
# 26              143         6063.58       outdoor  Cycling
# 27              145         5378.71       outdoor  Cycling
# 28              142         6095.87       outdoor  Cycling
# 29              144         5392.26       outdoor  Cycling
# ..              ...             ...           ...      ...
# 215             456         5734.59       outdoor  Running
# 216              63         1047.16       outdoor  Running
# 217             565         5782.77       outdoor  Running
# 218             458         5895.76       outdoor  Running
# 219             660         3698.49       outdoor  Running
# 220             435         5990.81       outdoor  Running
# 221             454         5749.38       outdoor  Running
# 222             455         5789.03       outdoor  Running
# 223              49          779.13       outdoor  Running
# 224             447         5674.95       outdoor  Running
# 225              75         1213.08       outdoor  Running
# 226             462         5838.99       outdoor  Running
# 227             253         3927.29       outdoor  Running
# 228             101         1593.61       outdoor  Running
# 229             489         6154.29       outdoor  Running
# 230             105          844.11       outdoor  Running
# 231             467         5805.84       outdoor  Running
# 232             205         3016.58       outdoor  Running
# 233             366         4815.52       outdoor  Running
# 234             353         4555.47       outdoor  Running
# 235             238         3272.86       outdoor  Running
# 236             357         4675.90       outdoor  Running
# 237             365         4683.07       outdoor  Running
# 238             361         4655.55       outdoor  Running
# 239             362         4703.84       outdoor  Running
# 240             360         4672.89       outdoor  Running
# 241             520         4690.98       outdoor  Running
# 242             343         4498.64       outdoor  Running
# 243             130         1984.28       outdoor  Running
# 244              65          986.25       outdoor  Running
#
#                                uri  utc_offset
# 0    /fitnessActivities/1005956310          -3
# 1    /fitnessActivities/1005843765          -3
# 2    /fitnessActivities/1005535586          -3
# 3    /fitnessActivities/1005303953          -3
# 4    /fitnessActivities/1004255363          -3
# 5    /fitnessActivities/1004088987          -3
# 6    /fitnessActivities/1003621881          -3
# 7    /fitnessActivities/1003493993          -3
# 8    /fitnessActivities/1002663916          -3
# 9    /fitnessActivities/1000879327          -3
# 10   /fitnessActivities/1000713723          -3
# 11   /fitnessActivities/1000444019          -3
# 12   /fitnessActivities/1000067931          -3
# 13    /fitnessActivities/999721058          -3
# 14    /fitnessActivities/999458777          -3
# 15    /fitnessActivities/997878707          -3
# 16    /fitnessActivities/997716950          -3
# 17    /fitnessActivities/997294049          -3
# 18    /fitnessActivities/997151351          -3
# 19    /fitnessActivities/996701562          -3
# 20    /fitnessActivities/996573146          -3
# 21    /fitnessActivities/996225220          -3
# 22    /fitnessActivities/995999970          -3
# 23    /fitnessActivities/995698428          -3
# 24    /fitnessActivities/995399416          -3
# 25    /fitnessActivities/993855342          -3
# 26    /fitnessActivities/993644394          -3
# 27    /fitnessActivities/993644390          -3
# 28    /fitnessActivities/993050883          -3
# 29    /fitnessActivities/992607843          -3
# ..                             ...         ...
# 215   /fitnessActivities/772361130          -3
# 216   /fitnessActivities/770943625          -3
# 217   /fitnessActivities/770943610          -3
# 218   /fitnessActivities/766282546          -3
# 219   /fitnessActivities/764018100          -3
# 220   /fitnessActivities/759716642          -3
# 221   /fitnessActivities/755079850          -3
# 222   /fitnessActivities/753860205          -3
# 223   /fitnessActivities/753646484          -3
# 224   /fitnessActivities/749797852          -3
# 225   /fitnessActivities/747371294          -3
# 226   /fitnessActivities/745796497          -3
# 227   /fitnessActivities/745656183          -3
# 228   /fitnessActivities/745656175          -3
# 229   /fitnessActivities/743736231          -3
# 230   /fitnessActivities/743518140          -3
# 231   /fitnessActivities/742107339          -3
# 232   /fitnessActivities/742025830          -3
# 233   /fitnessActivities/738351372          -3
# 234   /fitnessActivities/734684880          -3
# 235   /fitnessActivities/695107893          -2
# 236   /fitnessActivities/682306939          -2
# 237   /fitnessActivities/662964078          -3
# 238   /fitnessActivities/660961272          -3
# 239   /fitnessActivities/577596948          -3
# 240   /fitnessActivities/559747998          -3
# 241   /fitnessActivities/554014359          -3
# 242   /fitnessActivities/553679343          -3
# 243   /fitnessActivities/439268589          -3
# 244   /fitnessActivities/439268582          -3
#
# [245 rows x 11 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to visualize the data into an excel file, the cell bellow is responsible for exporting the data.

# %%
# Export the new dataSet to csv
api_df.to_csv('dataSource.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # Statistic section
#
# #### Here in this section, we'll handle the statistics infos.
#
# #### The idea is to use the ***top-down analysis***, from the more generic context to the specific one

# %% [markdown]
# ## 1) Exercises summary

# %% [markdown]
# ## 2) Activites overall times

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,hover,save'

# Make a bar chart: p
p = Bar(api_df, values='duration', label='type', agg='mean', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            plot_width=750, plot_height=500, tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity overall time'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Average time:',' @height')]

# Configure visual properties on a plot's title attribute
p.title.text = "Overall time by activity type"
p.title.align = "center"
p.title.text_font_size = "25px"

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e416e5b-4c42-45a8-b75d-8801da4d4b90">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3070c3b6-a1ff-4e47-8b15-663d312d0605"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3070c3b6-a1ff-4e47-8b15-663d312d0605").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3070c3b6-a1ff-4e47-8b15-663d312d0605");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3070c3b6-a1ff-4e47-8b15-663d312d0605' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c44ccb84-1664-4c0c-b43e-e0275f94f76f":{"roots":{"references":[{"attributes":{"label":{"value":"Cycling"},"renderers":[{"id":"3ca19a34-248a-45e5-bd02-88a9cff4b946","type":"GlyphRenderer"}]},"id":"9d3e811a-7991-4d97-8e04-641519a338d6","type":"LegendItem"},{"attributes":{"callback":null,"factors":["Cycling","Running"]},"id":"f06ba464-a5a0-4466-a9fa-23d867adb887","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Running"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[34.752777777777766],"label":[{"type":"Running"}],"line_alpha":[1.0],"line_color":["white"],"type":["Running"],"width":[0.8],"x":["Running"],"y":[17.376388888888883]}},"id":"cd3aba32-2b55-48ac-a415-656d63dffce3","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5f1e8a1-b4e1-425e-bda4-0794af4661cf","type":"BoxZoomTool"},{"id":"434597c4-75dc-4c86-9d7c-3c498b41893b","type":"BoxSelectTool"},{"id":"ebfd89e1-64ca-4e43-ad44-05006ba13943","type":"CrosshairTool"},{"id":"b3ae9ed4-7d4c-4100-8f79-97975db0bf2c","type":"ResizeTool"},{"id":"5f7a0308-2bf1-41b0-8280-320e6dc8f0f8","type":"ResetTool"},{"id":"f16088bf-be0e-402c-a774-02e749c66b1b","type":"HoverTool"},{"id":"d178c58a-3809-47e4-8433-6ee3b0e19538","type":"SaveTool"}]},"id":"93e86fe7-d699-46c1-85ca-bab8c32c14ed","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"f74dce24-4640-4704-9b0f-ee025f95d654","subtype":"Chart","type":"Plot"},"ticker":{"id":"0d51947b-c289-4474-8c4e-3af209afdc77","type":"BasicTicker"}},"id":"4cf4c9b2-92a0-4af7-9a19-b16671845866","type":"Grid"},{"attributes":{"align":"center","plot":null,"text":"Overall time by activity type","text_font_size":{"value":"25px"}},"id":"4e6fa759-d62b-4cdb-ba2d-f9490be2d1bc","type":"Title"},{"attributes":{},"id":"c3d7fc7b-370e-4bbb-a2ef-2997e75e5743","type":"CategoricalTickFormatter"},{"attributes":{},"id":"0d51947b-c289-4474-8c4e-3af209afdc77","type":"BasicTicker"},{"attributes":{"axis_label":"Activity overall time","formatter":{"id":"0fb67b44-b019-4234-8106-500ee9f90c0c","type":"BasicTickFormatter"},"plot":{"id":"f74dce24-4640-4704-9b0f-ee025f95d654","subtype":"Chart","type":"Plot"},"ticker":{"id":"0d51947b-c289-4474-8c4e-3af209afdc77","type":"BasicTicker"}},"id":"5eb94d8d-7ebd-4f64-803d-fbd9b2b3580e","type":"LinearAxis"},{"attributes":{},"id":"3279623f-96d8-4f0d-a96f-388d6794797f","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dfceed10-6961-4d54-bdb4-1d21d9382a23","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"02aa0f05-3696-4735-9f28-1d74bdaff163","type":"ColumnDataSource"},"glyph":{"id":"b0bb17ef-1f56-4d0d-98dd-76139ee552a3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3ca19a34-248a-45e5-bd02-88a9cff4b946","type":"GlyphRenderer"},{"attributes":{"axis_label":"Activity type","formatter":{"id":"c3d7fc7b-370e-4bbb-a2ef-2997e75e5743","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"f74dce24-4640-4704-9b0f-ee025f95d654","subtype":"Chart","type":"Plot"},"ticker":{"id":"2b1901c1-512f-4adb-b223-9d139b7123be","type":"CategoricalTicker"}},"id":"18b3fff8-fc0f-44e7-b5aa-f8a68848f2e0","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"f74dce24-4640-4704-9b0f-ee025f95d654","subtype":"Chart","type":"Plot"}},"id":"d178c58a-3809-47e4-8433-6ee3b0e19538","type":"SaveTool"},{"attributes":{"callback":null,"overlay":{"id":"dfceed10-6961-4d54-bdb4-1d21d9382a23","type":"BoxAnnotation"},"plot":{"id":"f74dce24-4640-4704-9b0f-ee025f95d654","subtype":"Chart"," ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## 2) Activites calories burning

# %%
# =================================================================================
# Data selection
# =================================================================================

# =================================================================================
# Chart plotting
# =================================================================================

# Tools
TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

# Make a bar chart: p
bar = Bar(api_df, values='total_calories', label='type', agg='sum', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Make a box plot: unit 1
box = BoxPlot(api_df, values='total_calories', label='type', color='type',
            legend='bottom_right', background_fill_color="#E8DDCB",
            tools=TOOLS)

# Set the y and x axis label
p.yaxis.axis_label= 'Activity total calories'
p.xaxis.axis_label= 'Activity type'

# Set hover to bars
hover = p.select(dict(type=HoverTool))
hover.tooltips = [('Tipo de atividade', '@type'),('Total calories:',' @height')]

# Configure visual properties on a plot's title attribute
bar.title.text = "Total calories burned by activity type"
bar.title.align = "center"
bar.title.text_font_size = "25px"

box.title.text = "Total calories burned by activity type"
box.title.align = "center"
box.title.text_font_size = "25px"

# Create a list containing plots
row1 = [bar,box]

# Create a gridplot using row1 and row2: layout
layout = gridplot([row1],sizing_mode='scale_width', plot_height=750)

# Call the output_notebook() 
output_notebook()
show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0ec8ee6c-a41a-47f1-a5db-43d48988eff5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0915c2e5-efde-4852-8872-22527e19a214"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0915c2e5-efde-4852-8872-22527e19a214").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0915c2e5-efde-4852-8872-22527e19a214");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0915c2e5-efde-4852-8872-22527e19a214' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9c813b1a-c950-46b5-af13-46e3f0fc2aa3":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bf5d6157-3203-4110-ab11-4bcdc61671d5","type":"BoxAnnotation"},{"attributes":{},"id":"56324e26-8d0b-425b-b34e-e7910b0f1ef3","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"4a6e6a26-31d8-4270-a0f0-6411e361efba","subtype":"Chart","type":"Plot"},"ticker":{"id":"56324e26-8d0b-425b-b34e-e7910b0f1ef3","type":"BasicTicker"}},"id":"5dc1960a-ab6b-43ed-8d11-260c9470207f","type":"Grid"},{"attributes":{"children":[{"id":"058c9960-d686-4ac0-8fd2-89d360cbd2b7","type":"Row"}],"sizing_mode":"scale_width"},"id":"cdab1373-0bde-446e-a849-e86b04b062c8","type":"Column"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"bef2fbc1-2497-42ec-9a60-e46fecb643d0","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"c74b4629-d681-4e3d-bb9a-6f64a9f04faa","type":"LinearAxis"}],"plot_height":750,"renderers":[{"id":"0d5022c1-6d47-41a0-8483-47b3fea88c20","type":"BoxAnnotation"},{"id":"bf5d6157-3203-4110-ab11-4bcdc61671d5","type":"BoxAnnotation"},{"id":"7bf86f31-d0f8-4c30-954c-703a925067f8","type":"GlyphRenderer"},{"id":"5bc47be6-e720-473a-9e6f-9475111ad292","type":"GlyphRenderer"},{"id":"f42526e1-2509-4171-b5b9-53ef048afc85","type":"GlyphRenderer"},{"id":"11448e98-7841-455a-b846-311d5bb2ae28","type":"GlyphRenderer"},{"id":"1a47833f-787e-40bd-bd0c-59331508c908","type":"GlyphRenderer"},{"id":"dbd8c3a6-ba26-431c-b301-137e2f11e606","type":"GlyphRenderer"},{"id":"c95a5315-7c33-48c1-85fc-e7f5c1f70c38","type":"GlyphRenderer"},{"id":"dfe6a9d6-d644-4858-90e1-4ea256a58716","type":"Legend"},{"id":"bef2fbc1-2497-42ec-9a60-e46fecb643d0","type":"CategoricalAxis"},{"id":"c74b4629-d681-4e3d-bb9a-6f64a9f04faa","type":"LinearAxis"},{"id":"5dc1960a-ab6b-43ed-8d11-260c9470207f","type":"Grid"}],"sizing_mode":"scale_width","title":{"id":"29259b7e-3717-40b3-93c0-bd68c3673525","type":"Title"},"tool_events":{"id":"f4768e60-b58a-48be-a388-05bffa1bd0db","type":"ToolEvents"},"toolbar":{"id":"0eb077c6-7ec8-473f-b5d2-98770d224680","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":"auto","x_range":{"id":"ee4f8a88-4122-49de-add0-8ccdd22a7c64","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"fc5885c9-992e-4e8f-83ba-eb8910fbd75e","type":"Range1d"}},"id":"4a6e6a26-31d8-4270-a0f0-6411e361efba","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"136328c6-b5de-4717-ab2e-042a182a8611","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Cycling"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9.0],"label":[{"type":"Cycling"}],"line_alpha":[1.0],"line_color":["black"],"type":["Cycling"],"width":[0.8],"x":["Cycling"],"y":[148.5]}},"id":"711fb00c-7307-471e-85c0-f6ab43eefb01","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"1391554f-a6b8-494f-adb3-879abb2d434e","type":"BoxAnnotation"},"plot":{"id":"99d93f33-801d-4d9a-9f60-7559b33dd7db","subtype":"Chart","type":"Plot"}},"id":"5ef45981-2f93-4104-8645-1c6761c8e97e","type":"BoxZoomTool"},{"attributes":{"align":"center","plot":null,"text":"Total calories burned by activity type","text_font_size":{"value":"25px"}},"id":"0a1e87b0-b44a-47cb-b7dc-dfeb109715cc","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_col ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## 3) Activites by period
#
# First of all we need to split the information by period. To achieve that, the idea is apply a group selection by partial string in timestamp column

# %% [markdown]
# ## Timestamp split into columns
#
# In order to have a better way to handle the data by period, it'll be necessary split the timestamp column into separate columns

# %%
# =================================================================================
# Dataframe timestamp split
# =================================================================================

# Copy the data
data_by_period = api_df.copy()
data_by_period["month"] = 0
data_by_period["month_index"] = 0
data_by_period["year"] = 0

# Fill the years
data_by_period.loc[data_by_period['start_time'].str.contains('2017'), 'year'] = '2017'
data_by_period.loc[data_by_period['start_time'].str.contains('2016'), 'year'] = '2016'
data_by_period.loc[data_by_period['start_time'].str.contains('2015'), 'year'] = '2015'
data_by_period.loc[data_by_period['start_time'].str.contains('2014'), 'year'] = '2014'

# Fill the months
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month'] = 'Jan'
data_by_period.loc[data_by_period['start_time'].str.contains('Jan'), 'month_index'] = '1'

data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month'] = 'Feb'
data_by_period.loc[data_by_period['start_time'].str.contains('Feb'), 'month_index'] = '2'

data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month'] = 'Mar'
data_by_period.loc[data_by_period['start_time'].str.contains('Mar'), 'month_index'] = '3'

data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month'] = 'Apr'
data_by_period.loc[data_by_period['start_time'].str.contains('Apr'), 'month_index'] = '4'

data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month'] = 'May'
data_by_period.loc[data_by_period['start_time'].str.contains('May'), 'month_index'] = '5'

data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month'] = 'Jun'
data_by_period.loc[data_by_period['start_time'].str.contains('Jun'), 'month_index'] = '6'

data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month'] = 'Jul'
data_by_period.loc[data_by_period['start_time'].str.contains('Jul'), 'month_index'] = '7'

data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month'] = 'Aug'
data_by_period.loc[data_by_period['start_time'].str.contains('Aug'), 'month_index'] = '8'

data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month'] = 'Sep'
data_by_period.loc[data_by_period['start_time'].str.contains('Sep'), 'month_index'] = '9'

data_by_period.loc[data_by_period['start_time'].str.contains('Oct-'), 'month'] = 'Oct'
data_by_period.loc[data_by_period['start_time'].str.contains('Oct'), 'month_index'] = '10'

data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month'] = 'Nov'
data_by_period.loc[data_by_period['start_time'].str.contains('Nov'), 'month_index'] = '11'

data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month'] = 'Dec'
data_by_period.loc[data_by_period['start_time'].str.contains('Dec'), 'month_index'] = '12'

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid replacing the timestamp to other columns, we'll export the new dataSet to a csv file. You can skip this operation because the new .csv dataSet is already included in the project

# %%
# Export the new dataSet to csv
data_by_period.to_csv('dataSourceByPeriod.csv', encoding="utf-8")

# %% [markdown]
# ## All years overview

# %%
# =================================================================================
# Data import
# =================================================================================

# Import the fertility.csv data: data
data_by_period = pd.read_csv("dataSourceByPeriod.csv", encoding = 'latin2')

# =================================================================================
# Year selection
# =================================================================================

yearList = data_by_period.year.unique()

for idx, val in enumerate(yearList):

    # =================================================================================
    # Data selection
    # =================================================================================

    year = val

    # Filter the activities by year
    activitiesYear = data_by_period[data_by_period["year"] == year].sort_values('month_index')

    # =================================================================================
    # Data count
    # =================================================================================

    # Do some fix in disciplineStatus
    activityType = activitiesYear.copy()
    activityType["Count"] = 0

    # Count the status sum-up
    activityType = pd.DataFrame(activityType.groupby(["type"])['Count'].count()).reset_index()

    # =================================================================================
    # Chart plotting
    # =================================================================================

    # Tools
    TOOLS = 'box_zoom,box_select,crosshair,resize,hover,reset,save'

    barMonth = Bar(activitiesYear, values='total_distance', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barCaloryMonth = Bar(activitiesYear, values='total_calories', label=CatAttr(columns=['month'], sort=False), color='month', agg='sum', 
                          legend='top_left', tools=TOOLS)

    barDurationMonth = Bar(activitiesYear, values='duration', label=CatAttr(columns=['month'], sort=False), color='month', agg='mean', 
                          legend='top_left', tools=TOOLS)

    # Donut chart settings
    donutType = Donut(activityType, label=['type', 'Count'], values='Count',
              text_font_size='14pt', legend='top_left', 
              tools=TOOLS, background_fill_color="#E8DDCB", title='Discipline status', 
              color='type')

    # Set the y and x axis label
    barMonth.yaxis.axis_label= 'Total distance'
    barMonth.xaxis.axis_label= 'Month'

    barCaloryMonth.yaxis.axis_label= 'Total calories'
    barCaloryMonth.xaxis.axis_label= 'Month'

    barDurationMonth.yaxis.axis_label= 'Total duration'
    barDurationMonth.xaxis.axis_label= 'Month'

    # Set hover to bars
    hover = barMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total distance:',' @height')]

    hover = barCaloryMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = barDurationMonth.select(dict(type=HoverTool))
    hover.tooltips = [('Month', '@x'),('Total calories:',' @height')]

    hover = donutType.select(dict(type=HoverTool))
    hover.tooltips = [('Activity', '@x'),('Count:',' @height')]

    # Configure visual properties on a plot's title attribute
    barMonth.title.text = "Total distance by month in " + str(year)
    barMonth.title.align = "center"
    barMonth.title.text_font_size = "25px"

    barCaloryMonth.title.text = "Total calories by month in " + str(year)
    barCaloryMonth.title.align = "center"
    barCaloryMonth.title.text_font_size = "25px"

    barDurationMonth.title.text = "Average duration by month in " + str(year)
    barDurationMonth.title.align = "center"
    barDurationMonth.title.text_font_size = "25px"

    donutType.title.text = "Activities types in " + str(year)
    donutType.title.align = "center"
    donutType.title.text_font_size = "25px"

    # Create a list containing plots
    row1 = [barMonth, barCaloryMonth]
    row2 = [barDurationMonth, donutType]

    # Create a gridplot using row1 and row2: layout
    layout = gridplot([row1, row2],sizing_mode='scale_width', plot_height=650, plot_width=900)

    # Call the output_notebook()
    display(Markdown('# Activities overview in ' + str(year)))
    display(Markdown('<hr>'))

    output_notebook()
    show(layout)
# Out:
# # Activities overview in 2017
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="31f3cdd5-59fd-4c39-ac34-5dc05b115a29">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a2c615af-f773-4253-83ce-4224ded2fb89"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a2c615af-f773-4253-83ce-4224ded2fb89").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a2c615af-f773-4253-83ce-4224ded2fb89");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a2c615af-f773-4253-83ce-4224ded2fb89' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ee2388a0-fd73-4606-8838-81caf4219935":{"roots":{"references":[{"attributes":{"label":{"value":"Apr"},"renderers":[{"id":"01acb612-fed7-4e68-b97c-99f4b84f5f1c","type":"GlyphRenderer"}]},"id":"9044633a-47f6-4c46-9e4a-69ad9926da90","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8a2f4134-4155-44f3-9ca4-26c00f3cc3ac","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"8a2f4134-4155-44f3-9ca4-26c00f3cc3ac","type":"BoxAnnotation"},"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"5da0b370-e4fc-4860-b16e-172f7ab3d972","type":"BoxZoomTool"},{"attributes":{},"id":"e89f530b-b277-419c-901d-d379decfc76a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"overlay":{"id":"0ed94a80-30d2-4219-b49d-e9f5fa09be59","type":"BoxAnnotation"},"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"0162c7ce-1467-4ce6-b6d0-ba363546b7da","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"1581b7d9-d22d-4312-8af7-798c3a252eee","type":"CrosshairTool"},{"attributes":{"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"90d24b32-016d-43a0-aec9-493bb48a2ea7","type":"ResizeTool"},{"attributes":{"callback":null,"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"},"tooltips":[["Month","@x"],["Total calories:"," @height"]]},"id":"e26b3acc-7644-46b9-b675-c3f9c8e057c8","type":"HoverTool"},{"attributes":{"callback":null,"overlay":{"id":"1a200a8e-1d78-4ee0-a62f-baae54d39d44","type":"BoxAnnotation"},"plot":{"id":"28ce5d23-9c8e-4f89-89a1-9140a18a4ca1","subtype":"Chart","type":"Plot"}},"id":"5a195472-a898-40da-a52c-8369099594b9","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"979386ab-687e-4550-bcdf-9dd65caa1650","type":"ResetTool"},{"attributes":{"plot":{"id":"c52e4856-e88c-4f83-afa7-62e02b9af204","subtype":"Chart","type":"Plot"}},"id":"6ff25812-8c10-4070-a8ea-8d4f76c95478","type":"SaveTool"},{"attributes":{"plot":{"id":"28ce5d23-9c8e-4f89-89a1-9140a18a4ca1","subtype":"Chart","type":"Plot"}},"id":"df0a1b3a-14f9-4b80-b259-887bfc8145bf","type":"CrosshairTool"},{"attributes":{"overlay":{"id":"17073af5-fc18-4d5a-91dc-99d3662edc66","type":"BoxAnnotation"},"plot":{"id":"28ce5d23-9c8e-4f89-89a1-9140a18a4ca1","subtype":"Chart","type":"Plot"}},"id":"44534e54-cc6a-4f3d-9dab-505f64eba723","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0ed94a80-30d2-4219-b49d-e9f5fa09be59","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"28ce5d23-9c8e-4f89-89a1-9140a18a4ca1","subtype":"Chart","type":"Plot"},"tooltips":[["Activity","@x"],["Count:"," @height"]]},"id":"36dc4bc0-4ab9-4b79-a24d-fe6587e76702","type":"HoverTool"},{"attributes":{"label":{"value":"May"},"renderers":[{"id":"e0eba0bd-c13f-46f1-af94-8cfe8b872932","type":"GlyphRenderer"}]},"id":"c7d142e0-7f56-4342-ad21-d4086c5619a3","type":"LegendItem"},{"attributes":{"plot":{"id":"28ce5d23-9c8e-4f89-89a1-9140a18a4ca1","subtype":"Chart","type":"Plot"}},"id":"f7643acf-d94c-4d34-8d53-0634ec4e058a","type":"ResizeTool"},{"attributes":{"label":{"value":"Jun"},"renderers":[{"id":"e806832c-c482-4a24-baa4-d10d592b8480","type":"GlyphRenderer"}]},"id":"8ab323be-502c-4789-91e0-9afe8c9f2e51","type":" ...
# # Activities overview in 2016
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1bf0c7eb-c3bc-4b88-bed3-0ac1ecaa4734">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8cb8b7fa-ecd9-4b65-a660-99ad2a5a902f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8cb8b7fa-ecd9-4b65-a660-99ad2a5a902f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8cb8b7fa-ecd9-4b65-a660-99ad2a5a902f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8cb8b7fa-ecd9-4b65-a660-99ad2a5a902f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"318e653f-86d8-40f7-a538-c243b57f4983":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"Jul"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[454.0],"label":[{"month":"Jul"}],"line_alpha":[1.0],"line_color":["white"],"month":["Jul"],"width":[0.8],"x":["Jul"],"y":[227.0]}},"id":"cd010f33-df9b-4cc6-a14f-98eb532ede0f","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"eae837ab-0a7b-42ff-b3bd-8d4871b1e5ce","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Feb"},"renderers":[{"id":"24b523a1-cb91-46ec-8eb3-2599a842d252","type":"GlyphRenderer"}]},"id":"99b8adf4-95d3-45b1-b7aa-9e39dee12bc1","type":"LegendItem"},{"attributes":{"label":{"value":"Mar"},"renderers":[{"id":"4f672927-c353-4801-a0a5-6178deb594fb","type":"GlyphRenderer"}]},"id":"f27e26b8-b037-48d5-8eba-7a7a7b64c840","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"May"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[2235.0],"label":[{"month":"May"}],"line_alpha":[1.0],"line_color":["white"],"month":["May"],"width":[0.8],"x":["May"],"y":[1117.5]}},"id":"19431804-c64d-4787-b7ed-a6d74e3fe94d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"19431804-c64d-4787-b7ed-a6d74e3fe94d","type":"ColumnDataSource"},"glyph":{"id":"3d353391-ee4a-4d4a-9e34-2da6953ad6e7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e65ebdd3-158a-4d39-a3e5-bb9824363d3f","type":"GlyphRenderer"},{"attributes":{"label":{"value":"May"},"renderers":[{"id":"fc8ab69c-d07a-4415-9299-fca5039f5547","type":"GlyphRenderer"}]},"id":"eb4d53cd-fb59-422e-a4c6-8225b8b991f2","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"0"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[30.32866666666667],"label":[{"month":"0"}],"line_alpha":[1.0],"line_color":["white"],"month":["0"],"width":[0.8],"x":["0"],"y":[15.164333333333335]}},"id":"b0c35d83-21f8-4d24-8a82-7d8f6bb3443a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"451ff7ff-3d5a-4a97-a615-500741800552","type":"ColumnDataSource"},"glyph":{"id":"90882e94-2253-47e1-865c-242f9883c55d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4f672927-c353-4801-a0a5-6178deb594fb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e1146de4-3218-4fe8-8f08-951784912ef9","type":"ColumnDataSource"},"glyph":{"id":"25f9d61d-ad9c-4afa-86f8-8d89345be147","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6a6badef-7f5b-4fc5-bff7-7c4434b08536","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"May"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[29208.499999999996],"label":[{"month":"May"}],"line_alpha":[1.0],"line_color":["white"],"month":["May"],"width":[0.8],"x":["May"],"y":[14604.249999999998]}},"id":"6d7fd2e4-c26a-48a7-8957-455206320855","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"Nov"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[4728.0],"label":[{"month":"Nov"}],"line_alpha":[1.0],"line_color":["white"],"month":["Nov"],"width":[ ...
# # Activities overview in 2015
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10e0963c-c785-4041-951e-0663abc423a3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bafdae2d-daaa-45d1-8861-a5e849c103f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bafdae2d-daaa-45d1-8861-a5e849c103f5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bafdae2d-daaa-45d1-8861-a5e849c103f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bafdae2d-daaa-45d1-8861-a5e849c103f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6775bc82-37d9-4992-9a00-512daab072a5":{"roots":{"references":[{"attributes":{"children":[{"id":"b3114f12-497f-4998-8d2a-809d8702bbad","type":"Row"},{"id":"ca813b80-6c8a-476f-bf93-60fd31222729","type":"Row"}],"sizing_mode":"scale_width"},"id":"71166e62-cf1f-4246-a5a6-52648e503388","type":"Column"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a10a1228-e815-4b8c-b379-d2c2ee1c838b","type":"Rect"},{"attributes":{},"id":"fb65cb5a-b7d0-4470-ae15-a07f3f232419","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":14555.635499999999},"id":"188ada92-df18-4ee0-b0c4-5e1fe1e9449a","type":"Range1d"},{"attributes":{},"id":"bb77d6cf-5ab7-4345-bff0-e2826791190f","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"May"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[362.0],"label":[{"month":"May"}],"line_alpha":[1.0],"line_color":["white"],"month":["May"],"width":[0.8],"x":["May"],"y":[181.0]}},"id":"14560555-d0d2-4a62-8444-f9b3126c8b57","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"72a1f349-22f0-4f65-9e8d-7e197a143cfb","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"Nov"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[24.63],"label":[{"month":"Nov"}],"line_alpha":[1.0],"line_color":["white"],"month":["Nov"],"width":[0.8],"x":["Nov"],"y":[12.315]}},"id":"e64ac4c7-945f-4e7d-84a0-431e1c3e3d4d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"month":"Apr"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[1223.0],"label":[{"month":"Apr"}],"line_alpha":[1.0],"line_color":["white"],"month":["Apr"],"width":[0.8],"x":["Apr"],"y":[611.5]}},"id":"bae48168-e452-46ba-8c24-1c4b9e513157","type":"ColumnDataSource"},{"attributes":{},"id":"c081378a-cae3-4b07-917b-5f8599ab4ca5","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b0440f0-91b3-4752-b229-a109cebebf98","type":"Rect"},{"attributes":{},"id":"92124c9e-2a70-42f5-81b9-d9ed15c9655f","type":"BasicTicker"},{"attributes":{"data_source":{"id":"e64ac4c7-945f-4e7d-84a0-431e1c3e3d4d","type":"ColumnDataSource"},"glyph":{"id":"72a1f349-22f0-4f65-9e8d-7e197a143cfb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5c6e6ce3-7c4b-4c2b-9ac1-982ac670dd6b","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"642c5f27-25eb-4547-9406-75836ab3b2d9","subtype":"Chart","type":"Plot"},"ticker":{"id":"92124c9e-2a70-42f5-81b9-d9ed15c9655f","type":"BasicTicker"}},"id":"26317a6a-4391-4506-9d03-1da242cb3965","type":"Grid"},{"attributes":{"data_source":{"id":"bae48168-e452-46ba-8c24-1c4b9e513157","type":"ColumnDataSource"},"glyph":{"id":"0b0440f0-91b3-4752-b229-a109cebebf98","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f719caa7-fe21-41e1-936d-12753df25448","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"7f212dda-6a24-4aed-8bd8-f43ab602749f","subtype":"Chart","type":"Plot"},"ticker":{"id":"1a399952-41ce-4b53-9f62-135b7ea3134c","type":"Bas ...
# # Activities overview in 2014
# <hr>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="866b9bdf-b84c-439f-9d31-b31ab0115cdf">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d727ed54-d8f2-4cc9-9545-8fcbc75f4dac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d727ed54-d8f2-4cc9-9545-8fcbc75f4dac").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d727ed54-d8f2-4cc9-9545-8fcbc75f4dac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd727ed54-d8f2-4cc9-9545-8fcbc75f4dac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"689239ea-054c-49ba-9489-c7e53a37ec11":{"roots":{"references":[{"attributes":{"align":"center","plot":null,"text":"Total distance by month in 2014","text_font_size":{"value":"25px"}},"id":"4e547e10-5e64-4b5f-bcac-416983c69c8c","type":"Title"},{"attributes":{"label":{"value":"Mar"},"renderers":[{"id":"19227edd-1781-4d3d-8f79-faf017f3f14d","type":"GlyphRenderer"}]},"id":"0fbca686-5fa7-4c55-9f8b-b95ce5d5f53d","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","type_Count"],"data":{"centers":[2.25,1.125],"color":["#f22c40","#f22c40"],"end":[6.283185307179586,6.283185307179586],"inners":[1.5,0.0],"level":[1.0,0.0],"outers":[3.0,1.5],"start":[0.0,0.0],"type_Count":[["Running",2],["Running",""]],"values":[2,2]}},"id":"ccd001e8-be3d-4303-88a0-db6472a18442","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"1d196432-6130-4682-b891-e85e2a0297c7","subtype":"Chart","type":"Plot"}},"id":"a979411e-b4ba-42b5-979f-2921d3a20614","type":"CrosshairTool"},{"attributes":{"overlay":{"id":"913bc4bf-216b-4218-ab4b-eec09818db88","type":"BoxAnnotation"},"plot":{"id":"1d196432-6130-4682-b891-e85e2a0297c7","subtype":"Chart","type":"Plot"}},"id":"19d6840b-5a05-4f9b-a834-fb9d5c04fefb","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":3119.0564999999997},"id":"97bd708d-bf27-4c83-b8ba-9579f487e6dc","type":"Range1d"},{"attributes":{"axis_label":"Total duration","formatter":{"id":"50c9996e-4b1e-4f95-9bcf-cf835c982091","type":"BasicTickFormatter"},"plot":{"id":"c3c0ad4d-6845-4cc1-8b02-5fd53bae369b","subtype":"Chart","type":"Plot"},"ticker":{"id":"f3a9746e-fb92-4afe-a1aa-fbfe6a2fa34b","type":"BasicTicker"}},"id":"df737bae-69e3-4373-a779-10166d000198","type":"LinearAxis"},{"attributes":{"below":[{"id":"9ed616a3-a6ce-46c4-8332-c25912606b9d","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"df737bae-69e3-4373-a779-10166d000198","type":"LinearAxis"}],"plot_height":650,"plot_width":900,"renderers":[{"id":"cd933faf-21e3-4b35-8212-70eb55426ff0","type":"BoxAnnotation"},{"id":"ca7181db-b09a-4ecf-b6f4-3c4087df78e4","type":"BoxAnnotation"},{"id":"ca387944-6e1b-41aa-9928-a352c74dd035","type":"GlyphRenderer"},{"id":"820f35d0-c58e-44ad-ad7d-1411d31d0422","type":"Legend"},{"id":"9ed616a3-a6ce-46c4-8332-c25912606b9d","type":"CategoricalAxis"},{"id":"df737bae-69e3-4373-a779-10166d000198","type":"LinearAxis"},{"id":"cb8509ac-6e03-4cd3-ab3e-02eb53a01494","type":"Grid"}],"sizing_mode":"scale_width","title":{"id":"f5ea3120-6240-4b18-8467-9f495f624e35","type":"Title"},"tool_events":{"id":"c2cd98c8-8c44-4f82-9847-11956ba48958","type":"ToolEvents"},"toolbar":{"id":"a24cfb37-94fa-4ec3-bae9-ab0bb66e6ca0","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":"auto","x_range":{"id":"a9e62d94-bff5-4e02-b556-9627ab319968","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"a71598d8-cca3-43f8-aa21-656ca148c51c","type":"Range1d"}},"id":"c3c0ad4d-6845-4cc1-8b02-5fd53bae369b","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"19d6840b-5a05-4f9b-a834-fb9d5c04fefb","type":"BoxZoomTool"},{"id":"2c4bbc8d-3f69-4d8c-9319-1030ba299d06","type":"BoxSelectTool"},{"id":"a979411e-b4ba-42b5-979f-2921d3a20614","type":"CrosshairTool"},{"id":"ef043863-80e0-4a73-9ea7-0259604984b6","type":"ResizeTool"},{"id":"42ef0619-346c-4248-972c-2273f271ab74","type":"HoverTool"},{"id":"6c90e579-bd71-4ad0-8df3-b8689dcb9dde","type":"ResetTool"},{"id":"3754d6b7-ac7c-4283-8dd2-002da7190fa3","type":"SaveTool"}]},"id":"285e98c9-0b8c-4a6b-90d8-19624b9c9dff","type":"Toolbar"},{"attributes":{},"id":"c2cd98c8-8c44-4f82-9847-11956ba48958","type":"ToolEvents"},{"attributes":{"data_source":{"id":"6f408706-3041-4b3b-9300-9efacc1d89a7","type":"ColumnDataSource"},"glyph":{"id":"630a431b-9ded-4eef-aed0-ff524e5d4318","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ca387944-6e1b ...

# %% [markdown]
# # Geolocation section
#
# #### Here in this section, we'll handle the geolocation infos.

# %% [markdown]
# ## Location import [warning: too heavy]
#
# The cell below perform multiple requests to Runkeep Health Graph API, in order to retrieve all activities in details to get location informations such as: latitude/longitude

# %%
# =================================================================================
# Geolocation data
# =================================================================================

# Copy the data
geolocation_data = pd.DataFrame()

# =================================================================================
# API single activity request
# =================================================================================

# Base URI
base_URI = "http://api.runkeeper.com"

limit = 2

# Run through all activites
for idx, row in api_df.iterrows():
    
    # Final activity URI
    activity_url = base_URI + row['uri'] + "?access_token=" + ACCESS_TOKEN

    # Receive the results from API
    activity_content = requests.get(activity_url).json()

    # Perform a conversion from JSON to Data Frame
    activity_df = json_normalize(activity_content['path'])
    
    # Add the activity path data to geolocation
    geolocation_data = pd.concat([geolocation_data, activity_df])
    
geolocation_data
# Out:
#      altitude  latitude  longitude  timestamp   type
# 0   37.508971 -5.866466 -35.184888      0.000  start
# 1   37.553144 -5.866379 -35.184881     30.607    gps
# 2   37.609001 -5.866296 -35.184838     34.583    gps
# 3   37.672647 -5.866239 -35.184923     38.595    gps
# 4   37.732655 -5.866184 -35.185014     41.591    gps
# 5   37.790017 -5.866138 -35.185083     43.602    gps
# 6   37.891945 -5.866102 -35.185158     45.599    gps
# 7   37.993480 -5.866051 -35.185232     47.593    gps
# 8   38.096786 -5.865959 -35.185270     50.597    gps
# 9   38.203306 -5.865881 -35.185326     56.594    gps
# 10  38.314050 -5.865778 -35.185327     61.591    gps
# 11  38.438017 -5.865700 -35.185272     65.601    gps
# 12  38.561983 -5.865606 -35.185243    121.593    gps
# 13  38.677686 -5.865545 -35.185302    124.587    gps
# 14  38.776860 -5.865505 -35.185373    126.579    gps
# 15  38.867769 -5.865445 -35.185467    129.596    gps
# 16  38.950413 -5.865384 -35.185578    132.586    gps
# 17  39.024793 -5.865332 -35.185649    134.600    gps
# 18  39.090909 -5.865291 -35.185731    136.663    gps
# 19  39.140496 -5.865245 -35.185807    138.607    gps
# 20  39.181818 -5.865178 -35.185906    140.525    gps
# 21  39.223140 -5.865137 -35.185987    142.546    gps
# 22  39.256198 -5.865090 -35.186078    144.506    gps
# 23  39.280992 -5.865041 -35.186151    146.612    gps
# 24  39.305785 -5.864980 -35.186256    148.589    gps
# 25  39.347107 -5.864927 -35.186333    150.613    gps
# 26  39.404959 -5.864881 -35.186408    152.590    gps
# 27  39.471074 -5.864852 -35.186496    154.594    gps
# 28  39.537190 -5.864818 -35.186588    156.590    gps
# 29  39.603306 -5.864784 -35.186673    158.595    gps
# ..        ...       ...        ...        ...    ...
# 62  41.272727 -5.837374 -35.204052    566.278    gps
# 63  41.909091 -5.837378 -35.204152    572.286    gps
# 64  42.545455 -5.837391 -35.204265    579.283    gps
# 65  42.727273 -5.837394 -35.204383    589.266    gps
# 66  42.909091 -5.837407 -35.204485    597.286    gps
# 67  43.090909 -5.837423 -35.204580    605.260    gps
# 68  43.272727 -5.837428 -35.204679    612.236    gps
# 69  43.454545 -5.837404 -35.204768    618.284    gps
# 70  43.636364 -5.837390 -35.204863    625.431    gps
# 71  44.181818 -5.837403 -35.204956    634.283    gps
# 72  44.727273 -5.837385 -35.205051    640.278    gps
# 73  45.090909 -5.837381 -35.205143    647.295    gps
# 74  45.454545 -5.837340 -35.205233    654.279    gps
# 75  45.818182 -5.837297 -35.205318    660.267    gps
# 76  46.181818 -5.837257 -35.205409    667.273    gps
# 77  46.545455 -5.837231 -35.205499    674.283    gps
# 78  46.909091 -5.837232 -35.205598    682.242    gps
# 79  47.272727 -5.837292 -35.205686    689.260    gps
# 80  47.636364 -5.837355 -35.205753    694.275    gps
# 81  48.181818 -5.837433 -35.205801    700.279    gps
# 82  48.363636 -5.837550 -35.205871    711.240    gps
# 83  48.545455 -5.837620 -35.205942    716.287    gps
# 84  48.727273 -5.837649 -35.206036    722.284    gps
# 85  48.909091 -5.837644 -35.206134    727.275    gps
# 86  49.090909 -5.837651 -35.206233    734.278    gps
# 87  49.200000 -5.837656 -35.206339    741.285    gps
# 88  49.333333 -5.837683 -35.206428    747.271    gps
# 89  49.500000 -5.837591 -35.206457    755.242    gps
# 90  49.714286 -5.837495 -35.206484    768.285    gps
# 91  50.000000 -5.837505 -35.206520    839.407    end
#
# [99819 rows x 5 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid processing the cell above, here we are saving the processed geolocationd data.

# %%
# Export the new dataSet to csv
geolocation_data.to_csv('geolocation.csv', encoding="utf-8")

# %% [markdown]
# ## 1) Heatmap

# %%
# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in range(len(geolocation_data)):
    # eliminate items with'nan' element
    if all(~np.isnan([geolocation_data.ix[i,'latitude'], geolocation_data.ix[i,'longitude']])):
        coordinates.append([geolocation_data.ix[i,'latitude'], geolocation_data.ix[i,'longitude']])

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Print the heatMap
htMap
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-278-b8e8394cbfa8> in <module>()
#       9 for i in range(len(geolocation_data)):
#      10     # eliminate items with'nan' element
# ---> 11     if all(~np.isnan([geolocation_data.ix[i,'latitude'], geolocation_data.ix[i,'longitude']])):
#      12         coordinates.append([geolocation_data.ix[i,'latitude'], geolocation_data.ix[i,'longitude']])
#      13
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
